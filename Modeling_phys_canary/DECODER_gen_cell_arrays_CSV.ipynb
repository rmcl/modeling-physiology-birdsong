# %% [markdown]
# ## This code takes in .csv outputs from the TweetyBERT decoder, then saves the data into cell arrays inside of .mat files, which can be then input into Jeff Markowitz's probabalistic suffix tree (PST). PST pipeline can be found here: https://github.com/jmarkow/pst

# %% [markdown]
# ### Currently, TweetyBERT assumes ALL recordings were taken in 2024. This cell corrects that bug by using the .json file I generated for each dataset that contains the dates of recordings (found from the file properties), as well as the lesion date (that I input manually)

# %%
import pandas as pd
import numpy as np

recording_file_path_name = '/Users/mirandahulsey-vincent/Documents/allPythonCode/syntax_analysis/DECODER_csvs_and_jsons/USA5326_decoded.csv'
decoder_dataframe = pd.read_csv(recording_file_path_name)
path_to_json_file_with_dates = '/Users/mirandahulsey-vincent/Documents/allPythonCode/syntax_analysis/DECODER_csvs_and_jsons/USA5326_creation_data.json'
json_data = pd.read_json(path_to_json_file_with_dates)

print(decoder_dataframe.head(2))

from datetime import datetime
json_surgery_date = json_data['treatment_date'].iloc[0]  # Get the first date if it's a Series
# Convert string to datetime object
date_obj = datetime.strptime(json_surgery_date, "%Y-%m-%d")
# Convert datetime object to desired format
surgery_date = date_obj.strftime("%m.%d.%Y")
lesion_date = surgery_date
print(f"Surgery date: {surgery_date}")
# Out:
#                                 file_name  song_present  \
# 0   USA5326_45324.28882476_2_2_8_1_22.wav          True
# 1  USA5326_45324.32074401_2_2_8_54_34.wav         False
#
#                           syllable_onsets_offsets_ms  \
# 0  {'35': [[0.0, 83.65079365079366]], '31': [[83....
# 1                                                 {}
#
#                     syllable_onsets_offsets_timebins
# 0  {'35': [[0.0, 31]], '31': [[31.0, 72], [112.0,...
# 1                                                 {}
# Surgery date: 02.20.2024

# %% [markdown]
# ### Organize the dataframe to extract animal ID, date and time of recording

# %%
import pandas as pd
import json

with open(path_to_json_file_with_dates, 'r') as f:
    json_data = json.load(f)

# Extract subdirectory creation dates from JSON data
subdirectory_dates = {subdir: data['subdirectory_creation_date'] for subdir, data in json_data['subdirectories'].items()}

# Function to extract date, time, and animal_id from the file name
def find_recording_dates_and_times(recording_file_path_name):
    try:
        # Split the full path to isolate the file name
        file_name = recording_file_path_name.split('/')[-1]
        
        # Split the file name by underscores to extract relevant parts
        split_file_name_by_underscores = file_name.split('_')
        
        # Extract animal ID
        animal_id = split_file_name_by_underscores[0]
        
        # Extract month and ensure it has two digits
        month = split_file_name_by_underscores[2].zfill(2)
        
        # Extract day and ensure it has two digits
        day = split_file_name_by_underscores[3].zfill(2)
        
        # Combine month and day to form the date in MM.DD format
        date = f"{month}.{day}"
        
        # Extract time components (hour, minute, second) and ensure proper formatting
        hour = split_file_name_by_underscores[4].zfill(2)
        minute = split_file_name_by_underscores[5].zfill(2)
        second = split_file_name_by_underscores[6].replace('.wav', '').zfill(2)  # Remove file extension
        
        return animal_id, date, hour, minute, second

    except IndexError:
        print(f"Error: Unexpected format in file name {recording_file_path_name}")
        return None, None, None, None, None
    except Exception as e:
        print(f"Error processing file {recording_file_path_name}: {e}")
        return None, None, None, None, None

# Function to update the date with year from the JSON file
def update_date_with_year(row, subdirectory_dates):
    month_day = row['Date']  # Extract the month and day
    month = month_day.split('.')[0]  # Get the month part
    for subdir, date in subdirectory_dates.items():
        year, json_month, json_day = date.split('-')  # Parse the year, month, and day from the JSON date
        if json_month == month:  # Match based on the month
            return f"{json_month}.{month_day.split('.')[1]}.{year}"  # Return the updated date with year
    return month_day  # If no match, return the original date

# Function to create a table from the DataFrame and update the date
def make_table(input_data_frame, subdirectory_dates):
    # Filter rows where song is present and reset index
    only_song_data = input_data_frame[input_data_frame['song_present'] == True].reset_index(drop=True)
    num_files_with_song = only_song_data.shape[0]

    # Initialize organized DataFrame
    organized_data_frame = only_song_data.copy()  # Retain original columns

    # Add new columns for animal ID, date, hour, minute, and second
    organized_data_frame['Animal ID'] = [None] * num_files_with_song
    organized_data_frame['Date'] = [None] * num_files_with_song
    organized_data_frame['Hour'] = [None] * num_files_with_song
    organized_data_frame['Minute'] = [None] * num_files_with_song
    organized_data_frame['Second'] = [None] * num_files_with_song

    for i, row in only_song_data.iterrows():
        recording_file_path_name = row['file_name']
        try:
            animal_id, date, hour, minute, second = find_recording_dates_and_times(recording_file_path_name)
            organized_data_frame.at[i, 'Animal ID'] = animal_id
            organized_data_frame.at[i, 'Date'] = date
            organized_data_frame.at[i, 'Hour'] = hour
            organized_data_frame.at[i, 'Minute'] = minute
            organized_data_frame.at[i, 'Second'] = second
        except Exception as e:
            print(f"Error processing file {recording_file_path_name}: {e}")
            continue

    # Update the 'Date' column with the year using the JSON data
    organized_data_frame['Date'] = organized_data_frame.apply(lambda row: update_date_with_year(row, subdirectory_dates), axis=1)

    # Output the results
    print(f"First rows of organized_data_frame with updated dates: {organized_data_frame.head(3)}")

    return organized_data_frame

# Run the function and generate the table with updated dates
organized_data_frame = make_table(decoder_dataframe, subdirectory_dates)
# Out:
# First rows of organized_data_frame with updated dates:                                 file_name  song_present  \
# 0   USA5326_45324.28882476_2_2_8_1_22.wav          True
# 1  USA5326_45324.34642642_2_2_9_37_22.wav          True
# 2   USA5326_45324.34922587_2_2_9_42_2.wav          True
#
#                           syllable_onsets_offsets_ms  \
# 0  {'35': [[0.0, 83.65079365079366]], '31': [[83....
# 1  {'31': [[0.0, 32.38095238095238], [1443.650793...
# 2  {'32': [[0.0, 129.52380952380952]], '30': [[12...
#
#                     syllable_onsets_offsets_timebins Animal ID        Date  \
# 0  {'35': [[0.0, 31]], '31': [[31.0, 72], [112.0,...   USA5326  02.02.2024
# 1  {'31': [[0.0, 12], [535.0, 579], [608.0, 643],...   USA5326  02.02.2024
# 2  {'32': [[0.0, 48]], '30': [[47.99999999999999,...   USA5326  02.02.2024
#
#   Hour Minute Second
# 0   08     01     22
# 1   09     37     22
# 2   09     42     02

# %% [markdown]
# ### Get the syllable order for ONE song

# %%
import json
import re

# Assuming this is the string you've printed
sample_one_song = organized_data_frame['syllable_onsets_offsets_ms'][0]

# Remove the extra outer single quotes and replace single quotes with double quotes
cleaned_sample = sample_one_song.strip("''")
cleaned_sample = re.sub(r"'", '"', cleaned_sample)

# Now try to load it as JSON
try:
    sample_one_song_dict = json.loads(cleaned_sample)
    print("Successfully parsed JSON.")
except json.JSONDecodeError as e:
    print(f"JSONDecodeError: {e}")

# Now you can proceed with your original logic
syllable_times = []

# Loop through each syllable label and its corresponding onset/offset pairs
for syllable_label, times in sample_one_song_dict.items():
    for onset_offset in times:
        syllable_times.append([syllable_label, onset_offset[0], onset_offset[1]])

# Convert the onset and offset times to floats if needed
syllable_times_array = np.array([[syllable_label, float(onset), float(offset)] 
                                 for syllable_label, onset, offset in syllable_times])

# Sort the array by the onset times (second column)
syllable_times_array_sorted = syllable_times_array[syllable_times_array[:, 1].argsort()]

# Display the sorted result
syllable_times_array_sorted
# Out:
# Successfully parsed JSON.
# array([['35', '0.0', '83.65079365079366'],
#        ['31', '1036.1904761904761', '1160.3174603174605'],
#        ['26', '1160.3174603174605', '1246.6666666666667'],
#        ['25', '1246.6666666666667', '1257.4603174603176'],
#        ['32', '1257.4603174603176', '1341.1111111111113'],
#        ['15', '1341.1111111111113', '1942.857142857143'],
#        ['26', '194.2857142857143', '302.22222222222223'],
#        ['32', '1942.857142857143', '2083.1746031746034'],
#        ['33', '2083.1746031746034', '2180.3174603174602'],
#        ['29', '2180.3174603174602', '2231.5873015873017'],
#        ['33', '2231.5873015873017', '3750.793650793651'],
#        ['31', '302.22222222222223', '456.0317460317461'],
#        ['26', '3750.793650793651', '3850.634920634921'],
#        ['26', '456.0317460317461', '558.5714285714286'],
#        ['31', '558.5714285714286', '706.984126984127'],
#        ['26', '706.984126984127', '809.5238095238096'],
#        ['31', '809.5238095238096', '920.1587301587302'],
#        ['31', '83.65079365079366', '194.2857142857143'],
#        ['26', '920.1587301587302', '1036.1904761904761']], dtype='<U32')

# %%
# import json
# import re
# import numpy as np

# # Assuming this is the string you've printed
# sample_one_song = organized_data_frame['syllable_onsets_offsets_ms'][0]

# # Remove the extra outer single quotes and replace single quotes with double quotes
# cleaned_sample = sample_one_song.strip("''")
# cleaned_sample = re.sub(r"'", '"', cleaned_sample)

# # Now try to load it as JSON
# try:
#     sample_one_song_dict = json.loads(cleaned_sample)
#     print("Successfully parsed JSON.")
# except json.JSONDecodeError as e:
#     print(f"JSONDecodeError: {e}")

# # Now you can proceed with your original logic
# syllable_times = []

# # Loop through each syllable label and its corresponding onset/offset pairs
# for syllable_label, times in sample_one_song_dict.items():
#     for onset_offset in times:
#         syllable_times.append([syllable_label, onset_offset[0], onset_offset[1]])

# # Convert the onset and offset times to floats if needed
# syllable_times_array = np.array([[syllable_label, float(onset), float(offset)] 
#                                  for syllable_label, onset, offset in syllable_times])

# # Sort the array by the onset times (second column)
# syllable_times_array_sorted = syllable_times_array[syllable_times_array[:, 1].argsort()]

# # Extract only the syllable labels in order of onset times
# syllable_order = syllable_times_array_sorted[:, 0]

# # Display the syllable order array
# syllable_order
# Out:
# Successfully parsed JSON.
# array(['10', '10', '9'], dtype='<U32')

# %% [markdown]
# ## Find the syllable order for each song, and add to the dataframe

# %%
import json
import re
import numpy as np
import pandas as pd

# Function to generate syllable order from a single song data (syllable_onsets_offsets_ms)
def get_syllable_order(sample_one_song):
    # Clean the input and parse it as JSON
    cleaned_sample = sample_one_song.strip("''")
    cleaned_sample = re.sub(r"'", '"', cleaned_sample)
    
    try:
        sample_one_song_dict = json.loads(cleaned_sample)
    except json.JSONDecodeError as e:
        print(f"JSONDecodeError: {e}")
        return None

    syllable_times = []
    
    # Loop through each syllable label and its corresponding onset/offset pairs
    for syllable_label, times in sample_one_song_dict.items():
        for onset_offset in times:
            syllable_times.append([syllable_label, onset_offset[0], onset_offset[1]])

    # Convert the onset and offset times to floats
    syllable_times_array = np.array([[syllable_label, float(onset), float(offset)] 
                                     for syllable_label, onset, offset in syllable_times])

    # Sort the array by onset times (second column)
    syllable_times_array_sorted = syllable_times_array[syllable_times_array[:, 1].argsort()]

    # Extract only the syllable labels in order of onset times
    syllable_order = syllable_times_array_sorted[:, 0]
    
    return syllable_order

# Function to iteratively find syllable orders for each row in the DataFrame
def find_syllable_orders(organized_data_frame):
    syllable_orders = []

    for i, row in organized_data_frame.iterrows():
        sample_one_song = row['syllable_onsets_offsets_ms']
        syllable_order = get_syllable_order(sample_one_song)
        if syllable_order is not None:
            syllable_orders.append(syllable_order)
        else:
            syllable_orders.append([])  # In case of a parsing error, append an empty array

    # Add a new column for the syllable orders
    organized_data_frame['syllable_order'] = syllable_orders
    
    return organized_data_frame

# Assuming you've already loaded the data and updated the table
organized_data_frame = make_table(decoder_dataframe, subdirectory_dates)

# Now find syllable orders for each song in the organized_data_frame
organized_data_frame_with_orders = find_syllable_orders(organized_data_frame)

# Output the first few rows with syllable orders
print(organized_data_frame_with_orders[['syllable_order']])
# Out:
# First rows of organized_data_frame with updated dates:                                 file_name  song_present  \
# 0   USA5326_45324.28882476_2_2_8_1_22.wav          True
# 1  USA5326_45324.34642642_2_2_9_37_22.wav          True
# 2   USA5326_45324.34922587_2_2_9_42_2.wav          True
#
#                           syllable_onsets_offsets_ms  \
# 0  {'35': [[0.0, 83.65079365079366]], '31': [[83....
# 1  {'31': [[0.0, 32.38095238095238], [1443.650793...
# 2  {'32': [[0.0, 129.52380952380952]], '30': [[12...
#
#                     syllable_onsets_offsets_timebins Animal ID        Date  \
# 0  {'35': [[0.0, 31]], '31': [[31.0, 72], [112.0,...   USA5326  02.02.2024
# 1  {'31': [[0.0, 12], [535.0, 579], [608.0, 643],...   USA5326  02.02.2024
# 2  {'32': [[0.0, 48]], '30': [[47.99999999999999,...   USA5326  02.02.2024
#
#   Hour Minute Second
# 0   08     01     22
# 1   09     37     22
# 2   09     42     02
#                                          syllable_order
# 0     [35, 31, 26, 25, 32, 15, 26, 32, 33, 29, 33, 3...
# 1                  [31, 26, 31, 26, 31, 26, 31, 26, 32]
# 2     [32, 30, 27, 30, 27, 30, 27, 30, 27, 30, 28, 2...
# 3                                [10, 11, 7, 1, 31, 23]
# 4     [34, 16, 13, 16, 13, 34, 33, 29, 3, 8, 12, 35,...
# ...                                                 ...
# 8002               [32, 35, 16, 32, 16, 32, 16, 32, 16]
# 8003    [32, 0, 26, 33, 27, 33, 27, 32, 33, 26, 25, 26]
# 8004  [32, 15, 9, 15, 9, 15, 9, 13, 6, 10, 11, 7, 1,...
# 8005  [32, 28, 34, 17, 28, 28, 13, 22, 28, 34, 35, 3...
# 8006                                [28, 17, 28, 32, 2]
#
# [8007 rows x 1 columns]

# %% [markdown]
# ## Map each syllable label to a letter instead of a number (1->A, etc. This is necessary so we can tell labels '1' and '2' apart from '12' once they all get concatonated  into a string)

# %% [markdown]
# ### Test this code for ONE song

# %%
# import json
# import re
# import numpy as np

# # Define a function to map syllable labels to unique characters
# def map_labels_to_characters(syllable_orders):
#     # Get all unique syllable labels across all rows
#     unique_labels = sorted(set(sum(syllable_orders, [])))  # Flatten the list of lists and get unique elements
    
#     # Create a mapping from each unique label to a unique character (uppercase, lowercase, digits)
#     available_chars = [chr(i) for i in range(65, 91)] + [chr(i) for i in range(97, 123)] + [chr(i) for i in range(48, 58)]  # A-Z, a-z, 0-9
#     if len(unique_labels) > len(available_chars):
#         raise ValueError("Too many unique labels to map to single characters!")
    
#     label_to_char = {label: available_chars[i] for i, label in enumerate(unique_labels)}
    
#     # Replace each label in the syllable order with its corresponding character
#     syllable_orders_mapped = []
#     for order in syllable_orders:
#         mapped_order = ''.join([label_to_char[label] for label in order])
#         syllable_orders_mapped.append(mapped_order)
    
#     return syllable_orders_mapped, label_to_char

# # Example syllable order (as shown in the sample)
# syllable_orders = [
#     ['8', '21', '22', '21', '22', '21', '22', '21', '26', '23', '2', '3', '26', '5', '11', '14']
# ]

# # Map the labels and get the string representation
# syllable_orders_mapped, label_to_char = map_labels_to_characters(syllable_orders)

# # Output the mapped syllable orders and the label-to-character mapping
# print("Mapped syllable order:", syllable_orders_mapped)
# print("Label-to-character mapping:", label_to_char)

# %% [markdown]
# ### Do this for EVERY song in the dataframe

# %%
import json
import re
import numpy as np
import pandas as pd

# Function to generate syllable order from a single song data (syllable_onsets_offsets_ms)
def get_syllable_order(sample_one_song):
    # Clean the input and parse it as JSON
    cleaned_sample = sample_one_song.strip("''")
    cleaned_sample = re.sub(r"'", '"', cleaned_sample)
    
    try:
        sample_one_song_dict = json.loads(cleaned_sample)
    except json.JSONDecodeError as e:
        print(f"JSONDecodeError: {e}")
        return None

    syllable_times = []
    
    # Loop through each syllable label and its corresponding onset/offset pairs
    for syllable_label, times in sample_one_song_dict.items():
        for onset_offset in times:
            syllable_times.append([syllable_label, onset_offset[0], onset_offset[1]])

    # Convert the onset and offset times to floats
    syllable_times_array = np.array([[syllable_label, float(onset), float(offset)] 
                                     for syllable_label, onset, offset in syllable_times])

    # Sort the array by onset times (second column)
    syllable_times_array_sorted = syllable_times_array[syllable_times_array[:, 1].argsort()]

    # Extract only the syllable labels in order of onset times
    syllable_order = syllable_times_array_sorted[:, 0]
    
    return syllable_order

# Function to map syllable labels to unique characters
def map_labels_to_characters(syllable_orders):
    # Flatten the list of syllable orders (since syllable_orders is a list of lists)
    flat_syllable_orders = [label for sublist in syllable_orders for label in sublist]
    
    # Get all unique syllable labels
    unique_labels = sorted(set(flat_syllable_orders))
    
    # Create a mapping from each unique label to a unique character (uppercase, lowercase, digits)
    available_chars = [chr(i) for i in range(65, 91)] + [chr(i) for i in range(97, 123)] + [chr(i) for i in range(48, 58)]  # A-Z, a-z, 0-9
    if len(unique_labels) > len(available_chars):
        raise ValueError("Too many unique labels to map to single characters!")
    
    label_to_char = {label: available_chars[i] for i, label in enumerate(unique_labels)}
    
    # Replace each label in the syllable order with its corresponding character
    syllable_orders_mapped = []
    for order in syllable_orders:
        mapped_order = ''.join([label_to_char[label] for label in order])
        syllable_orders_mapped.append(mapped_order)
    
    return syllable_orders_mapped, label_to_char

# Function to iteratively find syllable orders for each row and map them
def find_mapped_syllable_orders(organized_data_frame):
    syllable_orders = []

    for i, row in organized_data_frame.iterrows():
        sample_one_song = row['syllable_onsets_offsets_ms']
        syllable_order = get_syllable_order(sample_one_song)
        if syllable_order is not None:
            syllable_orders.append(syllable_order)
        else:
            syllable_orders.append([])  # In case of a parsing error, append an empty array

    # Map the syllable orders to unique characters
    syllable_orders_mapped, label_to_char = map_labels_to_characters(syllable_orders)

    # Add new columns for both the raw syllable orders and the mapped syllable orders
    organized_data_frame['syllable_order'] = syllable_orders
    organized_data_frame['mapped_syllable_order'] = syllable_orders_mapped
    
    return organized_data_frame, label_to_char

# Assuming you've already loaded the data and updated the table
organized_data_frame = make_table(decoder_dataframe, subdirectory_dates)

# Now find and map syllable orders for each song in the organized_data_frame
organized_data_frame_with_orders, label_to_char = find_mapped_syllable_orders(organized_data_frame)

# Output the first few rows with both syllable orders and mapped syllable orders
# Output only the 'syllable_order' and 'mapped_syllable_order' columns
print(organized_data_frame_with_orders[['syllable_order', 'mapped_syllable_order']])

print("Label-to-character mapping:", label_to_char)

# Output only the 'syllable_order' and 'mapped_syllable_order' columns
print(organized_data_frame_with_orders[['syllable_order', 'mapped_syllable_order']].head(2))
print("Label-to-character mapping:", label_to_char)
# Out:
# First rows of organized_data_frame with updated dates:                                 file_name  song_present  \
# 0   USA5326_45324.28882476_2_2_8_1_22.wav          True
# 1  USA5326_45324.34642642_2_2_9_37_22.wav          True
# 2   USA5326_45324.34922587_2_2_9_42_2.wav          True
#
#                           syllable_onsets_offsets_ms  \
# 0  {'35': [[0.0, 83.65079365079366]], '31': [[83....
# 1  {'31': [[0.0, 32.38095238095238], [1443.650793...
# 2  {'32': [[0.0, 129.52380952380952]], '30': [[12...
#
#                     syllable_onsets_offsets_timebins Animal ID        Date  \
# 0  {'35': [[0.0, 31]], '31': [[31.0, 72], [112.0,...   USA5326  02.02.2024
# 1  {'31': [[0.0, 12], [535.0, 579], [608.0, 643],...   USA5326  02.02.2024
# 2  {'32': [[0.0, 48]], '30': [[47.99999999999999,...   USA5326  02.02.2024
#
#   Hour Minute Second
# 0   08     01     22
# 1   09     37     22
# 2   09     42     02
#                                          syllable_order  \
# 0     [35, 31, 26, 25, 32, 15, 26, 32, 33, 29, 33, 3...
# 1                  [31, 26, 31, 26, 31, 26, 31, 26, 32]
# 2     [32, 30, 27, 30, 27, 30, 27, 30, 27, 30, 28, 2...
# 3                                [10, 11, 7, 1, 31, 23]
# 4     [34, 16, 13, 16, 13, 34, 33, 29, 3, 8, 12, 35,...
# ...                                                 ...
# 8002               [32, 35, 16, 32, 16, 32, 16, 32, 16]
# 8003    [32, 0, 26, 33, 27, 33, 27, 32, 33, 26, 25, 26]
# 8004  [32, 15, 9, 15, 9, 15, 9, 13, 6, 10, 11, 7, 1,...
# 8005  [32, 28, 34, 17, 28, 28, 13, 22, 28, 34, 35, 3...
# 8006                                [28, 17, 28, 32, 2]
#
#           mapped_syllable_order
# 0           dZTSaHTabWbZTTZTZZT
# 1                     ZTZTZTZTa
# 2          aYUYUYUYUYVTPTSZSOZS
# 3                        CDhBZQ
# 4                cIFIFcbWXiEdVG
# ...                         ...
# 8002                  adIaIaIaI
# 8003               aATbUbUabTST
# 8004           aHjHjHjFgCDhBQiY
# 8005  aVcJVVFPVcdYVJaHaFbVaVTaV
# 8006                      VJVaM
#
# [8007 rows x 2 columns]
# Label-to-character mapping: {'0': 'A', '1': 'B', '10': 'C', '11': 'D', '12': 'E', '13': 'F', '14': 'G', '15': 'H', '16': 'I', '17': 'J', '18': 'K', '19': 'L', '2': 'M', '20': 'N', '21': 'O', '22': 'P', '23': 'Q', '24': 'R', '25': 'S', '26': 'T', '27': 'U', '28': 'V', '29': 'W', '3': 'X', '30': 'Y', '31': 'Z', '32': 'a', '33': 'b', '34': 'c', '35': 'd', '4': 'e', '5': 'f', '6': 'g', '7': 'h', '8': 'i', '9': 'j'}
#                                       syllable_order mapped_syllable_order
# 0  [35, 31, 26, 25, 32, 15, 26, 32, 33, 29, 33, 3...   dZTSaHTabWbZTTZTZZT
# 1               [31, 26, 31, 26, 31, 26, 31, 26, 32]             ZTZTZTZTa
# Label-to-character mapping: {'0': 'A', '1': 'B', '10': 'C', '11': 'D', '12': 'E', '13': 'F', '14': 'G', '15': 'H', '16': 'I', '17': 'J', '18': 'K', '19': 'L', '2': 'M', '20': 'N', '21': 'O', '22': 'P', '23': 'Q', '24': 'R', '25': 'S', '26': 'T', '27': 'U', '28': 'V', '29': 'W', '3': 'X', '30': 'Y', '31': 'Z', '32': 'a', '33': 'b', '34': 'c', '35': 'd', '4': 'e', '5': 'f', '6': 'g', '7': 'h', '8': 'i', '9': 'j'}

# %% [markdown]
# ## Now, sort the data by into different groups (e.g. by days, by pre vs. post lesion group), then export them into .mat files

# %% [markdown]
# ### Test: Get all the arrays from one day of recording:

# %%
# import pandas as pd

# # Filter the DataFrame for the first day of recording
# def get_first_day_songs(organized_data_frame):
#     # Find the first day of recording
#     first_day = organized_data_frame['Date'].min()
    
#     # Filter the DataFrame for the first day
#     first_day_data = organized_data_frame[organized_data_frame['Date'] == first_day]
    
#     return first_day_data

# # Generate a 1xN cell array where each cell contains the mapped syllable order for the first day
# def generate_first_day_cell_array(organized_data_frame):
#     # Get the filtered data for the first day
#     first_day_data = get_first_day_songs(organized_data_frame)
    
#     # Extract the mapped syllable orders into a list (which acts as a cell array)
#     mapped_syllable_orders = first_day_data['mapped_syllable_order'].tolist()
    
#     # Create a 1xN cell array (as a list of lists for flexibility)
#     cell_array = [mapped_syllable_orders]
    
#     return cell_array

# # Assuming organized_data_frame_with_orders contains the data
# first_day_cell_array = generate_first_day_cell_array(organized_data_frame_with_orders)

# # Output the result
# print("1xN cell array of mapped syllable orders for the first day of recording:")
# print(first_day_cell_array)

# %% [markdown]
# ### Get the syllable string arrays from each day of recording

# %%
# import pandas as pd

# # Function to get the unique dates in the DataFrame
# def get_unique_dates(organized_data_frame):
#     return sorted(organized_data_frame['Date'].unique())

# # Function to generate a cell array for each day of recording
# def generate_cell_arrays_for_each_day(organized_data_frame):
#     # Get all unique dates
#     unique_dates = get_unique_dates(organized_data_frame)
    
#     # Iterate through each unique date
#     for date in unique_dates:
#         # Filter the DataFrame for the current date
#         day_data = organized_data_frame[organized_data_frame['Date'] == date]
        
#         # Extract the mapped syllable orders into a list (which acts as a cell array)
#         mapped_syllable_orders = day_data['mapped_syllable_order'].tolist()
        
#         # Create a 1xN cell array (as a list of lists for flexibility)
#         cell_array = [mapped_syllable_orders]
        
#         # Print the date and the corresponding cell array
#         print(f"Recording Date: {date}")
#         print("1xN cell array of mapped syllable orders for the day:")
#         print(cell_array)
#         print("\n")

# # Assuming organized_data_frame_with_orders contains the data
# generate_cell_arrays_for_each_day(organized_data_frame_with_orders)
# Out:
# Recording Date: 01.19.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aOU', 'T', 'gF', 'adIdcbHaHaHa', 'BV', 'aVaVaVaVaVaVIVIVa', 'aTZTZTZTZTbTaVa', 'adIaIaIdUdUdUdHFbWbVPa', 'PJ', 'aabdaMaHWHWHWHPab', 'aIHbdbd', 'aOdadaU', 'aTZTOPaTZTZ', 'MJVIdcdYWYdHFbWb', 'aNONOU', 'CQDhCDhB', 'aOUPVPVPVP', 'aTZTZTZIdcbWbPSPSPSPSaTZ', 'dIdcdcdcdbWXi', 'aXNPY', 'aTZTZTZPTOaZTZa', 'aGPaCVa', 'T', 'Va', 'YO', 'abdbdbddaSZHbd', 'adadadadbdbdbdbdbdbdIPa', 'agM', 'aVPghVAC', 'geB', 'aUOY', 'adbdbdbdZdZaZSbFHaYdbdb', 'aTcdcIWbWbWHadI', 'aOdUdaU', 'aCVPada', 'baOdaU', 'HUdUaUadadUONONOaY', 'T', 'daIaVPad', 'aFIdcdcdcbWXNdI', 'VaPUO', 'aOU', 'aOUZaU']]
#
#
# Recording Date: 01.20.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aFbWbPSadI', 'aaYXdiWjHFWV', 'CfLKLKLKLKLKLKLKLKLE', 'aYUO', 'adPYVaVij', 'aCDhHFdbWbVBQEh', 'VadYdJcVdcF', 'abHFTPTFbW', 'aDPhahC', 'dbWbTVZBHZQ', 'adcdWdWdWbWIWaHadWIWFIFIFIbWbPI', 'aZTZTZIcbWYOPZTZT', 'IabWbdI', 'aXYadbaY', 'aadTIZbWbTZTZQ', 'adbJYVdcPRYcFbWbJV', 'VGhRYCODhaA', 'aZTZTZTZTZIPZTa', 'a', 'aaPVaVaVabVPP', 'aPZTPTZTSZSZTZT', 'aYUO', 'a', 'aYDhC', 'aYiEFGUNO', 'bISaYbWXYNKLKLKLKLKLKLKLKLEdQ', 'aVWbWXNUFJVdI', 'aSaSdSdaIHdbWbIaBa', 'abWXHF', 'aPFa', 'aYPij', 'aFbWVXijdFgadeI', 'aDVhaCA', 'aYPUVPO', 'addbcTdFcVFaFa', 'aUaUOdUdUdaUa', 'abddbdIaIYcIdcabababababababWbHa', 'aIdbWbPVQ', 'aTPTZTSZSZZTZTZTZ', 'abWbWbVaVaVaUVUdbdbdPdUdOiCID', 'aGPGP', 'aUO', 'aTPZTPaZTZTZ', 'bd', 'VJdVcFa', 'dIUIYcdIHFbWb', 'bTWbWXNKLKLKLKLKLKLKLKLZETQZTIaH', 'T', 'ZaZaUcXaTSadTaPZSZTPZTPZSHaWbaW', 'I', 'UdUO', 'aTPZTZTZTZTZTZ', 'FWYiZTjijijHjHjHjHjZTIZUdcab', 'QMEMEMEMEMJVdaIaIaEME', 'aiIjdPcbWX', 'aVVJVPaIad', 'adULKLKLKLKLKLKLaKLKLKULKLEGO', 'TZZTZdbdbTZTZTZT', 'CfLKLKLKLKLKLKLEG', 'aQYghaCYDhBj', 'adIdcdcdbdbdcJUbWaYXdiLKLKLKLKLKLKLEF', 'd', 'adIaIaI', 'aIdFIFbFIdcbWbF', 'VabWYadYWXiDgIh', 'aaTdIdaVP', 'ajYPVPVi', 'WdbWXaiIjFW', 'VTZTZbdbdbdbdPabdbdIbWbaJTZTZ', 'VcJdVcFa', 'ajYPVPVPVPi', 'abWbTSTVBSZH', 'VabWXYadNIgCdaDhAd', 'aTZdbdbdbPZTZ', 'ZbTPTPTPZSISISZbIbWabW', 'aQTHbWbWZbTPTZ', 'aTPFPTaFbTZTV', 'abdZbTaITZSTad', 'aIFIFYcYcbYdWXibdj', 'TTZZTaITdadbWaZYJOTZaZTZ', 'aYij', 'aVdbdbdbdJ', 'MJV', 'abWXPVdPVPdcdcdZQaWHWH', 'aIbWbWbZad', 'aVIdadabaYFEO', 'acdcdcF', 'aYXNFaIFdcdcdcdcaWaWaWHFbWbWbjijij', 'daYKLKLKLKLKLKEUaUGO', 'TIdcVdVbIHWHbWbPZTaPTPZSTPZSada', 'ARFPGgA', 'aYj', 'TPTPVPVIZTPT', 'aaFIYcdcdbYWVYObdVTPITPTPSYZS', 'aTZTPZTdadaZdZTZ', 'abWPXNadTUdWIWIWIWIWIWIWIWI', 'adPVPdZcdcdZddaHZbWdbb']]
#
#
# Recording Date: 01.21.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aXGhRYNaYFghghCDA', 'aYOPTPTPTSZSZSZS', 'aIaUaUdOadaVTad', 'aPZTPZTPZdZZVITaZTZT', 'aUKLKLKLKLKLKLKLEhECODhB', 'aPDaC', 'ChAD', 'aTZTTZZTZTZTZ', 'aUO', 'daZTZaTTZaTZTZ', 'ajgYhCDhiB', 'aOUaU', 'aTUTUTUTUbdbdTdTdTbdbdbTVPbSTSbSTa', 'TZaTPZTZQdT', 'a', 'abSTTSTZTaHWabW', 'a', 'aDPC', 'gjC', 'aITFbWXad', 'acM', 'A', 'aZTZaTZTZTPZSZQdIaIaIJTaT', 'TPTPTTbTbTbZbT', 'aZbTTaTaT', 'aPDhaCCA', 'aXYNghAbGhWR', 'aPTPTPZSZSbabZTZT', 'adUaUO', 'aijijijijUPVPO', 'aijigYC', 'a', 'aIFcYdXcJcJcbWTXaNOd', 'aUOZTP', 'aYji', 'aTPZTZPZTTSZSZSaZSZSZTZTZTZ', 'aijijJPJPY', 'aPTVPaZdZT', 'aFbWbWbdJbPVbVbVBQIEhA', 'IbIb', 'Td', 'aOabWbUWbWbaU', 'aUaUaUVUO', 'aPaTZTPTSTS', 'aPDC', 'aTaDhCECa', 'ZZaZTZSZSZSTZSZTZTZT', 'aHdaTdTadUOTZTZTZa', 'aZTPUTOUO', 'aOfUKLKLKLKLKLKLKLKLKLKLE', 'YIUdUFdcdVbVFVbFHWFbWbT', 'ZWbVTTaPTPSZQHWHaWFb', 'aDAPhgaeCaCLKLKLKLKLKLKLKLKLELEQ', 'aijYaY', 'AARbWbG', 'aIFIbWYXdN', 'aZTPZTPadQaYbWbTbZTP', 'VVdcbWaXaSTSTSNPI', 'aaYIdFcdcdcbWXiY', 'abdaTaVaVa', 'aITaWYdXUdUdUdNbdbdbKLKLKLKLKLKLKLdKLKE']]
#
#
# Recording Date: 01.22.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aIadbWaWabWPXNOVZVZTPTPZTPTPT', 'hDhAGhAhRC', 'abTbdTVa', 'MJVTI', 'aYUOVPa', 'TZTUPTO', 'aPTZTVT', 'aWbJTZHb', 'aYiTjZHa', 'ZdbdbdbdbdZTaPaZTPZTZa', 'aFJa', 'aYbNWLKLKLKLKLKLKLYKEX', 'aiXNVLfLfLKLKLKLKLKLKaLKLEjY', 'DCDCDhAF', 'aIdIdIadbWbdTPTadI', 'aTbTVPTPPa', 'aGhRUiajgUhCDANONO', 'aTdb', 'MghghghCDhBQ', 'aYgCKLKLKLKLKLKLKLKLKLKLELEj', 'aPaMPa', 'aTOZaTZTSTaZY', 'aYcF', 'bIFbWXNOd', 'ajiY', 'aijgY', 'abWdbbdI', 'aJVMI', 'aGAhARPDThPCCDA', 'QOJOZTPTPZSZESZSZSZB', 'VaJYVaRcbWIFiVajVYEcYcF', 'aPYj', 'MJVdMTa', 'aJVcF', 'abababdadadababdVhITbWAbWbPTa', 'aaVaVaVHbTWbZVTTZTZaT', 'abSTPTZHWHWFbW', 'VVacJVdcFa', 'aVgCaDhYjij', 'aPYaYj', 'T', 'aTC', 'ZbTTSPTTSTSZHFbW', 'abdbdId', 'aXNLKLKLKLKLKLdKLKLKLKLEcGdcAGbWY', 'abWXSNOZVaVaTHPTF', 'aZQZETJZTZTZT', 'aPbdbdbdbdISPad', 'hCDhBQ', 'hQDhaCCDhhB', 'FPVQbFTbTTVbTPTTPTPV', 'aTTPTaPZTZIbWbTZTZPTZTa', 'abdbdIdadFbWbadaTTPVdadbd', 'aTZT', 'abZTPTPZTPZTbdba', 'aBQPTPIFPdcadcdWHaHaHaEZTCZDTh', 'ddbWbVTI', 'hDhBCQ', 'VSaHTbTbaaT', 'abWbZTTZZTaZaH', 'Vb', 'aVPaZa', 'aWbTYb', 'abObIbYTdTdTdUaadbOdOdUbdbObdbd', 'aaUOTaU', 'aZTTaTZTZa', 'bPPVPVPTVPPZTPZTUPdZZdZdITTFIacbWZUOTVRIXIbF', 'ZZTZTaPTUPSbSaZUTV', 'KgMeVLKLKLKLKLKLKLKLKLKLKEG', 'aJVYPM', 'adbdbdbdbdbdbIFabWbYdadadaTbUbUbdbdbdbdbdbdbdb', 'aYIdbWbVTPTPT', 'abWbYVaTPTYUdUI', 'aYaUOVidadadfEAQadada', 'T', 'ZTZTZTZTPTPPZQFaTPTPTPVTVZTZ', 'aV', 'ahChghgDeLKLKLKLKLKLEChCDA', 'aUaGaUOIaIHa', 'T', 'VJdVacdF', 'adaYdIaIcVdHbWbdO', 'VIVFbWbWbWbFZTPTPTbTVdbdbIdFcdcaaIaIaIFE', 'VYPVPJIJjij', 'adHdbdbdbdbdbdbdb', 'aPTPTZbSVQZTZT', 'aNOUJijFaaVTaTPU', 'abQWVYXYNagYCDhB', 'aPSZaZaP', 'aTaZTPPZQHbWbaTZTa', 'dIad', 'aPPJa', 'aYJYJjJj', 'gQgahMCDhB', 'VYVOJZTPTPZTPZSZSJaj', 'adcdcF', 'aTZTZSZQUTa', 'dIbWbTPTad', 'aFIacdVcFMYgaYj', 'aZTZTZTbPTPJZTZT', 'VYNfaLJFJjJjHjHjFgX', 'PTXdPNIUPjPFbW', 'aPDhVKVKDC', 'aaUOdaBaSadSIbAaJZSAaZSU', 'aIdTbWadcYUOaTVZTZd', 'aATbUbUabTST', 'aHjHjHjFgCDhBQiY', 'aVcJVVFPVcdYVJaHaFbVaVTaV']]
#
#
# Recording Date: 01.23.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aTATATATATATAaTTATA', 'fKLKLKLKLKLKLKLKLELKL', 'NOV', 'adadaVdI', 'aVDTChB', 'TZIabWTaFaYUOZad', 'hhaha', 'aTPTZTZbTdTdTVT', 'abT', 'aTZTZTZaZ', 'a', 'VDAGARdWVWYOLKLKLKLKLKLKLKLKLEhaIC', 'bIddb', 'aEDPhAC', 'FdIPFIdYdYcdbaVaVaYVYVYdYbdb', 'aTijaFgYaY', 'PZSZSZSPTST', 'aVTVTVPVbTb', 'aaTSTSTSTSZHbWbTTZPTTabd', 'aYj', 'hbFA', 'aIdabd', 'cNVX', 'aUaVTZTPTPUTO', 'FaFAPDhWPWPBC', 'adYajTgZTZTTZa', 'aYghCAjGhAR', 'aLKLKLKLKLTSZSPDhCCDgeLKLKLK', 'bYdFbWbPYIa', 'ajdaY', 'abaIYad', 'adbdZTbZaTaZTdPTPZdZTZTZdaaZaZdTb', 'aYgij', 'VbdbVTPTPTdPTPQUaTbWUTXbTdNYbdbd', 'aUO', 'ghCDhAgGhR', 'gCDAGARbh', 'aCDhPAaPGhR', 'a', 'HJM', 'aOUVTaPTPTSTU', 'CDhCDhA', 'aDPhC', 'Aa', 'aTZTZTZTPTPTTPSZQZdEZdadadadad', 'aWYXNdadaId', 'aDPAPhCaC', 'aPTPTZQZaAGTZT', 'VOY', 'P', 'aaVbWVYOPTPTdPTPISZSZSZSZSZSZT', 'aUVTPTPTPTPZSO', 'gCDhB', 'IFbWdXNOWI', 'TZSZSZSZSZSTPTP', 'CAh', 'aGARPDhaCACDA']]
#
#
# Recording Date: 01.24.2024
# 1xN cell array of mapped syllable orders for the day:
# [['abdIFWbWbdbdbd', 'ggMhCaDhBQ', 'P', 'a', 'aUaUOUa', 'A', 'VPjY', 'aONVKLKLKLKLKLKLKLEUaaU', 'agYhM', 'aDPhaC', 'gDhBC', 'acgYCcMDhB', 'abdbdId', 'aiY', 'UaUSO', 'dI', 'aYaYaYdYdcYWYXYXdNfKLKLKLKLKLKLIKLKLE', 'dI', 'dIbWbTP', 'aZQYFghCDhijB', 'aYXNORFbWbi', 'Mg', 'VJVYFa', 'aZTZTZTZTZT', 'aZabWbTaZZTTSTSZH', 'VdJVcdFa', 'aCDhPaV', 'aYJVcF', 'bZIFbWbTZaTZTZT', 'VJVaYcF', 'adbT', 'PACDhPAAPA', 'gACGhR', 'aOYaY', 'VVaDPhAVKVKCa', 'Dh', 'aPTZPTPTZQZTZT', 'aDPhAaPadbC', 'VjJgeVLKLKLKLKLKLKLKLKLKLEiGY', 'adbdbdbdaHIHIbabdbdbdb', 'PaDgVFhUahC', 'aDPhCCA', 'aYLKLKLKLKLKLKLKLKLKEj', 'aYIdbWbbdTSPSTPSZSZS', 'aJdF', 'aTScdaIFIFIYIYIYIYcdcbWbTVPda', 'dUIadUYaddFbUWdUdbUUdTUdUdUdPTPSZSZVQ', 'OT', 'dijajYLKLKLKLKLKLKLKLKLEhEa', 'aGDhPgeLKLKCLKLKLKLKLKLKLKLE', 'VJVcFY', 'ajPYi', 'VYIdbaVUadUdUdTdTd', 'adbdbdbdbdZTPVdb', 'abdbdYbdbdbddbIFb', 'aPDhSPAaCF', 'AGhR', 'O', 'abdId', 'VJYVFa', 'F', 'abdbdbdbddbdbdIbWbVTbdbd', 'ababdbTbdbI', 'aijJPTUYUY', 'aIFVcbWbTd', 'aYFgeKLKLKLKLKLKLKLKLKLEiGjij', 'VYJVcFZRYcF', 'aOdadaUY', 'aUNO', 'FPTZSTZIFVFWHZFbWabTTaZTZT', 'agM', 'VaYPajV', 'dUTO', 'aQPDhSPaCCaDChB', 'PaPZZTUOZV', 'VadcYUYUYXNVdVUdI', 'adIFbWbT', 'dFVWbTPTPTPZSbdbdbI', 'aTDhZaBCQ', 'abdbbdbdbd', 'acbWdVYVYXUdNfKLKWLKLKLKLKLKLIELE', 'VVdVgchCaMDhVAaVGhaR', 'iNTYiX', 'aVbPTPTPaUVP', 'adYcYcdcF', 'adIaddWXNfLKLKLKLKLKLEhEhgh', 'aJVYF', 'CZQDhCDhghgeB', 'VIaYVaVFIFTbTWVUadYdOVVIWIaFaFbd', 'aITdTad', 'aIYaYcdXNfKLKLKLKLKLKLKLEdQ', 'aTaDPhBaVC', 'aDCDPhBaYWJP', 'hCDhB', 'abdbIbd', 'Yj', 'aPVbdbdbPaV', 'dIdcWXNfLKLKLKLKLKLKLKLE', 'bYbWVbWabdTaI', 'abWbcdcI', 'ajYCKLKLKLKLKLKLKLKLKLK', 'abdIFbWbTYad', 'YIUdFYdYcXNO', 'gDhCA', 'aZTTPZTZTZZTZT', 'aAFDhPSPSPSATZCGhR', 'dIdcdcYcbWXNOTV', 'UaVRUFJVO']]
#
#
# Recording Date: 01.25.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aDhPaC', 'aBQPDhCCA', 'aDAaAPhC', 'aVTV', 'aAjUJVTPTFUPTSZSZSZQEhY', 'VYPVPVj', 'aIdFIcWXNLKLKLKLKLKLKLKLKLE', 'aFaPDhAaVC', 'VJVYFa', 'aIFIYaYcdWXNOd', 'aYij', 'aIYFIbWbd', 'abdIFbdWXNfLKLKLTKdLKLKLKLKLKLKLE', 'badIFIFIFdcYbWXbbdTdN', 'aijY', 'aWbTZTZHb', 'aJVFaF', 'aIdbWbWbWbJbJbJbJbIWId', 'ChDB', 'aYgj', 'AaPaaFCPDhAWVP', 'agMFJV', 'VaMYJVMa', 'aYj', 'TAGhRaPTPTPSTZSZQZTEZZTCDh', 'hghACgFh', 'abdIPYcicicJFMgd', 'aYPj', 'aUdUdIaIFcbWXdNadYaTd', 'aZTZTaTZSZQdTZT', 'dbddIdcdcYXNbdT', 'aIdFbWbVTPTPTPT', 'gYghCaMDh', 'a', 'aPDhACGhRQRIRI', 'ajiYi', 'adbdbVTb', 'adIHIHIHIHIda', 'aTdPTPSTPZTPQb', 'aijY', 'bdbTdbdb', 'aKLKLKLKLKLKLKLKLKVZSZSZSDVhaCCDgeKLKL', 'aCPDhAaP', 'aTUbTbdT', 'aWbTSTSTZWHWb', 'abWYbdbdI', 'G', 'ATPTJTJa', 'aDPhCCA', 'hA', 'aYOVbWaU', 'CQIDhCgheB', 'aYaYIbWbUdUdUYUdUd', 'aIaIadadcbWUOVd', 'aUVO', 'abWPXNOTdTI', 'abFJVd', 'aYPUYj', 'FBPFbWXTNSaOZVTCdTdDIh', 'aYjP', 'aJVYF', 'abdbdbdbdbabd', 'aZTZTZTPZaZaZT', 'VdIdIcaaFECDhI', 'ChD', 'abdbdIFYdUNOdVbd', 'aDhVCARI', 'aYij', 'YbdIdbWbTbdbdbdbd', 'AGFRF', 'geLKLKLKLKLKLKLEGQ', 'VYJVFa', 'PadFbWXNIOV', 'adI', 'aCDhCAF', 'adIFIdcXNfLfLKLKLKLKLKLKLKLKLKLE', 'YFdcdcdcdcbWaYJYJOJOVdI', 'P', 'ddbIPdcbWbaa', 'abdIaIFcdbWaWYXdTdNTdTdTd', 'aAPJVaJFTa', 'abWXNOdI', 'abdFIFbWXNKLKLKLKLIKLKLKLEG', 'abdbdbdbdbdIFbPad', 'iE', 'aTa', 'abdbdbdbdbdbdbIYWbTUPTPdTPZSZSZSZSZQ', 'YIddFYOVa', 'aOVU', 'aiVY', 'dijaUY', 'VYJVcFRcFJV', 'ADChAGaARI', 'VJVcYcYcFY', 'AP', 'aIYFdYWdXdNfLKLKLKLKLKLKLKLKLEQ', 'VJYUVcFa', 'aUdUdUdUdUdUdUdUdbdIPFcXaiEdaTd', 'CQDhCgeB', 'aijJDVCaVadhChALKLKLKLKLKLKLKLKLEY', 'ajdaY', 'abdbZT', 'aIYdYFdcbWYO', 'VIPFcbWXWXiaJd', 'dijadUYYd', 'FddbXTdTdI', 'aPDhJPJPJPYAaACGhR', 'aVVaUOY', 'aijPY', 'aTZTZTZT', 'VJVdTcPTFY', 'aDPhaC', 'aPDhaC']]
#
#
# Recording Date: 01.26.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aVIQIPad', 'YdYdIScdcbWXiJEG', 'aNOdU', 'ajdFUaY', 'aPYj', 'abTPTPZIQWEdJ', 'aDSPhaAUCGhR', 'fX', 'aadadadaddIadYdYWXVQ', 'abdbdb', 'CDhAGhR', 'aDPC', 'aggMCDahAGhAR', 'YIddWXNV', 'aIVFcXPNaOd', 'J', 'VbWXaYV', 'aDPhACGhR', 'VYXVTScaVadbWbWbVb', 'MghCDhBZQ', 'aaCDPhJ', 'aDPhaAC', 'adYj', 'aIPFIUXSaNKLKLKLKLKLEYVQaUYTdTd', 'gECDhAgGhRMCaDhBQ', 'aVC', 'adcdcWXdNI', 'gaCDhAGhR', 'aIdFbWFaYUYUOV', 'aIdFYcbWXV', 'aYVZRYJFUO', 'FFaFWPDCDCDSPhaLCKLKLKLKLKLKLKLKLKLEG', 'h', 'aOVdadadU', 'ddXVTI', 'FDhIPFIFIFIFIFIFIdcdcWXNVaTLKLKLKLKLKLKLKLKdLKLKLELELELETdC', 'CDhCA', 'aOU', 'aFbWbTTPZTPVRHFJV', 'aNONOdU', 'dI', 'aIFbWXWXidEh', 'aIPZdZd', 'MFJVg', 'aYdIFbWUdXNOV', 'aPDhAC', 'NNONONOVRO', 'ChD', 'abdbSad', 'ajVY', 'cNXfKLKLKLKLKLKLKLEAG', 'PaIddIdcdcbWXV', 'aijTaY', 'aYZTUONONO', 'aDPhCA', 'aFIbWbTdaPTPVVI', 'aYVO', 'aJVcM', 'aababaUPab', 'aJVYcF', 'aijPaY', 'UVO', 'aIdWXVd', 'adcdcdcdcdcbWXYdNOI', 'agPeLKLKLKLKLKLKLKLKLKLKLKLKLCE', 'aNONONOU', 'hQB', 'gGhRgacghaMCDA', 'dcjdcJdaYdY', 'aObabaU', 'adUdUdUO', 'aDC', 'VYUNOa', 'aWbTSTTSTZHPTPZSZSZSZBWb', 'OV', 'FfPaC', 'aUObAUa', 'DChA', 'aYj', 'aPVZRVadFYJVj', 'aZPC', 'aQgCYDhBj', 'aOVTPTPTdaU', 'aId', 'aDPaPhC', 'aYIFbWdXYdV', 'VdFbWXNIaVPRcFJ', 'CGhRhCAD', 'aaTdUdTdTdTdOdOdOdbdbObObObObdOdOdbdbdbdIdcdcXYTYTU', 'aDhPaCBZQ', 'aNOU', 'abdbbdbd', 'abWbTZHF', 'aaTZabTbTbTbZTbabTabdbdb', 'VdaUNOaPTa', 'a', 'VOUa', 'bTZTZTZSZSZQdaZdTZTZ', 'aNONONOdU', 'aaCPDhAPCAF', 'aGhRDBPaPhaTGZaCCA', 'aTZTZTZBaSZYZjijiFjFTZTZ', 'OLKLKGOLKLKNLKLKLKLKLKLKLKLKKELKLKhLKLCKLANKLK', 'aVUTYIbWX', 'adbdbb', 'aYj', 'daZbdbIbIdTadaTZT', 'abdbdbd', 'aVaVaVaPDhZCO', 'IdIdWXV', 'aVYj', 'VXTVaHaFbW', 'aPDhaCB', 'agePBC', 'aIUYUYUYUYXNVd', 'dFIaIaIFEAGI', 'daIaI', 'aPDhACGhR', 'hDhBC', 'aDhPACGhRF', 'aijY', 'VVKLEPaDhCCfLfLKLKLKLKLKLKL', 'aOUVYaYaU', 'ChDBQhBQE', 'aTUTUTdTdIFbWXWXWXPNfaKLKLKLKLKLKLKLEQ']]
#
#
# Recording Date: 01.27.2024
# 1xN cell array of mapped syllable orders for the day:
# [['abdbIdbd', 'aOVUYUYBUYUYU', 'VJacKLKLKLKLKLKLKLKLKLEVQF', 'aYPj', 'IdIdcbWXadV', 'VYJcVF', 'aUVO', 'VIadbWbWbWIWIWIWIHbTPTd', 'aYjd', 'aZTYbWab', 'aadITSadcSTVXIXTaTaTZaZad', 'aZTadZTYbWbd', 'aYadadadPYj', 'aJcYVcFY', 'aTZTZTZTZ', 'dIdTdWVWXV', 'bIFIFbWUWUXaVRYbWbd', 'aIdadadad', 'aabdbd', 'aadIFbWXNUVUdOV', 'ZPZTTPTSZTSZZSZQTaZT', 'aIaIaIYdcXdVB', 'TITFbWXZaTNZOTVada', 'TZETZJVQcFP', 'T', 'adYdIdcdYWXYdY', 'aYPj', 'a', 'FYjcFEV', 'ChCDAGhR', 'aFgMCDhBZQ', 'abZTPYTPZSZSZSZQbJ', 'ZhaBaQTaZaZTZTdPTPTZSZQECDb', 'aYPj', 'aVaYPVVPja', 'aNONONOVRFYFbFbFU', 'aJVIPdcdcdcdcdcbWaXPSNaOVdZRYRJF', 'gDhCAGhR', 'FdPcVPFaFaFa', 'hDAC', 'aOVUaUcU', 'aaCd', 'aOdbdbObObObbdb', 'VOdVUUdU', 'aOYUYVaYU', 'UUOVVVURYFJbWUbWbbUdTWaPTYUY', 'VTdTaVaPaVb', 'dVUO', 'hfLKLKLKLKLKLKLKLEC', 'aaYj', 'aZTZSZQZTZTZT', 'aFJFIdcYj', 'aTTZTZVTaZTZaTZZTZ', 'aTadIdcdcdcdcWHWbTa', 'ZZQPZZTPZQETZCTDZhTTB', 'dIdcbWXiEhQ', 'VYJcVF', 'abFTa', 'VadbacdcdadcdXaVYIWNaVaIWIOVW', 'ZTPTZSZSZZSTZTZTZ', 'aTbYbY', 'AhRcbWbG', 'VYcJVF', 'aPZTZTTZaFZJVTBZ', 'aIddYdUYW', 'aFHFHbWFWFWaWXVH', 'aTdTdTbPadbdV', 'bbTaaTZaY', 'aVOUaUaU', 'aPa', 'gJV', 'aYVFgaCDhjBZQ', 'aCDSPJPJhDCa', 'adIdIdScScXiEgQda', 'bTTZTZaTZTa', 'TbWZXWHa', 'VYJVUFUFUFPVYRcFJV', 'VNOaVdadadU', 'aVUO', 'aPPTZa', 'FVaYijbdPdbdT', 'aITFbFbWXZdNTdTdO', 'aVYVYVYPVja', 'aIVIVIdcVXVPaZTVd', 'UVO', 'VTdVTPTZSZSZSTZSadTdb', 'aPISPZd', 'abWYXNSOVVHF', 'aYUaUdUdTUTUdbdbdIPSa', 'aVPaPa', 'VYUOYVabWa', 'aZT', 'aVUO', 'VaVDdaPhCCE', 'aYPj', 'aTPabd', 'aVUcO', 'ARGh', 'YVFbWaYXdiIEQVd', 'aYa', 'aZTYbWb', 'VPYVajVY', 'aUaUaUdbdbdaPISa', 'VaYTPZTbWb', 'aVGPGPa', 'J', 'aijY', 'aV', 'VOVYRYFbYWYVaU', 'VYVj', 'aVa', 'aIPSad', 'gDhBCQ', 'Yj', 'aJVdF', 'a', 'a', 'aYgeKLKLKLKLKLKLKLKLKLEjG', 'VaVaVYiRcbWbWbj', 'VjaUOUYaaY', 'dQIdcdcUcUbWXiCDhB', 'adbdbddZTbdbdb', 'VYJaYKLcKLKLKLKLKLKLKLEF', 'aTYbWb', 'gMEhBQhC', 'aQhgdecLKLKLKLKLKLKLKLEhMB', 'VaYaYJVcYcdcF', 'aUOVZTdPTZSdTZSZSZZQa', 'dIdcaUOJ', 'HOVbWaUaU', 'aTbY', 'abdbdPbITZaTd', 'aYPj', 'M', 'aYj', 'adcIWIWddcdcbIaWaIaadEICDhBQ', 'ZbaTYPTbWbW', 'aPUaUYj', 'VOVRcbWbWTbUaUaUaUaUa', 'aTdTIdbWVWXNV', 'O']]
#
#
# Recording Date: 01.28.2024
# 1xN cell array of mapped syllable orders for the day:
# [['bbWbdTaI', 'hCDhBQ', 'adbdbdTPZQadaIb', 'adOdcdcbWXI', 'VJcLKLKLKLKLKLKLKLKLEFQY', 'YgFjMP', 'WGhRdcdcbWVXWdVUdiWVEIhYCA', 'DCDhBhQ', 'AGhR', 'aVUO', 'aYajdaV', 'adcdcdcF', 'aWbTIHb', 'aZSZSZTZZSSZQZISZS', 'VdcbWbdTPTZaSTZaHI', 'aTZTZTabdbdbdbdb', 'TTTPTPSZSZZQabdbdTIFVFUYcWIZWIWVXdNLKLKLKLKLKLKLKLEZ', 'daIaIdcdcbWXV', 'VacNLKLKLKbLKLWKLKLKLKEYX', 'VVbWVWVWXFbVbVdaINVVFaFdYXRabWbTPTPSZSZSZQ', 'MJgLKLKLKLKLKLKLKLKLEQ', 'gFJV', 'aFNdVcbWXdVTadadI', 'VVbdWdXdVbadZIQIdcdcbHIHIHIHEMEMEMEMEMEadJa', 'hDhBCQE', 'aBZQadbcdbdaWIFIFEadhCIDh', 'bdcbWbdYdYTPUTYdIY', 'PTPPTVaIabWdXbXaNdOV', 'VJcVFY', 'adITbWVXZIHa', 'VJVFaUOVY', 'VJVcFY', 'aDPhaCC', 'UWIdbWXNYijUPUdI', 'VaJOVUaUaUYO', 'aIdYUYUYUbYWUFWXdNOVY', 'dbdbadIFIdYcScbWXNOdV', 'TbUWIdTUaTWXVaTTUd', 'aYDVPhCagPeC', 'UUPYVPYUjY', 'adScScYWVWXTVVadI', 'abWXdVcdBZQIEOVT', 'VYVYJFKLKLKLKLKLKLKLKE', 'dQOEhaAGhRdagUeB', 'adcdcScddcdcdbWaWEICDhA', 'hEGC', 'adaIaIaIaI', 'aQEhIBQdcaEdCDhB', 'ghOV', 'aVcbWYX', 'aQdEZTOZTZSTZQETCZDThZB', 'YIdYddbWYWYWYWYUWUXVJYJYdYJFJV', 'dPTTbTb', 'adCDIhAGhRbWXdiYdEGIQEa', 'aFbWbTSTZHYa', 'aGPdIdaVPa', 'ChCDADGhR', 'abWXYdNUOVdYI', 'YdIFcabWXNOV', 'VdbdbddUTVbdbdbdTdTbTbTUbbTbTbUOXbObdbdbdb', 'YbdYdYdYTdVbVYRYJFJFJdVZRFYdJ', 'VJcYcVRFcbWijY', 'aAVaPDhCCD', 'ddcdacbWdadXVI', 'dbWbadY', 'VYFbWYUONONONOcdcdcdadadaIa', 'aYUO', 'VYaTYaYabWb', 'ECDhBZQ', 'VYVaYaVaVaj', 'aadTbZTZTZZd', 'adcdcbWAgUYUXaUaVTI', 'aJYVdYdcF', 'ZbaTTSdSdHVZRYRFJVbFbW', 'aYIdaIaFbdbaUTO', 'gVdcJgYcYeKLKLKLKLKLKLcKLKLKLELEj', 'VVYj', 'abdTda', 'aTd', 'VFdSdSdSdScdcdcbWaXdadaId', 'aId', 'aHFbWPbTaZTZSZQTZTa', 'MJV', 'VgcJMVa', 'aUOY', 'bdbdbdbaT', 'VacJVFdTZVSOVRcbcFJFJ', 'abYTaYaYTad', 'aPDhCCEG', 'FaPFIacVXaNdOV', 'VYaYbWaYWXdUdUdUNYKLKLVKLKaLKLEUdQI', 'aadbdbV', 'gDhAGhRCIF', 'IVcVdcdbWXVIaIaIa', 'abWbTTPTPTaPTPIZRbHFjPW', 'adbdbdTdbdbdTbTdTdIFIUdcdcbWVWXVRYFbFbWbTPZSZSZSZSTZdSZQT', 'aVYPTPVZVZVWRbFJVVaVaj', 'gKLKLKLKLKLKLKLKLKLKLEGe', 'aSZTQZTZSZa', 'gJV', 'YVaaaYaYdUdI', 'VYPj', 'aDhPOaC', 'NVdYXaXW', 'aIdaddYWXd']]
#
#
# Recording Date: 01.29.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aVeVeVeVYPVHIbWXNgejB', 'aJVYcF', 'aPVYaYCj', 'aC', 'aPYj', 'adcVUWX', 'ZbWbZTTVZTZTTZH', 'adIdbWXV', 'hCgeLKLKLKLKLKLKLKLKLKLE', 'dbIcVdVYVYXV', 'aPDhAaGhRC', 'adIdcbWXNKLKLKLKLKLKLEG', 'aPJa', 'aYNKLKLKLKLKLKLKLEJVbWYWYX', 'aYbIddcdcaFEOV', 'aabWXdaI', 'VdcPVF', 'abWXTdI', 'hGhRQRQRAbA', 'a', 'gFJV', 'aPYaIFIij', 'VPjY', 'aTZHWb', 'MFJLKLKLKLKLKLKLKLKLEhgAGghghR', 'geLKLKLKLKLKLKLKLKLKLKLEQ', 'FYbdaIaIaIUFdIdcYXa', 'aFIFIdcdbWdXNfLKLKLKLKLKLKLEIQ', 'aIVIdcbWXYdVbWaZT', 'VJVcPRcbWbiJiFEMEMEFJY', 'VaVFdcScScdcWFIHdWbWFJVI', 'ZaSZTSZSZSZZQTZTZTZ', 'ChAGhRD', 'aZaIdaWXVd', 'VTPVYRcUcbWiEFJbVWbY', 'aFYFj', 'VJbVWXYcYcYcYNdYdYfcILKLKLKLKLKLKLKLKLKLKLKLKLKLKLKEGAQE', 'aQPIYdYdYdcdYIWYHFbadYdYWXjNfKLKLKLKLKLKLE', 'aVIPad', 'VaJVTYPTaYij', 'aYijJEMCDhj', 'VYPIaIaFJVij', 'aTIZdcddJcJbJbJWagCD', 'aPIcbWXaNOdV', 'aDZTThZCCAGRVFVF', 'VYPj', 'aTZRIbWaUObWVbY', 'aVUYUNONO', 'aZTcdcdcdcdcdcbWb', 'aFIYcVbWXaNVYbaWbITPJQ', 'VIaIaIaIHIWFWFWFJYVcRcbWbIaaVIaIaa', 'aacXVTHbW', 'aFYiYj', 'a', 'aIdbWbXVd', 'aVYadcYdcadbWXI', 'aUYUO', 'aAGhRIPdcIFEThZCTDZhd', 'CGARDhCA', 'aIddaScbWbXV', 'VTaYPZQbYb', 'P', 'aIFbWXNKLKLKLKLKLKLKLKLdEV', 'aYPj', 'P', 'aFcVVdVcPbWXNadI', 'aPYj', 'ahPBDhCCD', 'hAGARFjP', 'GI', 'adcdcF', 'aXYNOVi', 'ZdbZTdYdPbdb', 'VKLKLKLKLKLEQOVaYZRFbWXjNfLfLKL', 'aCdXN', 'ahBQEODPhCCE', 'abaTTSTSTSVZKTZPQHbWZ', 'XdYdYdZTZTIaIaIaIdaScObYVUUYbWbTT', 'VQFFbWXNIOIVRFJVdG', 'AGgARFbWb', 'hCEFEJV', 'aUaUOYVbWa', 'gDhAGARARFC', 'aPC', 'aZSZSZQTaTSEZJSZS', 'YVO', 'aPYWaHaHWIWIFbWXdYNOjQE', 'BEMEMFQ', 'VaJcVdcF', 'ZQZEGSTZSZSZSZZSZSZQTEQEZThZSB', 'adadbWYX', 'ZYTVPVbWba', 'dbcbTPFbFIHdWH', 'gOhREAGQIdICDhBAQE', 'VPdcdIbWXNjOVY', 'VbWXNYUOIVYRYFjP', 'aaFEdadSJdcVdcRYJcJbFdcJVW', 'adcbWXWXdVTcRcFWIJ', 'VPYVPVZRFaJVj', 'addcdcdIaFI', 'ChAGhARFJD', 'VjPVRcFJVVFWbTOcaYJRcbWJVVcYcFX', 'aYFYjJV', 'aaZTZTZTTZTZHIbWbWIZTQadI', 'gDhCAGghR', 'aIFIFIbWXVUNOVYcbWd', 'VYPVPVRFbJVj', 'dOJaU', 'VYPVPVj', 'aIcbWdXNfKLKLKLKLKLE', 'aYOVZTZSZSZSj', 'adcSbVCdTZdZdZI', 'aVITVdcdcScObOdVbVb', 'acFJVaaVRYRYRYRcbWYijREMEMEJ', 'aPZdTZTZSZHbWbYZTZTjZPcdcdVdVdaQ', 'aBZQIdFcdcIWJMghCDh', 'aOJOVdU', 'ajTgZaedLKLKLaKLKLKLKLKLKLEYG', 'aVUO', 'hBQEG', 'TTIdZcbWXVTZSaTZZd', 'VdSScVdcdcO', 'aJXcNVaPVRcFYadJVcdPVQWE', 'adJVcdZTcF', 'aQECDhgBQMCDEhB', 'aVYj', 'aXNYObW', 'ChAGhRD', 'CDhAGhR', 'TITcbWZXTijdPVSZ', 'aYJiaUaUOUVY', 'BQ', 'ahCDYhBQEGiEbWAGQXE', 'YJVcRFcbWbYbYbYiEJ', 'hgACeLKLKLKLKLKLKLKLKLEQ', 'aQQSbWbaTTaPTPTZTPRIZcbWbiSJEZ', 'TZITFdcdcdcZWbJd', 'aFbWXdNadaOVIRbWbTVT', 'aNLKLYKLKLKLKLKLEbWX', 'hAGAhRFJVC', 'AGhARFJV', 'VdYdVadYcFdcJVbWIbWVWYXUNVWX', 'aUVadIFbWbXdNVdVdUVUVUV', 'VJVJVYBja']]
#
#
# Recording Date: 01.30.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aYPTZTPVZRbcbFJVj', 'VJVacF', 'chAZdZGhRTEZhdTZBTQZZEdQ', 'hDhBZQC', 'T', 'aPSaC', 'QhCDhAEQEGhGhRAG', 'VaJVdYdYdWRbWbFTPVPVRFJV', 'aTabWbY', 'S', 'aZZSTZSZSZZQTZTZS', 'aYaYj', 'hDhBQC', 'agYhCDhABjQ', 'aYNXPWYX', 'daIFIbVYdbWVWVWXWXdT', 'VaYaYJVGZSZQj', 'ZTZHTabWbZTZTZaTZ', 'dIdcdcdSVWHWHWHWHWHWHaFEFJ', 'adadIFIFdcdcYVWXNKLKLKLKLKLKLKLKEQ', 'VJYaYcLKFLKLKLKLKLKLKLKLEQa', 'dUVdJFJFJFJLKLKLKLKLKLKLKLEQ', 'aYZTPZRYcFbJVWb', 'aYVj', 'aIdbbdb', 'dIdcbWX', 'aQbWUXigYeLKLKLKLKLKLKLEGJ', 'aYJj', 'aEaEPOVQ', 'abWaYaUJdaI', 'aPVYaYj', 'IdIFIdcdcdcdcdcbWXNfLKLKLKLKLKLKLKaLKLELE', 'bTdbdTbO', 'adadadadYj', 'dIVIVIYcdcdbWXV', 'ZTZaIZdcbWaWaYWYWXTVZTTZTZ', 'aYVZTPTPZSZTSZQj', 'aPYj', 'aIFbWXNVd', 'adcbWXVUVUaVVadI', 'VYJPZTcFa', 'dIdUbWXNONONLKLKLKLKLKLKLKLKLKLEQ', 'TZTZT', 'CDAGhR', 'VOYVURbWbdJaiaUa', 'aGhRYbNXNgWCYDhAX', 'VUJVYaj', 'adIdcdcbWXNOWVYZRbcFJdI', 'ZaTYPTZVbVdVRJFbWb', 'aYVaTj', 'VPdYVaj', 'ahDhYaYUCCDA', 'abdIdb', 'VYPVPj', 'VcNdcOVbaWX', 'T', 'AG', 'aTZSTZHZbTZT', 'OV', 'gDChARb', 'TTaIaFdaZTaZZdZd', 'UVUZTVUPVZRYcJFaJUVaO', 'aadSZHabWbTZTabab', 'aQEghBDPhSaSCCDhB', 'ggMCDhBcQE', 'aGgCMDhBQE', 'aVYFIFIHIaIFIFIFj', 'ITZQZaTEJVZQTZTZ', 'bTZPVZVZVRbcdcdcdcdcTdFJZVTZT', 'aYaYj', 'aUVaO', 'aUYUOJVdcdcdcbW', 'aTZTaHbWbTZTZTZTZ', 'aUVO', 'ggMCDhBQVa', 'aSPDhaAC', 'gDhChBZQ', 'aYaYj', 'OZQV', 'dIdcdcFMgeKLKLKLKLKLKLKLKLE', 'VYVRcbWiEQja', 'abIaIdcVcaHaHaHFbWXdaNKLKLKdLKLKLKLKLKLE', 'YFj', 'aFbWYXYNVKLKLKLKLKdLKLYKLEUQdUdI', 'abWbZSTZTZH', 'aJbJYJbJVTSZdc', 'aTYPTPVZRFjaYbWb', 'ThTTZPTPVZRaYcbFJdadVZRbWabiE', 'aIdFbWXNKLKLKLKLKLKLKLEV', 'CDhBQ', 'aIIUFIcdcbWdXNLKLKLKLKLKLKLE', 'aVIdcdcddcbWbWXWXNOUdUdVTd', 'aZOdTVZTZTZT', 'EQZEQGIZaEITZaTCECZDahITaZBT', 'ahPDahCCD', 'gDhACGhR', 'aHaHaHaHaFESJcVa', 'aBZQXcNgdCcdcDdchUW', 'ZZEbWbTZTZTZQT', 'geVLKLKLKLKLKLKLKLKLKLEG', 'ggMeBeBeBQY', 'ZZVTZTZTTO', 'CDhBQEa', 'aTdVOU', 'TbWbTTZTZHZ', 'OhBQRcbWbTPTPZSZSZSZSZQEV', 'gKLKLKLKLKLKLKLKLEGZSZSZTe', 'aGhRJgYhCDjA', 'aTPZTYbWb', 'aFYPj', 'dTZaTZTZTZdYIUdZTZ', 'h', 'TdaIZ', 'VZTdPTPTaPdaTdaPaZRbWbWbTPTdad', 'abdbIASFIdcdcbWXTSTGNdOUTWd', 'aJdVcdcaHFaFF', 'IdIdcdbWXij', 'DCAGhRhFIFIF', 'BQEhAGhR', 'baZTSZHbdadTadP', 'dabdaaIddadScaYXVd', 'aUVO', 'MgCDhAGhR', 'aUaUaUUaO', 'ajadYcYd', 'aFjY', 'aPTFTJVZaZRaYcTbWiZVFVTEQ', 'ZTaYbWb', 'CDhAGWAR', 'SJEQFbWbWbTZTZaZTYZTRSabJFJVTZRaZacbWiH', 'aTSZQZTEZTZTZTZS', 'IIddcdbWXa', 'TZTTPaZcdFZJVTZZT', 'aZbWbTTZTZH', 'VYPJPIHIHj', 'VaVaYVj', 'VHaHaHaHFJVcdcaHa', 'aITFbWdadaXdNiKLKLKLKLKLKLKLKEVFQ', 'aQdbWSXdaSdNgSdcCDhdScdBI', 'aXiXdVcdcdcdcdUcUbW', 'gDChA', 'aijUJPO', 'abWXVdaTI', 'CDhBQ', 'VJVcFY', 'daTZH', 'ChBQD', 'ggahghghMAGhQRQR', 'aTPZTZTZT', 'aIdadFaYUO', 'CDhBQ', 'ajY', 'dIUdYdYFIFVScScbWXNLKLKLKLKLKLKLKLEQ', 'aYPIdcbWXNOjijVRJF', 'DAGhARQRQRFh', 'aYVdYdYdYdYdYdYdcdcYj', 'TbWbWbWbTZTTPaYRZFIZ', 'aIbdFIFIFUSdSdSdScSUIUIUcUcIbIbWbWbWabVWVbHbdT', 'VJVcaJF', 'ZGhRabWbZTTPTPZSTSZQZETZhHAT', 'VZRcFjOPYPVOVTaVUPTZVRYcFJV', 'aVZTbTVjVYBQENO', 'gDhBCQ', 'gJV', 'UVO', 'gagMDCDhBZQ', 'aXYNLKLKLKLKLKLKLKLKEGWAGbUY', 'ZaZTZTZTZaZT', 'ZTZTZTZT', 'CDhBQE', 'IdaIIaIdSdZbaWa', 'ZbaWbZTTPTZTZHT', 'aZHbWXTTiZETZGQ', 'aPYj', 'aZQTdEZThZTAZGahRQRQRQRQRQRQRT', 'ZZTZTZHTZTZTZT', 'aPYj', 'VWbaTTZPVRcJHFjZVb', 'ZZSZQZaSbTTZPTVSTRYJbWbZS', 'aWXVdadcdcdcbWa', 'TTIFIYdYdYdUcbWbWTXidEZAFQEQ', 'agMCDhAGAR', 'hDACGhR', 'YbaaYaYMdgCDhA', 'gagMCDhAGhR']]
#
#
# Recording Date: 01.31.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aPDhaCC', 'abdbdbbd', 'AGhARVbF', 'aGhRdgCVDahcIcMA', 'dIFIFIFIdb', 'dIdcdcdcdcdaI', 'ZZTZTTZT', 'aTPZTPTZPZVT', 'agMj', 'aTPTPTdZaSdZSZSZSZQ', 'abWbWbTTZH', 'gcYghaMCaDhEgaG', 'bbTUTPTda', 'dcdcdcdcF', 'aVIFIFIFdbd', 'aPC', 'aPTabd', 'CDhCAJFJF', 'aIddcdcdcdcbWFEJ', 'aIddb', 'aPDhACGhR', 'aFbWXdNgIJ', 'aCaCPDTPaTZ', 'aWbZTTSaHFb', 'aDhgVPeLKLKLKLKLKCLKLKLKLKLKLKLKLELELELE', 'aZTZV', 'aaTPVaPTP', 'VYPj', 'aIFdScdcbWbd', 'UaaUdbOULKLKLKLKLKLKLKLKLKLKLE', 'abdbdbdZTZHPTabd', 'aCVKPDhaCAPGhR', 'gDChB', 'aPC', 'CHj', 'VYgJdVcadcM', 'CDhCDhB', 'aIFIPdcdcdcdcbSTPaTd', 'aC', 'YijijaVY', 'aPDhCaDCA', 'FcdcjdcPFa', 'aIUdcbWXdUNdLKLKLKLKLKLKLKLKLEG', 'IdIaIaIdTada', 'dbTPVOVRbF', 'UVaZIRcJUOF', 'aeBDPhCCDhg', 'gDhCAGhAhR', 'UO', 'agYMCDhAGhR', 'aVDhAIaIaIaGhahaQR', 'aTPSaC', 'IadIdcbWXN', 'aBQIdcVdcaaVaVEdVCaaDdh', 'ChDCDhB', 'CDhCACDhB', 'CDhBQ', 'hhCMDAGhR', 'UVRFO', 'VJVdcdcMc', 'MgCDhBQ', 'gMTgZTZaZa', 'aPaC', 'CDhCAGhAhR', 'dVdUdaHUOF', 'UVZTO', 'ahBaCDhCdD', 'aTCPDaPhaP', 'aFEFEcAJH', 'YJcLKLKLKdLKLKLcKLKLKLKEdcFF', 'ChKLKLKLKLKLKLKLKLKLKLED', 'Mg', 'gDhBQC', 'CDhCfKLKLKLKLKLKLKLKLKG', 'ChBDQ', 'VVYVYjY', 'a', 'ARbWb', 'MgFJFJF', 'aSZSTZSZSZQZTZTZTZ', 'aPSaC', 'ZZZTTT', 'a', 'TZOaTaTaTVUTZTZT', 'aXYNObW', 'ZZSZSZSTZSZQZaaGTZZTZS', 'aIdFIFcbWXNfKLKLKLKLKLKLKLKLEG', 'abdbdbdbdZTdadI', 'CBZQDhBQEh', 'aTZTZd', 'CDhCDA', 'TVHZFbTWbZaTZTaTa', 'aPDhCA', 'aaCDhC', 'AGhR', 'aPIFbWXiaYEUYUd', 'aLKEGdIadFIdcbWXNgeLKLKLKLKLKLKLKLK', 'aCPaCa', 'aIFdFdTSVbWbTa', 'VbTTaZVaTZTZd', 'aPC', 'agcMeLKLKLKLKLKLKLKLKLKLKLEG', 'JaVhh', 'aPOSVTPZUdbd', 'SVTTZZRTFZSjJP', 'adYdIYdYdFdcbWXiE', 'aWVWFC', 'aghCDMhBQ', 'aGDPhaCVPACGhR', 'CDhNiNX', 'YVj', 'aUVTZTPTPSZSZSZOSaQ', 'VJcKLKLKLKLKLFKLEaVY', 'aPIAPcbWYXaNfYdLKLKLKLKLKLKLKLKLE', 'AGBhR', 'aJcLKLKLKLKLKLKLKLKLEFQ', 'geLKLKLKLKLKLKLKLKLKLKLEQ', 'aPjVC', 'McFbWbgaMCDYhAGhR', 'dcdcdcadF', 'aAPbVadadadC', 'FIYaIaIdcIUbWXdNa', 'CDhAGhR', 'daI', 'aOdOdbdbdbIbIFIFJTSVbWHIHFdVEFJ', 'ZbdbZTUTdT', 'agFM', 'TTZdcdFZTZTZZT', 'CARhCADG', 'ZbWbaTSTTZHVZaVRZabJbZaZaZaZ', 'gFj', 'ZTZSZSZQZTEZTZhTZBSQ', 'TITFIFIdFIdcbWaUOVZ', 'aaYUdVd', 'aijdY', 'aId', 'aFPSa', 'aWPC', 'abdbTbdbdbdTdbdbdbd', 'CDhCA', 'adcbdaI', 'aGhARgcYMCDhA', 'ZSZSTZQZTZSZSZ', 'DhCAGhR', 'VYJFKLKLKLKLKLKLKLKLKLKLEAF', 'aTbWbY', 'ahBQdgcdadaCDhMCD', 'DACAGhRh', 'aPiSZC', 'VTZPZTPFRTcFaZjTdTP', 'ChJIaIDa', 'aPC', 'aId', 'TZbWbTZTZTZH', 'aYFIdcdcIcIcWcWcWFcFcbcbIWIaIaIaIaIaIdaIaIaIIFdVYXdVdVNIVaVa', 'aF', 'aVPC', 'ChBQD', 'dIFIdcdcbWXNKLKLKLKLKLKLK', 'TSZSZSZSTZSZQZETZhTZZAST', 'VJaVcF', 'aFDChCAGhR', 'CDhBQ', 'babdbdbTYTYTUdT', 'aPaZaZadTd']]
#
#
# Recording Date: 02.01.2024
# 1xN cell array of mapped syllable orders for the day:
# [['IhIddcdcbWXdighCDa', 'CFbhCDAGhR', 'VVYj', 'aFYFVa', 'agcYMFj', 'IdSZQZTEZTZhSAGhRZ', 'CDhBQ', 'aYIUFIFIcdcdcdcbdWbT', 'ARGh', 'aaIdcbWXdiEI', 'aVPa', 'I', 'aAbdSdbdbddIFIdcdcbWbWXNgCDh', 'dI', 'ARFGg', 'aaMgMhCDhAGhARbWb', 'TSZQZTEZThZBSQAZ', 'aSUOTZJVaHa', 'adZIPdcdcdcbWXada', 'aIFIdIdcbWXdNOQ', 'ChAGhRD', 'agMC', 'AhARbG', 'aTdTPZRZYFTJVZaZTZaTZ', 'a', 'gFAgCDhMAGhAR', 'hDAC', 'adcdcbWXNdI', 'agMCDhAGgARF', 'agMhCDhAGhR', 'ajYaY', 'gagMeLKLKLKLKLKLKLKLKLKLKLEGQ', 'aPTPTaC', 'Yj', 'aFHWFbWbc', 'adbdbIFdcbWXNf', 'FbTPVZRcFZTjEG', 'aPDhCCA', 'gLKLKLKLKLKLKLKLKLEe', 'UdIFaFaFaFaIaIacdcbWXNV', 'agUagMeKLKLKLKLKLKLKLKLKLKLKLEQ', 'VaYFVJaYcMLKLKLKLKLKLKLKLEQ', 'aUVO', 'ggMaeLKLKLKLKLKLKLKLKLEQ', 'adbdaPbWJbJbFUVb', 'VYVij', 'aAGAGQEhBQEIhdcddcbWXNOVZR', 'aUVO', 'FaFjYFP', 'gFCDhAGhR', 'Yj', 'aVGPGPad', 'Gh', 'CDCfLKLKLKLKLKLKLKLKLA', 'aM', 'aWaWaFPa', 'AARFG', 'hDhCBQ', 'abdbdbTTVTVTVUVUd', 'aZTZTZZTTZTZTZT', 'ChBQEDAG', 'FYcYdcbWXWNVWKLKLKLKLKLKLYKLKLEVWVWaGAI', 'CGDhAQE', 'geKLKLKLKLKLKLKLKLKE', 'adPDhCCA', 'aWFUbWbTbbWaH', 'agM', 'aAQTIadXTdNfLKLKLKLKLKLKLKLKLKEG', 'CDhACACDA', 'CDhAGhRFbWiEVG', 'aVaPSaPa', 'gAVgaaVacCMDhAGhR', 'ChBQEDhEhEhA', 'ahBZQQEGUOQE', 'adC', 'aNVPUVO', 'aUVO', 'aTZZQTEZTGZQ', 'aPaC', 'aBQEAGIdcdXdNagCdDh', 'abY', 'aQUVdRcFJFJFJOKLKLKLKLKLKLKLKLKE', 'agM', 'adSdcScbWb', 'b', 'aYIdFcbWXNOV', 'aIZdcdcbSTWXSZNVTdT', 'AGhRb', 'gCDhA', 'CDhCA', 'ZWbacTadcZRYFJcb', 'IbaIdcdcbWXTdTdNgFJ', 'aTZSZHFbWbTVZRcFTjVZaZaTa', 'gagagMeKLKLKLKLKLKLKLKLKLEG', 'aPDhC', 'VTZTZdIFdcbHaHaHaHIEbY', 'AGhRAF', 'CjV', 'VYaaVj', 'TTdZIaddcdcdT', 'aVYaTUPTPRcFOJFJb', 'CfE', 'YTcYcPYSdcbWbWb', 'gFJKLKLKLKLKLKLKLKLKLE', 'DhBZQEhEAG', 'DGChDgeBQE', 'IhRddcdcdaFaFEIhCAG', 'VYVYdIFcdcbWXijPaYV', 'agYMhCj', 'F', 'aDTZhCT', 'abIFSdSdcbWdXNXNOT', 'agcgMeLKLKLaKLKLKLKLKLKLKE', 'aPjadadC', 'aYVUO', 'VFbWbWbTTZPVZRHJFja', 'UjPVPVO', 'abdbdbdbdbd', 'aTIFIFIFdcScbWbT', 'aVCPTPaVP', 'MgCDhBQE', 'aTVYUO', 'gSZSZSZSZQDhBCQEG', 'aadcIaHaHaHadHJEVJI', 'ARGh', 'aJVM', 'ZTPZQZETh', 'FcaFTPZR', 'DhCDhLKLKLKLKLKLKLKLKLKLEG', 'TaVaITbdTV', 'aDPC', 'geLKLKLKLKLKLKLKLKLKLEG', 'hCAF', 'aTYb', 'gMgaMeKLKLKLKLKLKLKLKLEa', 'aPC', 'gehBQHaLKLKLKLKLKLKLKLKLKLKLEQGZSZSZSZQE', 'ChBQD', 'TZWbWbTTZPTRZbFTJSTVZH', 'gDC', 'aVa', 'ghCDhBQEAG', 'aPaC', 'aTPYb', 'ZZSZSZZQTZTZTTZS', 'ZYaTbWb', 'gFJKLKLKLKLKLKLKLE', 'aTZbWbTZTZTZH', 'DhBQEG', 'adbdOdbObOdbObdOdObdbdTadbdb', 'FMFjFMg', 'gheBQKLKLKLKLKLKLKLKEAGQE', 'ZSZSZSTZSZSZZQTZTZTZ', 'TV', 'ahBgQEMAGCDhBQE', 'aFJV', 'dVdVUPYJj', 'AjCE', 'MAgGhRCDhC', 'aMPFJa', 'aCDhBGaIdcbWFbXYUNdUdUdKLKLKLKLKLKLKLKLEh', 'AGhRF', 'TZdcTbWbTZZRcJFIj', 'CDhA', 'AhARG', 'MegLKLKLKLKLKLKLKLKLKLEG', 'MgaCDhDhAQR', 'TUIdFIUYaVWXNOV', 'MhBgCDhCD', 'a', 'gCDhBZQh', 'aYPj', 'aYPVaTPUYbWYX', 'aTIFIFddFdcbWXNO', 'aPC', 'gGDhBQCE', 'VjYVaVa', 'aVgaaVMeKLKLKLVKLKLKLKLEQ', 'aPaC', 'AFR', 'hACDhBQ', 'gLKLKLKLKLKLKLKLKLEe', 'a', 'CDhCDA', 'VaYdcdcScbdWXNI', 'aYPTPVPVPVZRcbWbijj', 'dbT', 'ChCADR', 'ggMeLKLKLKLKLKLKLKLKLKLEGaGAGc', 'ChD', 'MGhRgCDhA', 'aPiTPTPC', 'CDhACACACA', 'aGhRPDhCCDAaC', 'adbTZRcbWbWbWbijP', 'agcMeLKLKLKLKLKLKLKLKLEG', 'gLKLKLKLKLKLKLKLKLKLEGZQe', 'gDhAGARhgC', 'FjcEAGAGFY', 'aAYGhRdbdIUdcIWIWIaIaIaWIFEhghgCdUdbdDh', 'SZCDhBQP', 'ZYTPZRcJFJFJFjbFVWab', 'aTPZPVYRYRaYcYcFTJKLKLKLKLKLKLKLEGAG', 'geLKLKLKLKLKLKLKLKLKLKLKLEGQ', 'gDhhBCQ', 'aUQEOGZSZSZS', 'aAXGhRdcdSdNgcdcCDhbWAC', 'gFJVT', 'abWYXiEFVa', 'FPiXaCNAC', 'VdVcYja', 'aC', 'YgMeKLKLKLKLKLKLKLKLKLKLKEG', 'ChCADGhR', 'TZSZSZTQSZSZZS', 'DhCfKLKLKLKLKLKLKLKLKLE', 'VJcVFcbWbY', 'acgM']]
#
#
# Recording Date: 02.02.2024
# 1xN cell array of mapped syllable orders for the day:
# [['dZTSaHTabWbZTTZTZZT', 'ZTZTZTZTa', 'aYUYUYUYUYVTPTSZSOZS', 'CDhBZQ', 'cIFIFcbWXiEdVG', 'FdIFIFdcdcbWXiEa', 'gLKLKLeKLKLKLKLKLKLKLEG', 'aSa', 'aJLKLKLKLKLKLKLKLKLcKLEFGAGAGY', 'AGhR', 'aPa', 'EHaEcdcadchCaDhB', 'agCDhBMQ', 'abWbSaH', 'adYMVCaDh', 'aQEAGgCDhBcM', 'aUTPTO', 'aM', 'aFGMgCDhBZQ', 'ababdbd', 'aMgPaV', 'agMCDhBQ', 'aAYdIFaYcbWbWbWXiNgCDCDh', 'aGhARgCDhAM', 'aUONRIRbWb', 'aM', 'aTVPa', 'aCijVgPaFP', 'gEAGagMCDhBQ', 'abdPa', 'aPDhaCLKLKLKLKLKLKLKLKLEG', 'FFjj', 'PVaDhFdFdC', 'IEhTAGhRAEdTZCTDZhTBZQQ', 'aZTSZSZZSZQTEZTAhAhZSAGhRQRQR', 'aDAGhRUdPSIcVIaIaaWFIFEhC', 'aWbSTTHb', 'ab', 'aBDhCPDCh', 'aaIPcbWXYZaNYdLKLKLKaLKLKLKLKLEYaY', 'aaYadcbWbWbWXYdI', 'ahbhbRgMCDhAG', 'ageLKLKLKLKLKLKLEAGM', 'aCDh', 'aUYUORbWbYaYaYUY', 'aGdYcdcbWdXYdYdYINgeLKLKLKLKLKLKLKLKLKLEGA', 'agCDchYMBZQ', 'YIcdcNcNYdcdcbWXdNONOV', 'ajPaC', 'aPTa', 'aZTSZHaTaTZTZTT', 'aUVSZSZSO', 'CDhBZQEF', 'G', 'WddcbWXiEIXIaQ', 'ababTbTV', 'hDhDhDhACACACACACACACg', 'aGhRHjHjiPjijiAgChghA', 'agCMfLKLKLKLKLKLKLKLKLKE', 'aCjiXN', 'geKLKLKLKLKLKLKLEG', 'aFDShTSTCCA', 'hgeB', 'daZMTgZTeTLKLKLKLKLKLKLZETQZH', 'aEAGgeLKLKLKLKLKLKLKLKLKLEMGAGZQ', 'aIaIYcdcdcbWdXUdNUadagdadF', 'aPaCPTPTPTPTDahA', 'abdVSPKa', 'aJYM', 'agMCDhAGhR', 'hDhBQC', 'agCDhdcBM', 'TghCaDhYaUM', 'agMCDh', 'aIdFIFcdcdbWXNLKLKLKLKLKLKLKLEG', 'ahBQgYCjDhCD', 'OVUFUFRFJPT', 'aPSaC', 'TZWbWbTTZPVRTFZSTSTSTZH', 'aTHWFbWb', 'KLKLGKLKLLKLKLKE', 'aBZQDPhaCCDh', 'abITZcbcbcbWXTdN', 'ageLKLKLKLKLKLKLKLKLKLKLELEGM', 'aUO', 'aIdFcbWXNKLKLKLKLKLKLKLKLE', 'aDPhJPaC', 'aPDhC', 'PIFIdcdcbWXNVd', 'adcMGhRgCDhA', 'abFDPhCCA', 'abd', 'PUVTO', 'agMeLKLKLKLKLKLKLKLKLKLEG', 'aghdcMAGhR', 'aOVUaUaU', 'ageLKLKLKLKLKLKLKLKLKLKLEM', 'aPjTPZUC', 'aGhRgCDhMA', 'aDPhaC', 'agCMDhBQE', 'dIdFTIFIbFbFWbcbWXiZdEAT', 'aadbdbPaPaPaPSPSPSZTd', 'aQEOSgCDhBTaM', 'aIcdcbWYJOd', 'aDPhaC', 'dI', 'ajPY', 'aNONObNbTaTbTbONbOb', 'aZa', 'aQDAPAhPCCDhB', 'ahAaTGa', 'Tb', 'AZbF', 'aIFIdFIFcbWTbWXdNOUdUdUd', 'aTIadcbWXTdNTdO', 'aDPC', 'aFIdcbWXNUOcVUVUQaI', 'aOVU', 'aPbdIaFdPcdcbaWbWbXNTaTafdL', 'aijJY', 'aYUOV', 'agCDhMB', 'aZaCDhTAaFP', 'CDhBQ', 'FjP', 'aBZQgYMCDh', 'aZSZSZZSZQTZTZTZTT', 'abWbghghghACMDhAGhAR', 'aWYWYWYXNUfdLKcLKLKLKLKLKLKLEJFb', 'aDhPCTaCA', 'aIddcdcbTWXZdN', 'hOSZSZSZQ', 'aIPadcdcdcdcdbWXNd', 'bTZaIHWbaWbTTaPZaZZRTbWZiTEZdTGS', 'abMFIM', 'aDSahCAGhQRQR', 'aIZdcTbWXSZTNTSTfZTSTKLKTLKLKLKLKLKZLETQ', 'aFDPhSZCCDA', 'aFbWbSTSTTZPZVZRIWHbF', 'ababVaUYM', 'aUgcYagMhAGhR', 'agMF', 'aIdcbWXdNOV', 'agecLKLMKLKLKLKLKLKLKLKLKLKLKLE', 'ajPAaC', 'CDA', 'h', 'agMCDahMA', 'aTaTZTdTdTaTSabTaTa', 'DCDhh', 'CQDEGhACDhB', 'aGhRgCDhMA', 'aIFIFdcTbWXaTNd', 'aIdSIdHIaIaIad', 'ChDCA', 'aIJFIFYFcbWYWXNOVYRdYF', 'gDhC', 'aGhQRPDhCCA', 'AZQCDaDhCaDhB', 'AFa', 'aTPTDCQPTa', 'adSdcdcdcbWXibEaVdI', 'agagMCDhB', 'aWAaPa', 'agMCDh', 'aDPhSPCACA', 'aQDPThhCACDhB', 'aPOa', 'agCMDhBQ', 'AjACC', 'T', 'aaCjPVPVPP', 'agCjEM', 'CDhA', 'h', 'agCMDhAGhR', 'TZaITdcabWXdNOV', 'aZQaIFdIdcdcbWXNOSTZSZSZS', 'bT', 'aIdNdcdcdcbWXdNKLKLKLKUdLKLKLKLKLE', 'aPaPDSTShZaCCP', 'gDChA', 'CDhBQ', 'hAF', 'aNOUVaUaU', 'aVaVKVPaVa', 'aDCDPhaCA', 'aZbTZTaHa', 'abWbTHFa', 'agcMCDh', 'aUYUOT', 'EAG', 'aWTa', 'aGAGdbdbIdcbWbXNiNiNgJLKLKLKLKLKLKLKLKE', 'bZRTEhAGhR', 'ChD', 'ajPTZRYYbFJV', 'IIdbWbad', 'CDhA', 'aDPhC', 'aiPVC', 'QZSGZQTSEZShBZSZQE', 'agCMDh', 'aPDShCCACACA', 'FajPPaC', 'GbAhAGaWahahbah', 'aOURFJ', 'aDhPSCZCDh', 'aQYgFgFgFMgFgFgFgFgCDhB', 'aaCPSZC', 'aHWHWHWIFbWbTdadacScW', 'ggcMCDhAaGhR', 'aNYOVX', 'aIYddPYPcbWXNLKLKLKLKLKLKLKLEF', 'aDPShCaCCA', 'aaTFIaZFITFIdcbWbWiUFTEd', 'NKLKLKLKLKLKLKLKLEG', 'ahBQEhBQIFIdSTZTZaYXNgdYadCD', 'aZSZQTEZSAZSGhR', 'CjV', 'agUCYUYM', 'TZFbWbSTTSTbRZHbWbiEGg', 'aMPgaPaC', 'aRgCDhMAGhQ', 'VjdcdcdFaVaVa', 'dIYcbWXN', 'aPabV', 'aPaPVTVPa', 'aGTGTVTa']]
#
#
# Recording Date: 02.03.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aPG', 'ad', 'aZTZTZdTZTZTZT', 'agchCMDhAGhR', 'aijY', 'aPaC', 'AF', 'dIcbWXNfLKLKLKLKLKLKLKLKLKE', 'TZTZTaZUTOZTZZTZT', 'aYj', 'bbWbTaTZSaZH', 'aPTPaC', 'acgCDMhBQ', 'ageMLKLKLKLKLKLKLKLKLKLKLEG', 'aPaWaWaba', 'TZVYRTVFZJVT', 'aJbJbWaWaWgbdY', 'gCEh', 'aLKLKLKLKLKLKLKLKLKLKLKLKdLKLKLOYdYiYi', 'ajYcF', 'abdbdbSaSa', 'IIFIcdcdbWXVd', 'AF', 'VYPj', 'aTZaTZTbbababababaVUaTZ', 'aC', 'gNCX', 'ZbTTZaHZRZaF', 'aPSPZC', 'aIdcdcdcbd', 'a', 'aahCBDChCD', 'ggMCaDhaMAGhR', 'aPa', 'aPC', 'aFTYaYj', 'aPjFjaC', 'aTaIddIdcSWXij', 'AF', 'aId', 'VdYcYdYPVPVaj', 'agcMeKLKLKLKLKLKLKLKLKLKLEAG', 'ageMKLKLKLKLKLKLKLKLE', 'ahBZQgYhCDij', 'gDhACGhR', 'agM', 'aPSPSPCHCHCDgJ', 'aYbaWX', 'aCPa', 'VabIaVadcbWXVUViVUVUVEaadAFW', 'adVTPaZTZ', 'aYVaUVIdUdcdcbWXiJEabJb', 'aPaC', 'TZUOUdV', 'FYMPgaa', 'VVjaYVa', 'ZQZETTJZTKLKLKLKLKLKLZKLKLKLKLESGZ', 'AGhR', 'TTZRZcbWTiJEZ', 'CDhCDCP', 'bbWbTZHabaa', 'aIddcdcbWXi', 'agMCDhBaMQ', 'aVcgVMJLKLKLKLKLKLKLKLEG', 'a', 'aTPTPaC', 'aTZTdTaTZTZ', 'aPCDh', 'ajPgFaC', 'acdcbWXNfLKLKLKLKLKLKLKLEdcd', 'TbZWbTTSZVTZH', 'CjHjHjHjHjHjHj', 'aPNXaC', 'adaTC', 'CDhAGbR', 'aOVU', 'AF', 'aYFIadcdcbWXWXdNOYIa', 'aZTZTYjTdaTZT', 'dIFTdcdcdbWUXdNKLKLKLKLKLKLKLKLEVQ', 'a', 'agCMDhB', 'aPSPC', 'aYVj', 'aFaUadbWXdNhIfLKLKLKLKLKLKLKLEQ', 'AF', 'ZTZTZTZT', 'aWbWbTTZVZRZbFHjP', 'IiaPEaC', 'CfLKLKLKLKLKLKLKLKLKLKLEG', 'gUgaVYcCYMDhAGhR', 'aPTPC', 'aTZZSZSZTSZQZTZTZTZ', 'CBDhCDge', 'aPaC', 'aYaYj', 'TZHTZTZSTSTZaS', 'abUVIcdcbWXiEdG', 'aPDhACCE', 'aM', 'aPC', 'babTZTZIRbFdj', 'CiHiHiHjHjg', 'AhRG', 'adUdUdaIdcdcdbT', 'TZSZZQTZETZTJZTZS', 'abWbTZTZH', 'aaCPaC', 'ChD', 'aDGPhC', 'aPTZC', 'aOVU', 'hCPV', 'aPC', 'ddbIVdcdcdcdbPaa', 'aPTPC', 'geLKLKLKLKLKLKLKLKLE', 'aPDhC', 'CE', 'aUNOWag', 'aUVBQO', 'aSWa', 'ajYaY', 'ggMCa', 'aVVZVZVXRYRYRYcbWaYPijVaT', 'VNOVaU', 'VYPj', 'aPDahPACGhR', 'YUO', 'aWHbWbTZTZH', 'TZFbWbTTZSVTSTZH', 'TAPDAPaChPAGhR', 'AF', 'VdJcaKLdKLKLKLcKLKLKLKLdKLKLKLKLcKLKLKLEQF', 'ZZSZZSZSZSaTQTZEJTZTZST', 'a', 'aPDChA', 'adbdbdbIYcdcadcdcdcbWXd', 'aSaC', 'AF', 'dZTZdFJT', 'aPNXC', 'aPaAaC', 'ajY', 'MagCDh', 'AF', 'aDhCCDaCA', 'dbWbTZTaaHZRbFJV', 'a', 'UIUdUdUdFIFIUaUTdUddcUdbUWdUUWUXdVd', 'CiX', 'aYj', 'aMgdCDa', 'aTPaC', 'ChD', 'gFgcMaCDhAGhR', 'aMVgCPaDhB', 'VYdJFLKLKLKLKLKLKLKLKLEG', 'CFHj', 'CNX', 'aijJVYaY', 'hTVYXRcFJ', 'AhRG', 'CDhBQE', 'aaCCDhCA', 'aaVTTPTaAaWh', 'ajY', 'bZTTZHbZTZTZTZTZTZT', 'TTPVRZbJbWbTZTZ', 'TZTZHTZZTZTZT', 'AF', 'AF', 'CE', 'aPC', 'CNX', 'aPSC', 'adI', 'ababd', 'adYj', 'aIdYcWYbWXNOd', 'aYVj', 'aTdZTZT', 'abcTbW', 'aTSZSTZQZETZhTACAZTZ', 'aDhCCA', 'ChBQD', 'aF', 'aPaC', 'aPDhCAC', 'aDhPZC', 'ZTPGSZa', 'BZQ', 'h', 'aPTPTaC', 'aPaC', 'VYJcYcYcdcFKLKLKLKLKLKLKLKLKLEQ', 'dZTdUaUYaITdcdcdbWXiUEaTZGT', 'aTbd', 'aTbdIFIdcbWdXNfKLKLKLKLKLKLKLKLE', 'BZQEG', 'aTZTZTZTSTZHTaZaZTZa', 'agCM', 'aHaHFbWbdcdTcdcdcbWHWaWa', 'ZbZTZRZYFTJZTLKLKLKLKLKLKLKLKLKLKLKLEQa', 'aYPj', 'geLKLKLKLKLKLKLKLKLKLKLKLKLE', 'VjVYaYa', 'geLKLKLKLKLKLKLKLKLKLE', 'aPSaC', 'aPDhaCAaGhQRQRQRQRC', 'VdPYVaij', 'abababaC', 'acdcJFLKLKLKLKLKLKLKLKLKLEQ', 'IajWPgAC', 'aPaC', 'AF', 'CDhB', 'ZZTaZTZPTZTT', 'aaPbKhKP', 'abIFIdScUScbaWdb', 'TZSZSaZSZQEZTZTZS', 'ZTZT', 'aPTa', 'aM', 'aTdaZQTEZJPTTO', 'aTPC', 'ZTZTZTZT', 'aC', 'aPTZaC', 'TPTaaWaT', 'agYeKLKLKLKLKLKLKLKLKLEM', 'YdIaIaIEcdcdcdIWa', 'a', 'aZdTZH', 'aPSPC', 'ARGh', 'ARGh', 'MVUFJ', 'WaYdcbWaXYadNaIW', 'TcTdcdbWXZINZfKLKLKLKLKLKLKLE', 'aDhPAHCCDCDhB', 'aPDhCaC', 'AF', 'agCMDh', 'aCaCPTPaCaCa', 'aFVaPTPTa', 'BQEhBQ', 'agMaM', 'ageYMBQ', 'a', 'aTaIaIaITaTadSa', 'a', 'TTZZTZTZT', 'a', 'abUYUXSdScScNbW', 'aPC', 'DhBZQ', 'adOadaZTVZTZTZT', 'aPSC', 'CNXP', 'ZZSZSZZQESZSGZTS', 'CDhBAG', 'aPC', 'aSZSZTZSZQZETZTGZZaZTaZ', 'aUVaOVdPa', 'ZZaTbd', 'h', 'SGARcdcdcbaZFEHCWDahA', 'TZTZTZTZTZT', 'aPTZC', 'aVPYaVVaVaVaj', 'a', 'aW', 'IbIFcbWdXNOV', 'aUgJVM', 'geBeBeBeBeBLKLKLKLKLKLKLKLKLKLK', 'aZTZTTaZTaZT', 'geLKLKLKLKLKLKLKLKLKLE', 'adUYUYij', 'aId', 'agM', 'aPC', 'TZTZHTaZTZaZS', 'agYM', 'aVYPj', 'a', 'ajY', 'agPadM', 'aPDShaC', 'aPTC', 'VaTZPVZVRYFTZTZTZT', 'a', 'ZbWbaTZWHF', 'gJKLKLKLKLKLKLKLKLKLEG' ...
#
#
# Recording Date: 02.04.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aIYaFIdcdcIHIHIHIHFIHIFdEJ', 'aTdZcbWXTiZaTEZVI', 'gDhAC', 'ACDN', 'TZQZETZSOVZS', 'XLKLKLKLKLKLKLKLKLKEN', 'aYdIFIFScdcb', 'BQE', 'MCgDhaAgGhAhAhR', 'aPghC', 'gCLCLKLKLKLKLKLKLKLKLKLKLE', 'aPaC', 'aTC', 'VdJVcFa', 'BQEG', 'aPSZC', 'aPaC', 'CfLKLKLKLKLKLKLKLKLKLE', 'ggcaM', 'DBZQh', 'hBQ', 'aaCdadPDZCaC', 'aOYaU', 'AhRbFbFG', 'Ci', 'YEGIdUbWbWXNfchYCcd', 'CDhB', 'abTWbTPTZaPVRcFWHjFWF', 'adTSZHZTZTZTTZ', 'aPTaC', 'aPiLKLKaPC', 'ggcCMaDh', 'aaIdFSTbTWXNONONfLKLKLKLKLKLKLKLKLKLKLEdhQ', 'VYaYacVdjacVFaEF', 'abd', 'gBQe', 'geBQ', 'abWbSTSTSTTZWH', 'aYaYIaYFIaYFcabWbdadT', 'aaUdUdUdUdUd', 'DQhBQEhB', 'XEAi', 'Ci', 'aPC', 'CHj', 'ZPaTPaaTVTV', 'aaCP', 'aVIFIdcdcdcbWbWbWbXdNLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLE', 'aPCcFJVPSPSPa', 'aIFIdcdcdcbdbWXdN', 'ChBZQD', 'AF', 'aaCVaVTVTV', 'aPjHjHjaC', 'CE', 'agM', 'aTPC', 'abWbdTcdcdcdcdcd', 'aPaC', 'agM', 'TTVIUddacbUWbd', 'aEcdcCDhBba', 'aPIFIcdcSdcScbWbXiUTEd', 'VYJcF', 'gCDhh', 'aPCHjHj', 'agM', 'CEG', 'aPSPPaKTKPJTaTa', 'agYMCDNX', 'aMgPa', 'aOdIFIbTObWbadT', 'aYij', 'BEAGQ', 'CE', 'TVbZR', 'a', 'aFIFIdcdcbWXNcOdI', 'aZHFTbWbSZaTTaS', 'aIdFdcdcbWX', 'CEhB', 'gDhAGhRbFC', 'aIdFTWXUdUdTdNLKLKLKLKLKLKLKLEA', 'AhRG', 'gEGCAC', 'ARGh', 'aPSZC', 'aVTPaC', 'aPDASAhSAC', 'ZZTZTZTTZTZaTZT', 'CE', 'eKLKLKLKELKTVLKLKLKLKLKLKL', 'adIFdcdcb', 'aWbWbTSZTZTZaTZSZSZQWEHJ', 'gDhBC', 'aTIbdZbd', 'TTSdZSZZQTEZThZATSTSZ', 'agCHjEGVAGAGYaYM', 'VcINYScbWX', 'aIdcbWXNUd', 'agMCACA', 'gCDhB', 'bbIFINUcUcbWbXNOd', 'daYbIVddcdcPIFIFEVhEhTd', 'dI', 'CDhB', 'aTZSZTZSZQIZTZTZ', 'aTZTZT', 'ARGh', 'aVTPC', 'adFdbcdcdcI', 'ghEC', 'aTZTZZTZTTSZHbZWadbYXTNVZTZTZ', 'aPDhCAGhR', 'aFbSTSTSTSZH', 'aPaC', 'CDhAGhAR', 'ZHTbWbZTTZTZSTSTSTZ', 'bYbFbWbZTSZZSZSTHHWbWbWbaTTZR', 'adZQXEdYIdhBQEhBZQVGaUdcbWUXNKLKLKLKLKLKEG', 'aZIUFIFIFcddcSdcbWUdUXdUTidE', 'dijJjJdYdYcYcYYdY', 'gDhC', 'aPHTjHjHjPC', 'agMCDh', 'aPDSTChg', 'geLKLKLKLKLKLKLKLKLK', 'agdcdMaM', 'AGhR', 'aFZa', 'VadcjFP', 'gBeBeBQe', 'gEC', 'aUaUbdbIdcbWX', 'gCDh', 'dIFIcdcdcdcbWXNXNP', 'TVPZbWbTTZTZVZIRYbFZTSjTSHjHjHjTZPH', 'ChBZQD', 'gEC', 'agMCDhAF', 'AGhR', 'AGhR', 'aijJWVYWaWY', 'agM', 'CX', 'adbdbdbdNdNdNbNbdXdadadXdUXUdUdUdUdTUdVT', 'aPC', 'aPaVaC', 'aTEZSTZSTSZQ', 'agcMCE', 'CDhAGhR', 'CDhAbJF', 'ddcdScbaI', 'aCPASHASAjHjPSPaP', 'O', 'aTSTZTSZT', 'aGbIdaddcbWXNfLKLKLKLKLKLKLKLE', 'gG', 'gDhBhghCQ', 'CihE', 'aFbWXdTNZdOI', 'CHjHjE', 'CE', 'EJCDhBhZQE', 'aPTC', 'ggMaCDA', 'gEChB', 'CiE', 'aGPVa', 'a', 'CDhBQ', 'aAVEPaVaVChC', 'VJYVcFa', 'AhAhRG', 'gDhC', 'adcdcdbHbWbYaYacdc', 'VUbIdUdUdFIFdcScbWXNTdTdOTaT', 'BEhAGhRIZQ', 'CDhB', 'CDhAGhAhR', 'ZTBYaZTZSTSZSZZQaEbCWbDZh', 'ARGh', 'CN', 'CEhAGhR', 'aZTZC', 'AhRG', 'AF', 'aIbdcbdT', 'AF', 'TaPYijijij', 'TZUZUTZRcJFUTJZKLKLKLKLTKLKLKLKLKLEQ', 'gCACE', 'aPCPTPa', 'agYJMLKLKLKLKLKLKLEG', 'ARGh', 'aMEQVIPdcbWXaiKLKLKLKLKLKbdLKbdLKLKbLKLKLKLEd', 'aaZTYj', 'abdbUTUTbTbTbTbd', 'abTHW', 'ARGh', 'CEG', 'ChAGhRD', 'gEhEhCB', 'Ci', 'aPTC', 'agMC', 'CiX', 'aTZTZTZTZTSZTZ', 'adgcdcdcdcdbQM', 'TSZQZESZSZ', 'aWbTHb', 'aPDThSTSaACACACACACACCA', 'TbCWbWbaTdIZHdcbWXigZhW', 'abIFIFdFdScScScbWXiEdad', 'CEhBQ', 'gJV', 'VadcF', 'aHjHjHjPEC', 'ThCZcdcbWTXWXZiTEZIGQE', 'BQ', 'IaC', 'acgMeKLKLKLKLKLKLKLKLKLKLEG', 'adcJUYMUgdUdI', 'FbIbIUdFUaUaUbWbWXTNKLKLKLKLKLKLKLKLKLKLE', 'aPaC', 'aPSC', 'AGhRb', 'CDhAGhR', 'gLKLKLKLKLKLKLKLKLEhghe', 'abTTZWZVZRcbHWbiLKLKLKLEWbQW', 'aPfLfLfLCKLKLKLKLKLKLKLKLKLKLE', 'ChD', 'AbF', 'Dh', 'ARbGh', 'geLKLKLKLKLKLKLKLKLKLKLKLEG', 'a', 'aYaYj', 'gDhBC', 'ARGh', 'TTZHbTTZVTZTZTSZ', 'abaVaV', 'ARGh', 'aPaC', 'aTWTWbTTZHV', 'AF', 'CDhAGhR', 'YadIUFIcdcbWXYNLKLKLKLKLKLKLKLKLEQ', 'gNC', 'VaYPVPVj', 'aTbIbIVadcdcbWXUTNdUKLKLKLKLKLKLdUKLKEd', 'VWbZdHT', 'gTZTZTZSZSZSZQECDh', 'VJFVXRaYRYbFiNXN', 'FTdcbWXZbiTFgZdCIZ', 'TPADADAD', 'DBh', 'FTIbdbTd', 'bcWHbWbddbH', 'DhDhBQBQEC', 'aPSTC', 'AhRG', 'aPEChEhB', 'SZSZSZSZQSTSZTZZTZT', 'aPgSPaM', 'S', 'agTcM', 'aPaC', 'aPC', 'DhBZQ', 'aIdFIFIFdcdcbWX', 'aJF', 'Magg', 'CNX', 'gEC', 'adTdbdTbdObObObObObObOdOTUVUVUaTUTUTUTbTbTb', 'gDhCBZQ', 'gLKLKLKLKLKLKLKLKLEGe', 'agMCDh', 'ChD', 'aPT ...
#
#
# Recording Date: 02.05.2024
# 1xN cell array of mapped syllable orders for the day:
# [['TWFWFbZWbTTZSZH', 'TWbZSTdZIHdcbWX', 'aGUdUIdYcdbWXNfLKLKLKLKLKLKLKLKLE', 'aiEPaC', 'CDhBQEh', 'aZTZSZSZTZQZTZTZT', 'SEZMEMEMYJQVJVJV', 'abWbTSZH', 'aIdFIFIFIFIdbdb', 'AQRGh', 'TZZSZQTESZSZhSC', 'ChBQHaGD', 'abgMCaDMhAGhR', 'aUdbdIFIadcbWbT', 'TSZTZSZQTEZTZCTDZhBST', 'Dh', 'CEG', 'VdIFbWIWIWIWIHFIEaG', 'aIUFdUcTbTbWUdXNKLKLKLKLKLKLKLKLKEUQd', 'agYaYCacM', 'aIadcSTabbWdFbWbT', 'aIdcbWXdNfLKLKLKLKLKLE', 'VUOVdYUaUbWaYa', 'aBeBPDhCChghge', 'ATF', 'TTFdcbWbZZVTVTZI', 'dIdcbWXV', 'CghAbF', 'CgFgFgFaV', 'agCMDh', 'ajGPaC', 'agMCE', 'aGAGPDC', 'aaHbWbTH', 'aRgCMDhAGh', 'adIFbWXUdNO', 'VIPFIFYcbWXaNd', 'ajYaY', 'AFaPDSPSaChA', 'BEGQ', 'aPDCDgCCDhB', 'CEG', 'ChADGhR', 'adIFIdcXaUNLdKLKLKLKLKLKLKLKE', 'aQbIUaUScbWbXNLKLKLKLKLKLKLKLKdLE', 'CghBDhC', 'AF', 'TZWbTZTTVSTSZSZH', 'aPTZC', 'TZTbIdFIFcb', 'aYj', 'aIYFbWbdT', 'AhRG', 'aIUaUVaIUUScdcdcbWXNdOV', 'ZFbWbaSTZZRaHFjPVPW', 'agCMDhA', 'agWPeVeVeLKLKLKLKLZKLKLKLKLKLCKLKLEQ', 'VJLKLFKLKLKLKLKLKLKLKLEhQY', 'aZHbWbdTaZTZTZSTSTS', 'adSISaYcddcbWcXdNcfLKLKLKLKLKLKLKLEQ', 'aDChCD', 'AARGh', 'bbWbWbaSTTSZPZRcbHFJa', 'aPDhCCDge', 'aYijdPVPVaPYUY', 'AhAhARVbG', 'TbWbZTHZaSTZSZQEWFJV', 'YVYPVRaYRcdFYJVj', 'AF', 'aId', 'agMCHjHj', 'TWbWTbTZSZZRZYFSjZaH', 'agMeKLKLKLKLKLKLKLKE', 'agCMDh', 'CDh', 'db', 'ChBQEGD', 'aPgaM', 'AFP', 'TbZWbTZTZH', 'aADhCCD', 'YaWHWHWbdTcdcZRcFdcjEW', 'CDhCA', 'aOVRcbWbTUVZVZVRFJ', 'agMCDh', 'VYVYPVj', 'bWHWHWHabWbZTZTZHT', 'VYTbZ', 'aTaITcdcbWXaTiajdF', 'aIFbWXdadNOTd', 'DCEh', 'CDBQEAhBQEh', 'ZWHWbWbSTZVHUWRcFaJV', 'aITadcbWXd', 'aTOUTbV', 'AhARG', 'hBQ', 'aYdYUdIFbWXNKLKLKLKLKLKLKLKLKLE', 'ZWbATGhRAbTSTSTZHTZSZZSZQEWbah', 'gCMCDhBQUgDhBQE', 'aYJaVM', 'TYRbTFWSbPVPVPZTaHVWZRYcFjPVPVSF', 'agMCDhB', 'aDPhSTZC', 'gQBEhEhBQ', 'UadIUdbdacdcbUWUdYUXdUdNaLNLKLKLKLKLKULdKLKLKLKdLKLKLKEad', 'aVgcMCDhB', 'aTZC', 'adIFUdcdcdcbWXijPVP', 'bZHZbTTZTZTSZTS', 'ChBQED', 'abWbTdSPI', 'aiPTaC', 'aGAGagMCDhBQE', 'aIdcdbWbd', 'T', 'ggMCaDh', 'aTZHbWbda', 'bUddUdUdUdbdbUdbHWHWHWTUTUTUdTUTUdTUbdUdUd', 'ZWAbWbTSZTHPZQESh', 'aYFbWbcdcdcdI', 'aJVcF', 'aUdUXdNUdUdUd', 'ARGh', 'CSZShACgeVeDSZ', 'aYIdFIdcbWbiUdUdUdUdE', 'aPgaC', 'agagcMCDh', 'aWbWbTZdbdbISFcdcbWbXZH', 'aIcdcbWXdNfKLKLKLKLKLKLKLKLKLE', 'aaCVPaC', 'VYJcFLKLKLKLKLKLKLKLKLEG', 'gBeBe', 'BEhBQQ', 'TZdcbWXTNZIfLKLKLKLKLKLKLKLEhQ', 'aSTZSZQZSZSZ', 'hBheg', 'aPTPaC', 'ChBQEGD', 'CeBg', 'aWbdYabdYbdbIdcdFIcbdcdcIWIWIWIFaFaFIFIFEGb', 'ggaCDMh', 'dIcdbWXNKLKLKLKLKLEG', 'aFTZDgChCA', 'aIdFbWUXdUdUNdUdUfdUdLKLKLKLKLKLKLKLEG', 'FUFUFUFUFUFjP', 'AARG', 'ARGh', 'aAFgPhSPCC', 'TFbTaTZTTZHZa', 'aPTPTPadVPa', 'aPaC', 'aIMgPCaDdh', 'agM', 'abgMCDahMAGhAR', 'agMCDhA', 'agCMDhB', 'bbWbWibjWbTZWHZRbFJTVRS', 'TbWbZTQPTZRbFjPVP', 'aVUdQAGO', 'VQYPVPVPVRcFjJLKLKLKLKLKLE', 'aCBQEdUdDUdhCgUe', 'gAGhAQRDhCBQEh', 'SbWbSTTZZRHbFJLKLKLKLKLKLKLKLKLZFEW', 'adIUFbWXdNO', 'aVIaYUdcbdWadXiLgC', 'FAgEPDTChCa', 'dWIUda', 'aahgAaFCA', 'aPFgFgeCKLKLKLKLKLKLKLKLKLKLE', 'bFcddcbWbTI', 'abWbWbSTZH', 'gGhRgcMaCgaDhA', 'agMCDh', 'aEGAGijY', 'VYjFPa', 'aWbYWbdTPVZVZVRbFJVI', 'VTcZVXRYbFbFbFbWbjPaVa', 'ZTbd', 'ChAGhAhARD', 'REbWi', 'aCVPaTZ', 'bZdcbWbTTTZZRIFJ', 'ajijdYPVRYbFYJVi']]
#
#
# Recording Date: 02.06.2024
# 1xN cell array of mapped syllable orders for the day:
# [['VaJVdcF', 'ARGh', 'CDhA', 'bcJFZWHjEQZWbWbTTTZSZTVSRTZYcFTJVZSYXRXR', 'aYIadcdcbWXdadadiEUdAGAG', 'CDhBQ', 'CDh', 'UaYUbaTUdTUdUZTdYa', 'gDhAGhRC', 'aJMFcM', 'aBVaPaC', 'aiXNUYdYdYdY', 'aKPVPaC', 'aDhBgQMCDhC', 'CDhBQ', 'ad', 'aPTZC', 'aIYddcdcbWXUdiUdJEAVG', 'aijVPaUaUaY', 'aPC', 'FVdIaUdcdcbWXNO', 'gAFh', 'aGhRgCDMhA', 'ZZTZHZbTTZTZTZT', 'aITddcdcbWXNKLKLKLKLKLKLKLKLKLKLKLE', 'agYMYMFJ', 'agM', 'CDhA', 'CDhBQ', 'BZQ', 'ZTZTZSZSS', 'agcMC', 'aIUFIdbUd', 'AF', 'bbYWbaTdcIWbH', 'CgBQ', 'VJcFKLKLKLKLKLKLKLKLKLKLEVGY', 'CDhAGhQR', 'CDhB', 'CSZSTSZSDhBQEG', 'ZZTZSTSTZTZTZHbTZTZTZT', 'aDChgC', 'CDhB', 'VIUdcbWXWXadNO', 'aIFcbWXYdiEG', 'CDhahA', 'AGhR', 'agMJLKLKLKLKLKLKLKLE', 'aPTPaC', 'aFgYCDhBijZQ', 'T', 'AF', 'VYJVcYUFPVYWRYRYRYcYcYRYRXIXRIRXRXRcFj', 'CgeBQ', 'ChBQD', 'gJKLKLKLKLKLKLKLKLKLKLELEVG', 'aSFbTWSTbSZTSVRZcFHj', 'AF', 'FaIFIcdcbWXWiYdFEQ', 'aDhCA', 'aPC', 'CDhA', 'AhRG', 'adbdbda', 'CDahCA', 'CDhA', 'aUOTVYja', 'aaTZadTZH', 'VIdVVUddcbWXUdNXV', 'ChAGhRD', 'adIdcdcbWXNfLKLKLKLKLKLKLKLKLKLKLE', 'dad', 'VUVUIddcUbWdUdXiFE', 'AQRQRQRQRQRQRGh', 'aTDahCCA', 'aPC', 'ARcFGh', 'aZTZTZTZTZTZSZSZSZSZQT', 'aBDhCCg', 'CDhA', 'abIbIbIUaIdcdcbadWXNOVd', 'adVaddcbWaXNOI', 'CDhAGhR', 'VIPdcdcbWXaTd', 'AF', 'CDhA', 'aYj', 'aIUYUaUdcdcbWXdUdNOVUd', 'ARGh', 'abdbd', 'gT', 'CDhBQEG', 'CDh', 'UZTVZTTO', 'aPC', 'TZWbWbTTZZTTZTZSZSZTZZSZSZQSTSTSTZH', 'agMCDA', 'cGhgRgYMYMCDhA', 'aaCVPaCaC', 'CDhB', 'aG', 'adIdcbWXiLKLKLKLKLKLKLKLKLE', 'Cg', 'ARGh', 'CDhA', 'ChEhJODhBEQE', 'hCDhBgh', 'aiYijPY', 'CgeLKLKLKLKLKLKLKLKLKLED', 'CDhAGhRb', 'CDE', 'CDhA', 'VJcVdFa', 'aPTPTPC', 'CiX', 'MagCgDhAGhR', 'bFbZTTZTZZRbFHTjFESTS', 'aIdFIcdcdcbWXUd', 'aPTSTSZaC', 'adYMUa', 'CDhAGhQR', 'CgF', 'VcPF', 'agMCDh', 'aFJYM', 'ZSTZSZZSZSZSTPQZSTSTSZ', 'CDhAa', 'agMYMJKLKLKLKLKLKLKLKLKELEG', 'aOVUaU', 'CDhFP', 'VVYdIadcbWXNa', 'CDhB', 'geKLKLKLKLKLKLKLKLKLKLKLKLE', 'CDh', 'VJVFY', 'aC', 'CDhA', 'aPTPTZC', 'dIFbWXNONOLKLKLKLKLKLKLKLKLEQ', 'ZbTWbZTTaSZTZTZTZZTZSTSTZHHWbWb', 'aTZTSZTTZHZTZTZTZ', 'CDhA', 'aYIddcbWX', 'bZTZTZHTbWbZTTZZRXRXRXbFTZaT', 'agMhCDhA', 'PaTaC', 'ARbGh', 'CDhB', 'ZTZSTZSZSZSZZQTZTZTZ', 'AcF', 'aPaC', 'CDhA', 'aadTdTdTdTbdaV', 'ARGh', 'CDhB', 'aIdcbWXdiEGVGQ', 'aPC', 'TCa', 'bITFcbWXZTSNZOaVTaZTZ', 'aUdVaIdcVbWXaVaVaYNdTdTdTdUdUdUdUdUd', 'CBDgQBQEh', 'AGhRFb', 'AF', 'aPZRbcFIddcbWaXdNOUdUdVT', 'aPTPTaC', 'CEhA', 'aIYcdcbWTd', 'aJVJIVIdcbWXNOdVZVRbF', 'aZTZSTSTZHUFbTZTTZTZT', 'CNX', 'CDA', 'FjcFPa', 'Cjg', 'aFgMCDhA', 'VYcjFEJEJEaG', 'adPaC', 'AF', 'CDhAGhR', 'gQEhgMCaDhaMB', 'CDA', 'gCDhAGgR', 'aYUYIdFIdcbWXUdNO', 'agYFJM', 'aPC', 'CehghgLKLKLKLKLKLKLKLKLKLKLKLKL', 'CBDhCDh', 'VPjY', 'aOdZTUaU', 'aPaC', 'gJV', 'VYcaJVF', 'ZZTSTZSZZSZQTTZTZTZT', 'gDhACF', 'CDhAGJhJhJR', 'CDhBQ', 'h', 'acaCYcYcDYcYhjC', 'abaTZTZTZT', 'CDhA', 'DBQhCge', 'ChBQD', 'ARGh', 'gCDhAhGhR', 'ChCDAD', 'CDhAGhR', 'CDhA', 'adVZSTSTSaPada', 'VaUVWRbJFO', 'aUdIVbWaXYNUYUdUdUdUdUd', 'VaVadIdcdcbWXiEaV', 'TdcdcdcbWTXZiTEZIZ', 'agVcMhC', 'ggYMYMaCDh', 'CDhA', 'aVaVaVYjcEF', 'aQdIcbWXUdNLKLKLKLKLKLKLKLKEG', 'CDh', 'VOUdUaY', 'hCDhA', 'CfLKLKLKLKLKLKLKLKLKLE', 'gagJMV', 'aVbIcdcdcdcbWXPad', 'aC', 'VYJVcJYJF', 'ZZZSZSZQTTEZTZhSBQ', 'CDhA', 'TCaaCaC', 'VXcNOVbWYa', 'CDg', 'CDA', 'ChDBQhBQE', 'aPTPC', 'aIdFIdcdcbWXNO', 'agcM', 'CDh', 'gDChAGhR', 'ZTTVRZYbJbWbiTJEZTQZTZ', 'VbWbaTdScSJI', 'bWbWbZTTTZRcFZWHjP', 'CDh', 'CDh']]
#
#
# Recording Date: 02.07.2024
# 1xN cell array of mapped syllable orders for the day:
# ...
#
#
# Recording Date: 03.06.2024
# 1xN cell array of mapped syllable orders for the day:
# [['gbWiPEGZR', 'aUaOUV', 'aAaAaAa', 'EGARJbWbiP', 'aZQEGAYGhRgMJTSZSZS', 'aTaPTSaAaAGTVaVa', 'MBhg', 'gDhBQgMCDaC', 'aJVMaM', 'ggaMaMF', 'a', 'VbdbPadUdTUd', 'aJVM', 'aZUZUZUTUZTUZUTUTZaQTaYdcbZWXTUZTiZPT', 'aSPAaC', 'a', 'agM', 'aPJaC', 'aCPDCCD', 'CEGZGZRbWbWbiP', 'YUNONOFP', 'aUaUbIdIdcbWXdig', 'aPC', 'UVUOY', 'MJV', 'aDTPCaDCC', 'YaYUbdbdIFIYcbWdXaUdUdUdUdUdUYdNaY', 'baQFAaaQaQ', 'ChAGDCD', 'VDChcBQCYMDCa', 'VbWXaSdSdSdicScSdcP', 'dUdUdUddYdUIYdYdYFIFIFdcdcdcddcbWXNYO', 'UUdUdbdbdbdbdbdbdOdbdbVbVdUTdTd', 'aDPCCaXC', 'MFgJV', 'aAEGZRgYMYMJSZSZSZSZQ', 'aM', 'aM', 'aCDhPDCCD', 'CBDZQEGRCDh', 'aCYMDCEG', 'aDXCMDC', 'CDBQCDh', 'UUbTbdTdIdcdcbWXda', 'Mg', 'OJOJOJOJOJOJOJOVJOJOJO', 'aCPDhBQCDCD', 'agME', 'CCDhDCD', 'aVaDC', 'CBQCDDh', 'YDCDUUhIBYUZQYUadadcabWXUdiDC', 'aDhBQgMCDC', 'ahHTBaDPCCD', 'aTV', 'MJV', 'UUdZTdbdTdTdbUd', 'aPC', 'aPC', 'gMga', 'aNONOUaUPVPV', 'ajPVPiCXNTZRcJbW', 'aJVM', 'aPaC', 'aPC', 'aDhPDCCDC', 'UUYYUOP', 'aFaFWFYda', 'aATaC', 'ajYPVPVPV', 'A', 'YVbTUIFIddUbWXaNP', 'YdcdaVbWXacadicdcgJdVc', 'BQAGE', 'aM', 'ChD', 'aGPDCCE', 'DBh', 'adda', 'ahghgMgM', 'aPTPTC', 'aPFC', 'YXijP', 'aFYM', 'aPDCCDh', 'ghBQMCDaCD', 'aCDCDX', 'ahMgbTS', 'YaYaYaPIcdcdcbWXVUidJPV', 'a', 'T', 'gDhaBMMgCDCa', 'DCDh', 'aCDPDCCD', 'aPZC', 'TUIFdcdcbWXdNP', 'YPVZRj', 'aUPUY', 'YJVdUIdTddcdcbWXig', 'aMJV', 'aSPTPTPaC', 'aJVEPGVQQE', 'YUVYdUdIFcdcbWXNO', 'aDXSZSZSZSZSPDaCC', 'gEJhBQ', 'V', 'aTZTZTZTZTZHdZTZTZ', 'VHFacdcdcdcdcZdcUbZWUZUXTZUTNOZVTUTZI', 'aDCDhPDCC', 'YPVaUdUYIUcdcdcbWXdi', 'aScbWUXcdciScScj', 'dZTZaCVPa', 'CQEDhB', 'gGaQgMeLKLKLKLKLKLKLKLKLKLKE', 'aBQaEPDTPTPCUCh', 'dbaWFbWbWbUTdZITdcdcabWiIHP', 'CBDQCDh', 'aYUPOTSPaCa', 'UQbWEXJcNfLKLKLKLKLKLKLKLKLKLKEG', 'aPDChaC', 'CBQDCDh', 'bCDhBQYbTdZRWJbWbiU', 'aPTPC', 'CDCXiXP', 'aDFaCFaFaFDUhPTPDAPCC', 'aTZC', 'agMPV', 'a', 'ahBPDCACDC', 'aPC', 'aVTPVTVTVPa', 'aGPDCCE', 'CDhCDDC', 'aPDhCQ', 'gAGhRgMageaBeBhBhBheh', 'UaAGgcMeKLKLKLKLKLKLKLKLKLKLKLE', 'aDXUYiCDC', 'agYM', 'aPjaC', 'YbdbdbdbdbdbbbdbdTbd', 'UTdTdbdTdTbdTUbdbdTdbTbUddbdTdU', 'aPSaC', 'aPaC', 'CDChB', 'aYPVPVj', 'YCDhBQdFcdcdcbWXiIDCD', 'aPiC', 'dITdcUdUdbWXUijP']]
#
#
# Recording Date: 03.07.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aJMV', 'aGUdUdUIddcbWXTdiYgd', 'OOJJOJOJOJJOJOJOJOJOJOOJOJVJOJOJOJOJOJOJOOJ', 'CDh', 'UJVSZSZSZSBQIdFaVaYcbWXig', 'aPaPaPaV', 'ChB', 'aUYcdcbWiJPY', 'aVPaZd', 'a', 'aPaMJPaV', 'aPC', 'aV', 'MCDJCVDhZWRbcbWig', 'a', 'CZQDhB', 'aUOZSZSZSZSZQY', 'aBMCZQDh', 'CDCEG', 'aVTC', 'aTZC', 'ahPADaCCD', 'abdbddbdbdbdbdT', 'YUjPVP', 'aPZC', 'YUjPVPV', 'aBQEGZRbgMh', 'aJVM', 'aDPDaCC', 'aJVM', 'ZVTZWZRWRYcbWjU', 'gFGPGPGVZRFJbWiPhghghghghghghghgEAG', 'YPVPVcYcYcF', 'UdYUdUTPIdcdcdcbWXUUdUdUdiYTdT', 'VUdAUGAGdTdTdTZRcbWjTPVdWR', 'YiXPVP', 'aJFYaYPc', 'aPDCSPSPaDhC', 'aPDCC', 'ZTZTZTZSZSZSZZSZSTZQZTaZTZ', 'aaYVPaVPVaVj', 'aJVM', 'UUaYVYUSPaY', 'UUTbUZTZdRUdJbWiaP', 'aPCPa', 'aPPa', 'aPAaC', 'aDhPDCC', 'VYPVPVaVajVa', 'ahDPCaCD', 'aPaC', 'aDCDhPDCC', 'aPaC', 'UDCUUdUdDCUdIcNcdcdcdcbdWUXdYiUdUdC', 'CDX', 'ahBQCMDCD', 'ajYaYPVPV', 'aCdadaPa', 'aUTYUTZUZUZUZUTUZTYZHUYUYUaU', 'YFPc', 'aGPTPTPSDaCCE', 'aYPVPj', 'UUjYUY', 'MYJV', 'aUTM', 'aPDCC', 'UTbaTZdZRUdU', 'ahPTDPaPaCCD', 'aVYMgMgFaJV', 'UTZTZOTaZTZTZH', 'VbWXaYicg', 'VYVYPVcJF', 'adMBQAGgha', 'dIdITUdYcdcbWXiP', 'aPDhaCB', 'aZTZUTZTZTZHYFaYcdcdcdJcbWXUTUNPZTP', 'dbdbdbJV', 'aPaCVPVPVPa', 'ahPDTPTPCCD', 'aYcYcbWViaXPVPVPYaYc', 'aaYbWjPVPcV', 'agcM', 'gBZQh', 'aBgQMhgh', 'aBZQPaDCh', 'aDCBMCDC', 'MGZRJbWFJFjPgE', 'VYSaZSZSZSZQdVYYUOa', 'aPCVPa', 'YaUSdcSdcScSdcMbWXN', 'UUYOcbWFj', 'CDX', 'ahPDSTPCaCD', 'aYPVPVPj', 'abaVab', 'aOSZSPDTPaCC', 'aPC', 'aJVM', 'adVcdcdcdJ', 'aXiXNiXNXNXNXNWiPY', 'ajJPVPY', 'aYUO', 'adadUdUYjSa', 'aCPaPSZaZa', 'aVJbJUaUTaUaUaYM', 'aYUYbUIYUYUddcdcbWXNV', 'aUPY', 'ghB', 'aBMgh', 'aGPCDCE', 'aJMV', 'aBPDGCCDh', 'aCDPDCCD', 'adUdUdUdUdVbdbdbTbdbTbdbdbdbdbJIJITPFdcSdcbWXaNUdU', 'UUOYUYUYV', 'aVJMV', 'aGMCDCE', 'aPDSahC', 'CDh', 'Ta', 'YJaYMaUFj', 'a', 'PF', 'VYPVPcYcF', 'aDhBQPaDCC', 'aGPDaCCDh', 'aUYTZWRbWi', 'aFgGAGIdcdcdbWXUdUdUdij', 'aDCDhPDCJPANC', 'YVUFjY', 'aDPDSCPSaC', 'aPSPSaC', 'UUOYQ', 'aDhPDCC']]
#
#
# Recording Date: 03.08.2024
# 1xN cell array of mapped syllable orders for the day:
# [['aMYUV', 'aBMgh', 'aUY', 'aEAa', 'aPSPSPPTa', 'MJCDhbdIbWXi', 'aDCDhPTDCC', 'WdUddUIdVdcdcbWXUdiPVPVPVPU', 'dTbIbIdcdbWAWAWAWiUPVPV', 'YUjYUYUYPVPVPUY', 'aiYVcJaSZSZSZSZSbZQW', 'bZTZCd', 'aBZQEGPgahM', 'ahBQEGVZRbDCCUaDUC', 'aPCVPa', 'aDPDCC', 'MgTZTZTZTZTZSZSZSZSZQ', 'aDCVDPDCaC', 'abWXYadcScSNc', 'adgcMh', 'aVCMDXiP', 'aPZC', 'ajYPV', 'YJcFJFYVYJVVc', 'CDCXiX', 'aPC', 'gQaYCMDhB', 'aJVM', 'UUUaFjYaaUYaUa', 'aYMYMYMYMYMYMcYM', 'aVAaAaAa', 'ddcadcI', 'aJVYM', 'YUj', 'aDPCCVDhKPDCaV', 'gQEGDhCB', 'aaKLKLKLKLKLEGAGdIUdYdcbWXNUfLKLKLKLKLKL', 'CCEGD', 'VIdUddcdcbWXUiPV', 'aId', 'ahBQMCDCD', 'aIWIWIWIMadcd', 'aDhPDUCUCC', 'aDhBQPDCC', 'aDCDCDChgCMDC', 'abMbEQMQM', 'XbWXdjXdciCDCYFE', 'aUVaQYaY', 'VPYj', 'aDhPCDC', 'CQDhB', 'adIdcdcdcdcdcYdYbW', 'aQPDCECG', 'aDhBQAPDCC', 'ChBQEDGQCD', 'YUdUbIdUdcdcbWXNij', 'aJVM', 'ViZPTVPZIUTFIYIYcdcbWbUTTVUTZRUTbW', 'aPbT', 'aDCDhPDSPCaC', 'daZTZTZTZdTZTZSZSZSZSZSZQ', 'VaIUddcdcbWXig', 'aM', 'ajY', 'aUdYdUFjFj', 'aPDCaCh', 'a', 'aVTVa', 'UVUYUYUYUYUYUdcdOcdcdcY', 'aBQgMh', 'dbdIcdcbWXiP', 'aYjP', 'aTZTUCUTDUTCZHjFjFTZUZ', 'aTUTUTZTVITUdUddUcTUbWXdUdUdUdNTVZTU', 'FVPVcYcFY', 'aDhPDCC', 'GMGAGQa', 'aDCPDhDCC', 'VjYaVaPVPV', 'dbdbdbdbdbdbdbdbdbTbTbdTdbdbdTbdbdbdbdbIUd', 'a', 'aPaPCPa', 'VTYUJYIddcbWXNVUdU', 'CDCE', 'aDhPDTPCC', 'aCJSTPDaCaCAaAa', 'aFJVM', 'VDCUYUIdbWYXdiYDC', 'CBQDCDh', 'a', 'aVaVa', 'aPTPaC', 'abYbYdYdYdYJYJbJbWgagaFaFadYcdcUYOcUOcYOcOcOcOcJg', 'aUd', 'aCMDX', 'adadaaTZCYaYM', 'UUYFjF', 'gDhBQCDC', 'aTZTbZHTbWbZTTZUZUTZRZTZ', 'aPaCDaUCUCCX', 'aDhPDSPSCaC', 'a', 'UYbYbYbYbYbXYbYbU', 'ajPVPVYaY', 'aTdIdcdcbWXig', 'aUUYUYUYSUaUaUYZUSYZSZS', 'aWPTPaC', 'gJbJbWUgYUYMVGaZR', 'YGZRJbJbWUjE', 'ahBMFgFg', 'CDCEG', 'ahBGPaCDC', 'aTZa', 'aDhPDCC', 'UPUUaUaaUOY', 'aTZTZTZBQZQEGIaIaMdTgZTZhTZ', 'aMaM', 'aWa', 'aMJVMa', 'aIdFIcbWUXdUdUdig', 'aDhPTPDaCC', 'adIaIaIaI', 'VJVaM']]
#
#
# Recording Date: 03.09.2024
# 1xN cell array of mapped syllable orders for the day:
# [['gaMghghghghghghghghghghAGhR', 'aPT', 'abWXSciP', 'AGhR', 'aPVadbdOdbdbdbPdbdbaV', 'YRAGVQEdGaAGAQEadWIJWIVadcdcOcOJbWUXdiPVPV', 'aDCDhPTDSPSPCC', 'aPaPCdZaTaV', 'aBQEGCdcdMDh', 'VMYFJVYaYa', 'aPWbWbWbWbWbWbaWTSZTSIPa', 'aPTaC', 'YUNO', 'DBCQDh', 'ajdY', 'cbWXdcNfLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKEQ', 'aPC', 'agMGQ', 'TVYUIdcdcbWXdUdUdaVaVa', 'adWaSaWbWbWbWabWbWaSbcNPZPZaPZaTSaWbTSa', 'CBDh', 'aZSZSZQYMCDXNVSZS', 'YAEAYGhRbWbiQMREGQa', 'aPFC', 'aUUYUYOJVa', 'aFJVM', 'CDDACGhRDC', 'aDhMCDC', 'aJWHYMFaTZTZTZTZSZSZSZQ', 'aijY', 'VVYajFYPa', 'THZWHWbWbTZTTZZTVRbJbWSZHWHW', 'ajPVPVY', 'aPVPVUdYabdbIYFcaYXVXVXai', 'aTPTPSZC', 'aPTFaC', 'adadVTPa', 'aM', 'aba', 'aPFJTPaM', 'aTUC', 'aM', 'YUVdUddUbdUdTUdZRUdbWbWbiaYaUd', 'aPbSa', 'aYYMVaMTZRbWbWi', 'VbWXSUdScSdcNadc', 'a', 'aaYMUaUJVTVP', 'WPUbdIdcdcbWUdbUdUbTUbZVZVJRJRbbWbWi', 'agM', 'aTZVIYcNdcdcdcbWXTdaTUZUTZUZU', 'YYbWXVciYVYPVYV', 'adadVPaVPVaMgGZQIRddcJcabWbXbXb', 'UYUFj', 'aPDSCCX', 'Cj', 'aMFMFVPa', 'aPZQVPaV', 'bUYdbdbdbdbIdFOJOcScbTWUbWTXUbdidbdP', 'aDhPDAPCC', 'YFbWiPVPcVYFJVZR', 'UbOdbdbdOdbdbdbNdbdNObdObdbdbJbdbdbdbdbdbdbddbdbUdbUdNdNdbdbdbObOdbdbOd', 'bPVPUdbdIUdUcdcdcdYbWXi', 'ahBQIPDCC', 'adUdIUFIcbWXdadiPV', 'aaCaCagaMaMQMQMQMQE', 'Yj', 'aJPJY', 'bdPVbdbdbdbdbdbdbTdTdTbTbTSaTZdaUdU', 'PVdIUdFIUcddcbWXijT', 'a', 'CDDhBQCDC', 'aVPaMFJdVa', 'aBaWPaWbWb', 'aEGAGAGPTDPaCC', 'aDCDCMDC', 'aTSTSTSaC', 'aDCJFjJjCMDC', 'aDhPDTSaCC', 'CBAGDh', 'gDhdCcaFaMDC', 'aM', 'aVa', 'gGMCDCaE', 'aDPCDhSPDCC', 'YjPV', 'aPTPTSTSPSPSPSaC', 'diYjUYUYUdUdUTUTZTZHYWFWFbWbdTYUYUZRbW', 'aUbJbWIdUdUd', 'aYFJM', 'ICDIUdUdYcYcdcdcbWdXiCD', 'aaSabTW', 'adaPaTdZ', 'aDhPTSPDCC', 'Yj', 'aAGhRbMgh', 'aPTC', 'CDhBQDC', 'ahBABQEGCMDCD', 'a', 'aVjaY', 'YYaYcMbWaYXiaXP', 'aGCMDCE', 'aWWbWSdWZdSZdSdSTSTdSTdSdSdWaTaPTaa', 'aPDTPTPaC', 'aAa', 'aaYbYbVPTZaZaUdUd', 'VbWXcScScaScSNVcaO', 'abWbYMTWVWVWR', 'aaCaCPTPaC', 'aYUYUYYbWXUYUYUYUMiP', 'aDhPDCC', 'MZSZSZQMagFZSZS', 'aaPCdaVP', 'DECG', 'aUYjP', 'aMPGada', 'aM', 'adZdZTId', 'aPZC', 'a', 'aDCPSPDCC', 'aaZTZTZTZTZTdZTZSZSM', 'aYaYdIcdccXi', 'aCAdaDTdTahdZT', 'adgaYM', 'aDhPCDC', 'ahCMDC', 'aPCSa', 'aZTZTZTZaTZTZTZPTabZT', 'aYM', 'DDhBQDCC', 'CCED', 'aDCFaFFNPSPDaCC', 'aUjFjYPVPV']]
#
#
# Recording Date: 03.10.2024
# 1xN cell array of mapped syllable orders for the day:
# [['abWXUcNSZSZSZS', 'aVPaVPZQaYadcdcbWXPSZa', 'aPaCAC', 'CDADC', 'CDhBQDC', 'agCSPaCa', 'YUddUdUdIUdUdUTUdcdcdcdTXdUdiP', 'CDXiP', 'CDCEG', 'bTTdTdbdTbdbdbdbdbdbbUbdTUdUdTUdTdUUdUd', 'YUIdcdcdcbWXiV', 'aPaC', 'CGhRIDA', 'aTVaAaAaAaPa', 'dTdTdTUbdbIdTFdITcdcUdcddcdX', 'P', 'ViYijY', 'YUVSZSZSZQO', 'DBDhC', 'Vd', 'YYUFjPU', 'aPC', 'YbcWUXcUVUiVVcPVPS', 'CADGhRCD', 'abWXicdcjJg', 'PJPVaVMVVaPYIMYMYMYMYMdcdcbWXi', 'aPAC', 'YbJbJbWUTVUTZUZUTZVZTVTZHFbWbTZR', 'aPaC', 'aPVaPCPa', 'SIaIaIddccdcdcdcdcYcXScdcdcdicdcddS', 'CEG', 'ZdabVTZdTZTZTFZTZIca', 'YZTZTZTZTZTZHa', 'CEG', 'adadZTZC', 'aUUTZTZYSZG', 'aiPVY', 'aJVM', 'abUTadZVZVZVR', 'aYigYa', 'YYUYUNONONOa', 'dZTZC', 'aPC', 'VWXaUcUcUciVPb', 'CDAGhARDC', 'UUOYa', 'aWiYJcYcdYcYcYcdcb', 'aDhYCMDC', 'cbPWXiPVaTZRcbWj', 'aCPaVP', 'aYigG', 'TP', 'aPaDC', 'YaPWHaYYaaWFWFbWTbYUTTaUZUZRTiUYTPZV', 'aVPVM', 'aYjPV', 'aCPPSPSPDCCgCgaga', 'aSTPZaCaCaCaCaC', 'CDADC', 'DACD', 'P', 'adZdZTZaTZTZTZTZTZTZSZSZSZQdcM', 'VUPdTVVRYcbWaFjY', 'aDhBQPCDC', 'adUUZUadUY', 'YUbWcbWbdIFIdcdcdcYUj', 'a', 'IIdUdUTdFIdbdcbWiUXO', 'aZTZTZTZdTaZTZHdadaY', 'dOaYQ', 'CDGhRCDCA', 'VZSZQicXOYbWVSZSZS', 'abWXSdSidcScJbJb', 'YIUYUYUFIcbWXdNOQ', 'abdbdbddbZTdTdZd', 'YUFjPVP', 'aCPaZWZGP', 'ha', 'aYOTZRFJbJbW', 'aUYOSZSZSZSZQY', 'aPTPTPaAC', 'aPaC', 'ViXNYSZSZSZSZQ', 'aYaYUYUYUWIdcbWd', 'aFTZaM', 'aZTZTZTZTZMSZSZSZSZQ', 'adadbI', 'VZSZSZQaYcbPWXVQNOSZS', 'abdbdbd', 'aPVQV', 'aPTPTPTPDSPSUC', 'aAaAaAbPAa', 'UOYUYdU', 'aaCVPaV', 'VaXScSdcSdicPbW', 'aBcMgh', 'dUbdT', 'aDAPDaCC', 'aOUQY', 'AGhR', 'aPaC', 'hgBhQEG', 'aPaCaCVPa', 'TVHZTFbWbZTTbTbdTbTbdbIZTFIFIFScScScScScScScOJOJbcZJMT', 'YiP', 'ahBiYiYg', 'aPC', 'aYjPVPV', 'a', 'ChBD', 'aPC', 'VbcWXSciPVP', 'aUUTbTZTbHFbWYb', 'aVPaCJdY', 'aUUaUVYUY', 'YaVPHaaYaYcdcbWXViIQYP', 'aPaQVPaV', 'YYAGAQUTUTUTZTZVHaIYcbWaYbaTZRYa', 'aDCPSDaCC', 'aPC', 'aYMFa', 'aZbTdUVZbVZQUaTdUTZTZT', 'aPaC', 'gDhPDACCda', 'aZTZTZTZTZTZTZTZTZTZQPaP', 'aPa', 'aPDaCCaEC', 'aYjPVPV', 'TUTUIVTUTdFIdcdcdcdcXiJiJPVPT', 'YiP', 'YUFjP', 'UYUYUYTUTbIdTUFIcdXdTidTdTPdVPVPTd', 'aPaC', 'abWiYc', 'YUFjP', 'CXEGQ', 'aJVM', 'YdUIcdcdcdXdi', 'YaMFJVaP', 'aVTPPJba', 'dPVaQIVaPaV', 'YUTUdTaIFYdYdTcdcdcdcYUUTjaUT', 'aPC', 'adUhghBdUdUbIdQUddcbWijg', 'aYaYMUcbWXiP', 'aYdTZTZMTZTZTZTZWH', 'YSbWbcdcT', 'aJaC', 'UYUYUUYOaUYU', 'aOJQaMGaYU', 'aJYMSZSZSZS', 'aPC', 'T', 'VbWaVXcdcdcdcigVGAGAG', 'YYaUYTaZRbWiPVP', 'CCEGD', 'CACDD', 'aPaZQVPadV', 'YjPV', 'YjVPVY', 'aUY', 'CDADC', 'aVa', 'aPVPVPYMAEGRbWi', 'adcdSIcFaFaIFYcdcbWXiJPSdcVP', 'aYMFJV', 'adadadadbdbdbVPada', 'ajMFTUaTbTZTZTZTZHWFbWbTZVZWRbJbW', 'AGhIQIQRQRQR', 'aVPY', 'CDXPV', 'aPC', 'aZPZTZCPaP', 'abdUabdbdTZTZTZTZTZaHPTPa', 'VYViXaVaVaNOYa', 'UYcF', 'YUXdUdig', 'aMQ', 'aUPVY', 'aDPSDPaCC', 'aPSPSPaC', 'aSbZIHWHWHFbWbUdbdbdbdbdbadJdJdbdbdbdbdbdVbTQAGAGZT', 'aJPVPVY', 'aVPVQ', 'bPCa', 'DEGC', 'acBCQMDh', 'ajYP', 'aTPhaCDC', 'UIdUdcdcScdcdcddcdcdcXiTdPV', 'VFaFYcYcdWYWXPViQPV', 'TVPVPV', 'CCjD', 'bZJPTVZIWHFbWabbaZTTZRbWZUZiUZUZTT', 'UTdbTbTdbdbYTbTZTZTdZHTFbbUbPTPdbdTdb', 'aGAQRQRQPRQRQRAGaPaZDTAZC', 'aXNVcYcbWY', 'ahYBig', 'CDXiSZSZSZSZSZ', 'aPVPVPaPCPDXai', 'YUYUIYdUFIcdbWXiPV', 'aYjPVPVPV', 'abWXdadcdcVdcdc', 'dSZSZSZSZSZQTETdUGdTdIFdIFcdcTdcdbWXdiU', 'dTdITddcTbdWXiTdPV', 'aUNONONOYSZSZSZS', 'aDAPGhRDCC', 'bPdPWHWHZWbWbWbTUTdbdbdTTUTZRbF', 'aIUdcdXNd', 'UUiPY', 'aDChEMCDC', 'aPTaC', 'aPPDCC', 'VdcdSIcdcFIFIYdYdYdcdcdcdcbWXdcNa', 'CGhQRQRDA', 'adYbdbdbdbdbUITFIFdcSdcScdcdcbUWidaPVPV', 'aUjYP', 'VKEGbdbdbdbdbTbTVIWIWIPcdcdcbWXaNYdUdfLfLKLKLKLKLKLKLKL', 'aFJVM', 'aUYNOQ', 'CDhBDAGAGZIRFbC', 'adaddaCcacYEMYMaG', 'aPJVaYM', 'aYUOUSZSZSZSZQ', 'YiX', 'UUOYJOJOV', 'aSPSPTaAC', 'UUY', 'adZddaVPa', 'UUYaF', 'adadaZaZaZTZC', 'UagUYMGAGZRJb', 'baZTSTSTSZTHbWbZTZTZTZT', 'aDCPhDCC', 'abdbdbdbdbdbdbdbdbdbUVTZTZdTUZTHd', 'UaUNaUYU', 'djYPVPU', 'CDhAGhRAGDC']]
#
#
# Recording Date: 03.11.2024
# 1xN cell array of mapped syllable orders for the day:
# [['VdcYbWXcYcigFAGZQ', 'UUYVGZRbWiPO', 'GI', 'aUTZTZadTZUdTZaTdZaUaTUZaTUaUZHaUY', 'aPC', 'aJVM', 'aVTVTVTVTVPVQ', 'adadad', 'YUdUIdUdYdcdcdcUNONONO', 'aiYP', 'CDAGhRDC', 'abIbIbYaTYdcOc', 'aC', 'dcdcdcdTIcdcdcdcdcdcdcdcdbd', 'CDCEG', 'UYjFgUTUTVTUTVIdcdcdcbWXi', 'ZbiJPYaMYFMVFVFVFVFTbUTZTZUTIHFbWbTZRJbW', 'aPTaC', 'VGAQbdPbIFIcYcYXaiTdTdTdUgd', 'aCPDCaAaACD', 'abdbddTdTd', 'VUSZSZSZQdEYhEhEGZURbWFiPIVUVFIYSYdcdcdcdcdcYUUaNOY', 'aPaC', 'dIaIdcdcbW', 'aYJM', 'aGhRYMCDCA', 'aJMV', 'YPVPVJIJIRbFAWFWFWUVTVdUaTdVTVTVTPJHFIYcbWi', 'YYUUajPVP', 'aV', 'MSTSbcbcbcScScScOcOcbcOJbIT', 'ChBDQCDC', 'aZTZTZTZTZTZTZTZTZHFaYMdcdcbW', 'aUdIFcXUdUdiUdUdPVP', 'aaPCVP', 'aBQcgMe', 'YYJMVUaUYONONOM', 'aYaCMDCDX', 'CDCDDhBQC', 'UUJPVPVY', 'aZTZTZTMZTZTZSZSZSZSZQ', 'aPaIaVYPUdZTZTZTZaV', 'aVaTZTZPaM', 'daUIdcbWYYNONOd', 'abWXcdcSPdcVPVdc', 'aM', 'YTUTdTddTIUTUdUdcdcdcbWXNV', 'VJVSZSZQIQIcYF', 'YUPVPV']]

# %% [markdown]
# ## Save into three groups with an equal number of songs in each:
# 1) 3.5k songs post-lesion
# 2) 3.5k songs from immediately pre-lesion
# 3) 3.5k songs from earlier pre-lesion recordings
#
# From TG: "Any comparison should have a balanced number of songs."

# %% [markdown]
# ### First, make sure each song contains at least 2 syllables (this is likely just a trill that's been marked as a song).

# %%
# Assuming the syllables for each song are stored in a column named 'syllable_order'
# Replace 'syllable_order' with the actual column name if different.

# Define a function to count the number of syllables in each song
def count_syllables(row):
    # Assuming the syllable order is stored as a list in the 'syllable_order' column
    return len(row['syllable_order'])

# Apply the function to create a new column with the syllable count
organized_data_frame_with_orders['syllable_count'] = organized_data_frame_with_orders.apply(count_syllables, axis=1)

# Filter the DataFrame to only include rows with 2 or more syllables
filtered_data_frame = organized_data_frame_with_orders[organized_data_frame_with_orders['syllable_count'] >= 2]

# Drop the 'syllable_count' column if it's no longer needed
filtered_data_frame = filtered_data_frame.drop(columns=['syllable_count'])

# Display the filtered DataFrame
filtered_data_frame
# Out:
#                                      file_name  song_present  \
# 0        USA5326_45324.28882476_2_2_8_1_22.wav          True
# 1       USA5326_45324.34642642_2_2_9_37_22.wav          True
# 2        USA5326_45324.34922587_2_2_9_42_2.wav          True
# 3        USA5326_45324.29466848_2_2_8_11_6.wav          True
# 4      USA5326_45324.37364950_2_2_10_22_44.wav          True
# ...                                        ...           ...
# 8002    USA5326_45359.34421464_3_8_9_33_41.wav          True
# 8003   USA5326_45313.31158371_1_22_8_39_18.wav          True
# 8004  USA5326_45313.41676612_1_22_11_34_36.wav          True
# 8005  USA5326_45313.41798028_1_22_11_36_38.wav          True
# 8006    USA5326_45359.24435593_3_8_6_47_15.wav          True
#
#                              syllable_onsets_offsets_ms  \
# 0     {'35': [[0.0, 83.65079365079366]], '31': [[83....
# 1     {'31': [[0.0, 32.38095238095238], [1443.650793...
# 2     {'32': [[0.0, 129.52380952380952]], '30': [[12...
# 3     {'10': [[0.0, 1457.1428571428573]], '11': [[14...
# 4     {'34': [[0.0, 62.06349206349207], [2517.619047...
# ...                                                 ...
# 8002  {'32': [[0.0, 188.8888888888889], [2533.809523...
# 8003  {'32': [[0.0, 393.968253968254], [747.46031746...
# 8004  {'32': [[0.0, 97.14285714285715]], '30': [[97....
# 8005  {'32': [[0.0, 2.6984126984126986], [5.39682539...
# 8006  {'28': [[0.0, 72.85714285714286], [2501.428571...
#
#                        syllable_onsets_offsets_timebins Animal ID        Date  \
# 0     {'35': [[0.0, 31]], '31': [[31.0, 72], [112.0,...   USA5326  02.02.2024
# 1     {'31': [[0.0, 12], [535.0, 579], [608.0, 643],...   USA5326  02.02.2024
# 2     {'32': [[0.0, 48]], '30': [[47.99999999999999,...   USA5326  02.02.2024
# 3     {'10': [[0.0, 540]], '11': [[540.0, 990]], '7'...   USA5326  02.02.2024
# 4     {'34': [[0.0, 23], [933.0, 1004]], '35': [[23....   USA5326  02.02.2024
# ...                                                 ...       ...         ...
# 8002  {'32': [[0.0, 70], [939.0, 940], [941.0, 942],...   USA5326  03.08.2024
# 8003  {'32': [[0.0, 146], [277.0, 282]], '0': [[146....   USA5326  01.22.2024
# 8004  {'32': [[0.0, 36]], '30': [[36.0, 351]], '8': ...   USA5326  01.22.2024
# 8005  {'32': [[0.0, 1], [2.0, 3], [15.00000000000000...   USA5326  01.22.2024
# 8006  {'28': [[0.0, 27], [927.0, 1051]], '32': [[27....   USA5326  03.08.2024
#
#      Hour Minute Second                                     syllable_order  \
# 0      08     01     22  [35, 31, 26, 25, 32, 15, 26, 32, 33, 29, 33, 3...
# 1      09     37     22               [31, 26, 31, 26, 31, 26, 31, 26, 32]
# 2      09     42     02  [32, 30, 27, 30, 27, 30, 27, 30, 27, 30, 28, 2...
# 3      08     11     06                             [10, 11, 7, 1, 31, 23]
# 4      10     22     44  [34, 16, 13, 16, 13, 34, 33, 29, 3, 8, 12, 35,...
# ...   ...    ...    ...                                                ...
# 8002   09     33     41               [32, 35, 16, 32, 16, 32, 16, 32, 16]
# 8003   08     39     18    [32, 0, 26, 33, 27, 33, 27, 32, 33, 26, 25, 26]
# 8004   11     34     36  [32, 15, 9, 15, 9, 15, 9, 13, 6, 10, 11, 7, 1,...
# 8005   11     36     38  [32, 28, 34, 17, 28, 28, 13, 22, 28, 34, 35, 3...
# 8006   06     47     15                                [28, 17, 28, 32, 2]
#
#           mapped_syllable_order
# 0           dZTSaHTabWbZTTZTZZT
# 1                     ZTZTZTZTa
# 2          aYUYUYUYUYVTPTSZSOZS
# 3                        CDhBZQ
# 4                cIFIFcbWXiEdVG
# ...                         ...
# 8002                  adIaIaIaI
# 8003               aATbUbUabTST
# 8004           aHjHjHjFgCDhBQiY
# 8005  aVcJVVFPVcdYVJaHaFbVaVTaV
# 8006                      VJVaM
#
# [7744 rows x 11 columns]

# %% [markdown]
# ### Figure out how many songs to include in each group:
# 1) Check the number of post-lesion songs, and the number of pre-lesion songs.
# 2) If the number of post-lesion songs is less than 1/2 of the number of pre-lesion songs, use that as the group size.
# 3) If the number of post-lesion songs is greater than 1/2 of the number of pre-lesin songs, use 0.5*the number of pre-lesion soongs as the group size.

# %%
# Function to calculate group size based on pre- and post-lesion song counts
def calculate_group_size(organized_data_frame, surgery_date):
    # Filter the DataFrame for songs recorded before and after the lesion date
    pre_lesion_songs = organized_data_frame[organized_data_frame['Date'] < surgery_date]
    post_lesion_songs = organized_data_frame[organized_data_frame['Date'] > surgery_date]
    
    # Count the number of pre-lesion and post-lesion songs
    num_pre_lesion_songs = pre_lesion_songs.shape[0]
    num_post_lesion_songs = post_lesion_songs.shape[0]
    
    # Determine the group size based on the condition
    if num_post_lesion_songs < 0.5 * num_pre_lesion_songs:
        group_size = num_post_lesion_songs  # Use the number of post-lesion songs as the group size
    else:
        group_size = int(0.5 * num_pre_lesion_songs)  # Use half the number of pre-lesion songs as the group size
    
    # Print the results
    print(f"Number of pre-lesion songs: {num_pre_lesion_songs}")
    print(f"Number of post-lesion songs: {num_post_lesion_songs}")
    print(f"Calculated group size: {group_size}")
    
    return group_size

# Example usage
group_size = calculate_group_size(filtered_data_frame, surgery_date)

# Function to calculate group size based on pre- and post-lesion song counts
def calculate_group_size(organized_data_frame, surgery_date):
    # Filter the DataFrame for songs recorded before and after the lesion date
    pre_lesion_songs = organized_data_frame[organized_data_frame['Date'] < surgery_date]
    post_lesion_songs = organized_data_frame[organized_data_frame['Date'] > surgery_date]
    
    # Count the number of pre-lesion and post-lesion songs
    num_pre_lesion_songs = pre_lesion_songs.shape[0]
    num_post_lesion_songs = post_lesion_songs.shape[0]
    
    # Determine the group size based on the condition
    if num_post_lesion_songs < 0.5 * num_pre_lesion_songs:
        group_size = num_post_lesion_songs  # Use the number of post-lesion songs as the group size
    else:
        group_size = int(0.5 * num_pre_lesion_songs)  # Use half the number of pre-lesion songs as the group size
    
    # Print the results
    print(f"Number of pre-lesion songs: {num_pre_lesion_songs}")
    print(f"Number of post-lesion songs: {num_post_lesion_songs}")
    print(f"Calculated group size: {group_size}")
    
    return group_size

# Example usage
group_size = calculate_group_size(filtered_data_frame, surgery_date)
# Out:
# Number of pre-lesion songs: 4329
# Number of post-lesion songs: 3234
# Calculated group size: 2164
# Number of pre-lesion songs: 4329
# Number of post-lesion songs: 3234
# Calculated group size: 2164

# %%
def filter_post_surgery_songs(organized_data_frame, lesion_date, group_size):
    # Filter the DataFrame for songs recorded after the lesion date (post-lesion)
    post_lesion_songs = organized_data_frame[organized_data_frame['Date'] > surgery_date]
    
    # If the number of post-lesion songs is greater than or equal to the group size,
    # select the first 'group_size' number of rows (songs)
    filtered_songs = post_lesion_songs.head(group_size)
    
    # Print the results for verification
    print(f"Filtered {group_size} post-surgery songs:")
    print(filtered_songs)
    
    return filtered_songs

# Example usage
group_size = calculate_group_size(filtered_data_frame, surgery_date)  # Calculate group size
post_surgery_songs = filter_post_surgery_songs(filtered_data_frame, surgery_date, group_size)
# Out:
# Number of pre-lesion songs: 4429
# Number of post-lesion songs: 1771
# Calculated group size: 1771
# Filtered 1771 post-surgery songs:
#                                     file_name  song_present  \
# 3437   USA5509_45416.47364572_5_4_13_9_24.wav          True
# 3438  USA5509_45416.47436330_5_4_13_10_36.wav          True
# 3439  USA5509_45416.47541692_5_4_13_12_21.wav          True
# 3440  USA5509_45416.47690761_5_4_13_14_50.wav          True
# 3441  USA5509_45416.63943551_5_4_17_45_43.wav          True
# ...                                       ...           ...
# 5789   USA5509_45433.6200445_5_21_1_43_20.wav          True
# 5790   USA5509_45433.6311298_5_21_1_45_11.wav          True
# 5791   USA5509_45433.6328153_5_21_1_45_28.wav          True
# 5792   USA5509_45433.6379459_5_21_1_46_19.wav          True
# 5793   USA5509_45433.6410309_5_21_1_46_50.wav          True
#
#                              syllable_onsets_offsets_ms  \
# 3437  {'6': [[0.0, 277.93650793650795], [323.8095238...
# 3438  {'6': [[0.0, 89.04761904761905]], '11': [[89.0...
# 3439  {'6': [[0.0, 275.23809523809524], [831.1111111...
# 3440  {'6': [[0.0, 7650.000000000001], [7855.0793650...
# 3441  {'6': [[0.0, 253.65079365079367]], '4': [[253....
# ...                                                 ...
# 5789  {'3': [[0.0, 1198.095238095238]], '6': [[1198....
# 5790  {'6': [[0.0, 156.5079365079365], [1049.6825396...
# 5791  {'1': [[0.0, 35.07936507936508], [145.71428571...
# 5792  {'1': [[0.0, 196.984126984127], [277.936507936...
# 5793  {'6': [[0.0, 178.0952380952381], [887.77777777...
#
#                        syllable_onsets_offsets_timebins Animal ID        Date  \
# 3437  {'6': [[0.0, 103], [120.00000000000001, 129], ...   USA5509  05.04.2024
# 3438  {'6': [[0.0, 33]], '11': [[33.0, 731]], '16': ...   USA5509  05.04.2024
# 3439  {'6': [[0.0, 102], [308.0, 392], [442.0, 497],...   USA5509  05.04.2024
# 3440  {'6': [[0.0, 2835], [2911.0, 2936], [3342.0, 3...   USA5509  05.04.2024
# 3441  {'6': [[0.0, 94]], '4': [[94.0, 962]], '2': [[...   USA5509  05.04.2024
# ...                                                 ...       ...         ...
# 5789  {'3': [[0.0, 444]], '6': [[443.99999999999994,...   USA5509  05.21.2024
# 5790  {'6': [[0.0, 58], [389.0, 425]], '3': [[57.999...   USA5509  05.21.2024
# 5791  {'1': [[0.0, 13], [54.0, 125]], '6': [[13.0, 5...   USA5509  05.21.2024
# 5792  {'1': [[0.0, 73], [103.0, 174]], '6': [[73.0, ...   USA5509  05.21.2024
# 5793  {'6': [[0.0, 66], [329.0, 524]], '3': [[66.0, ...   USA5509  05.21.2024
#
#      Hour Minute Second                                     syllable_order  \
# 3437   13     09     24                                [6, 1, 6, 1, 6, 11]
# 3438   13     10     36                                        [6, 16, 11]
# 3439   13     12     21  [6, 6, 4, 5, 11, 5, 11, 5, 11, 5, 11, 5, 12, 5...
# 3440   13     14     50  [6, 6, 4, 6, 4, 6, 11, 12, 11, 12, 11, 6, 17, ...
# 3441   17     45     43                                      [6, 4, 2, 14]
# ...   ...    ...    ...                                                ...
# 5789   01     43     20                                          [3, 6, 4]
# 5790   01     45     11                                    [6, 6, 4, 3, 2]
# 5791   01     45     28  [1, 10, 8, 10, 8, 10, 8, 10, 8, 5, 4, 1, 6, 3,...
# 5792   01     46     19  [1, 15, 17, 15, 17, 15, 17, 15, 17, 15, 17, 15...
# 5793   01     46     50  [6, 4, 3, 2, 17, 15, 5, 15, 17, 15, 17, 15, 17...
#
#                                   mapped_syllable_order
# 3437                                             OBOBOD
# 3438                                                OID
# 3439  OOMNDNDNDNDNENENEDNDNDNDNDNOENENENDNDNDNDNDNDN...
# 3440  OOMOMODEDEDOJOJOIJIJIJOJMJMJMJMJOMOMOJOMJMJMJM...
# 3441                                               OMKG
# ...                                                 ...
# 5789                                                LOM
# 5790                                              OOMLK
# 5791  BCQCQCQCQNMBOLJHJHJHJHJHJHJHJHJHJHJHJHJHJHJHJH...
# 5792  BHJHJHJHJHJHJHJHJHJHJHJHJMLMLOLOBOMOKLJHJHJHJH...
# 5793                 OMLKJHNHJHJHJHJHJHJHJHJHJHJHJHJHJO
#
# [1771 rows x 11 columns]

# %%
# def filter_surgery_songs(organized_data_frame, surgery_date, group_size):
#     # Filter the DataFrame for songs recorded after the lesion date (post-lesion)
#     post_lesion_songs = organized_data_frame[organized_data_frame['Date'] > surgery_date]
    
#     # Select the first 'group_size' number of rows from the post-lesion songs
#     filtered_post_surgery_songs = post_lesion_songs.head(group_size)
    
#     # Filter the DataFrame for songs recorded on or before the lesion date (pre-lesion)
#     pre_lesion_songs = organized_data_frame[organized_data_frame['Date'] <= surgery_date]
    
#     total_pre_lesion_songs = len(pre_lesion_songs)
#     print(f"Total number of pre-lesion songs: {total_pre_lesion_songs}")
    
#     if total_pre_lesion_songs < group_size * 2:
#         raise ValueError(f"Not enough pre-lesion songs to split into two groups of size {group_size}. Total available: {total_pre_lesion_songs}")

#     # Select the last 'group_size' number of rows for the latest pre-surgery songs
#     latest_pre_surgery_songs = pre_lesion_songs.tail(group_size)
    
#     # Select the 'group_size' rows just before the latest pre-surgery songs
#     earlier_pre_surgery_songs = pre_lesion_songs.iloc[-(group_size * 2):-group_size]
    
#     print(f"Number of latest pre-surgery songs: {len(latest_pre_surgery_songs)}")
#     print(f"Number of earlier pre-surgery songs: {len(earlier_pre_surgery_songs)}")
    
#     # Create cell arrays (lists) to hold the mapped syllable orders for each group
#     mapped_syllable_orders_post = list(filtered_post_surgery_songs['mapped_syllable_order'])
#     mapped_syllable_orders_latest_pre = list(latest_pre_surgery_songs['mapped_syllable_order'])
#     mapped_syllable_orders_earlier_pre = list(earlier_pre_surgery_songs['mapped_syllable_order'])

#     # Print the results for verification
#     print(f"Filtered {group_size} post-surgery songs' mapped syllable orders:")
#     print(mapped_syllable_orders_post)
    
#     print(f"Filtered {group_size} latest pre-surgery songs' mapped syllable orders:")
#     print(mapped_syllable_orders_latest_pre)
    
#     print(f"Filtered {group_size} earlier pre-surgery songs' mapped syllable orders:")
#     print(mapped_syllable_orders_earlier_pre)
    
#     # Return the lists of mapped syllable orders for each group
#     return mapped_syllable_orders_post, mapped_syllable_orders_latest_pre, mapped_syllable_orders_earlier_pre

# # Example usage
# group_size = calculate_group_size(filtered_data_frame, surgery_date)  # Calculate group size
# mapped_post, mapped_latest_pre, mapped_earlier_pre = filter_surgery_songs(filtered_data_frame, surgery_date, group_size)
# Out:
# Number of pre-lesion songs: 4329
# Number of post-lesion songs: 3234
# Calculated group size: 2164
# Total number of pre-lesion songs: 4510
# Number of latest pre-surgery songs: 2164
# Number of earlier pre-surgery songs: 2164
# Filtered 2164 post-surgery songs' mapped syllable orders:
# ['gaMghghghghghghghghghghAGhR', 'aPT', 'abWXSciP', 'AGhR', 'aPVadbdOdbdbdbPdbdbaV', 'YRAGVQEdGaAGAQEadWIJWIVadcdcOcOJbWUXdiPVPV', 'aDCDhPTDSPSPCC', 'aPaPCdZaTaV', 'aBQEGCdcdMDh', 'VMYFJVYaYa', 'aPWbWbWbWbWbWbaWTSZTSIPa', 'aPTaC', 'YUNO', 'DBCQDh', 'ajdY', 'cbWXdcNfLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKEQ', 'aPC', 'agMGQ', 'TVYUIdcdcbWXdUdUdaVaVa', 'adWaSaWbWbWbWabWbWaSbcNPZPZaPZaTSaWbTSa', 'CBDh', 'aZSZSZQYMCDXNVSZS', 'YAEAYGhRbWbiQMREGQa', 'aPFC', 'aUUYUYOJVa', 'aFJVM', 'CDDACGhRDC', 'aDhMCDC', 'aJWHYMFaTZTZTZTZSZSZSZQ', 'aijY', 'VVYajFYPa', 'THZWHWbWbTZTTZZTVRbJbWSZHWHW', 'ajPVPVY', 'aPVPVUdYabdbIYFcaYXVXVXai', 'aTPTPSZC', 'aPTFaC', 'adadVTPa', 'aM', 'aba', 'aPFJTPaM', 'aTUC', 'aM', 'YUVdUddUbdUdTUdZRUdbWbWbiaYaUd', 'aPbSa', 'aYYMVaMTZRbWbWi', 'VbWXSUdScSdcNadc', 'aaYMUaUJVTVP', 'WPUbdIdcdcbWUdbUdUbTUbZVZVJRJRbbWbWi', 'agM', 'aTZVIYcNdcdcdcbWXTdaTUZUTZUZU', 'YYbWXVciYVYPVYV', 'adadVPaVPVaMgGZQIRddcJcabWbXbXb', 'UYUFj', 'aPDSCCX', 'Cj', 'aMFMFVPa', 'aPZQVPaV', 'bUYdbdbdbdbIdFOJOcScbTWUbWTXUbdidbdP', 'aDhPDAPCC', 'YFbWiPVPcVYFJVZR', 'UbOdbdbdOdbdbdbNdbdNObdObdbdbJbdbdbdbdbdbdbddbdbUdbUdNdNdbdbdbObOdbdbOd', 'bPVPUdbdIUdUcdcdcdYbWXi', 'ahBQIPDCC', 'adUdIUFIcbWXdadiPV', 'aaCaCagaMaMQMQMQMQE', 'Yj', 'aJPJY', 'bdPVbdbdbdbdbdbdbTdTdTbTbTSaTZdaUdU', 'PVdIUdFIUcddcbWXijT', 'CDDhBQCDC', 'aVPaMFJdVa', 'aBaWPaWbWb', 'aEGAGAGPTDPaCC', 'aDCDCMDC', 'aTSTSTSaC', 'aDCJFjJjCMDC', 'aDhPDTSaCC', 'CBAGDh', 'gDhdCcaFaMDC', 'aM', 'aVa', 'gGMCDCaE', 'aDPCDhSPDCC', 'YjPV', 'aPTPTSTSPSPSPSaC', 'diYjUYUYUdUdUTUTZTZHYWFWFbWbdTYUYUZRbW', 'aUbJbWIdUdUd', 'aYFJM', 'ICDIUdUdYcYcdcdcbWdXiCD', 'aaSabTW', 'adaPaTdZ', 'aDhPTSPDCC', 'Yj', 'aAGhRbMgh', 'aPTC', 'CDhBQDC', 'ahBABQEGCMDCD', 'aVjaY', 'YYaYcMbWaYXiaXP', 'aGCMDCE', 'aWWbWSdWZdSZdSdSTSTdSTdSdSdWaTaPTaa', 'aPDTPTPaC', 'aAa', 'aaYbYbVPTZaZaUdUd', 'VbWXcScScaScSNVcaO', 'abWbYMTWVWVWR', 'aaCaCPTPaC', 'aYUYUYYbWXUYUYUYUMiP', 'aDhPDCC', 'MZSZSZQMagFZSZS', 'aaPCdaVP', 'DECG', 'aUYjP', 'aMPGada', 'aM', 'adZdZTId', 'aPZC', 'aDCPSPDCC', 'aaZTZTZTZTZTdZTZSZSM', 'aYaYdIcdccXi', 'aCAdaDTdTahdZT', 'adgaYM', 'aDhPCDC', 'ahCMDC', 'aPCSa', 'aZTZTZTZaTZTZTZPTabZT', 'aYM', 'DDhBQDCC', 'CCED', 'aDCFaFFNPSPDaCC', 'aUjFjYPVPV', 'aPTPTPaPC', 'aPZC', 'abdbdVTPa', 'abWbWbWIWVbWXc', 'acbTZRcbFWijV', 'aYUTUTUTUTUTVIaFbUWXdNV', 'aVTPPTa', 'dadTVZRPcbcJcbWiaVdPaP', 'aUYUYaUUaYUNOUYZRb', 'YjFP', 'aaZTZTZTSTSZHUFbWbTZTZTZT', 'CDCDh', 'aIFYIFIFUdcdcdcdcbWXdUidP', 'UUOVY', 'CBDCDh', 'aTPDaC', 'AGhRQRQRQRQRQR', 'aPaC', 'YbdUdUddUIFbWdXiP', 'TTZTZTZTTZZYZYcbWTbWbiZjTZZTZ', 'CBADCh', 'ajYPVPV', 'aOUEGQE', 'CEDGZRbWbiPhBQ', 'MFJV', 'CDhBQ', 'VjPR', 'aIFSdcdcdcdcdcbWdXUdiUPEdUdUdGg', 'adTbaVa', 'bdcdcZbWXTZViaIjTVZR', 'aPTPTPC', 'Yj', 'YOPU', 'VbRYWbWiaPVPdT', 'aVbPVdUd', 'aOYUaPY', 'aUIddUcdcbWdUdXij', 'aVPPTPZa', 'aTU', 'aPZC', 'TZTSZHZFbWbTZTTZTZT', 'aY', 'aPTZabdaVTP', 'agUcYMYMhQa', 'aCPTPaP', 'aYi', 'aaCSPaZTZC', 'ddaIdcdcdcbWXP', 'aCDhPDaCCD', 'aUUSTSTSTSZHdUFbWbTdUdPZSZSZSZQ', 'aPDCC', 'aVOU', 'aOUT', 'aUdIUdUdUdcdcdcdcbWXdUdNV', 'dhEhBaGZRKLKLUKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLEGQOIaNENO', 'aPIdad', 'ajY', 'CBZQDCDh', 'CDCDh', 'AGhRbW', 'aFcY', 'aZbdabTUdUdTd', 'VjYaVPVaVa', 'VjPVY', 'agTM', 'aYTZRcbWijU', 'aC', 'aTZTZTZTZTZTZTZdXVZ', 'adaVTVTVPa', 'aUIFcdcdcdXdUdUdij', 'aTZaITZTZTZTZ', 'hBQ', 'CDBCDh', 'acCMDh', 'CQEARQRQRQRAGDCDhB', 'aPTPTZC', 'aUiOYDRbW', 'YiPVPVaY', 'TTFdcdcdcbWXZTiZUTPZaIa', 'aVPadPTZTZTZTZTTaPPaTPTaVP', 'Yj', 'aCGhARFaFaFaFaFPDaCPA', 'aJM', 'ChDA', 'aaDAPAPC', 'AhRG', 'IaIaIdFIFIdcdcdcdcdWXUdUdiP', 'AGhR', 'AGhQRQRQRQRQRQRQRQRQRQRQRQRQIRIRIRI', 'CBDCDh', 'agMJVZR', 'FiPYcYcYcYcFJVZRa', 'FcYcYRFiP', 'VXPaYi', 'dIaWbdaUWdUdbacdcdcUUY', 'aCPTPaP', 'CDh', 'VbdbdbTdUdUdPZSZSZSZSYZbQU', 'aYNOUaUV', 'aDhPTSTSTSDaCC', 'aADPAhaC', 'CDA', 'CQEGARjPhBD', 'aFJVM', 'aXiVaVaXVGaY', 'aDhcPDTPCaDCC', 'UTUTZdUd', 'aKVTKPaC', 'ahBGgZQEGZARbWbiPMCDCYD', 'aPTC', 'BQEG', 'adZVT', 'ajYPVPVFa', 'aiUYXP', 'hPZSZSZSZSZSZSZSBQE', 'YUdUadUIdUdbWXP', 'ddUdPIUdFbWUdUXdUdiPVPVU', 'YIUcdcdcdcXaVdiUdUdP', 'aPDSPCSPSPC', 'aYcPVVPVYcYaVF', 'OVGAG ...
# Filtered 2164 latest pre-surgery songs' mapped syllable orders:
# ['VYPVj', 'adaIWIdcdbWdUdUdUdUdX', 'VOUaVYQEJVN', 'aFjYgUgUgUgUgMCDhA', 'aYEGdWi', 'VYPVPj', 'UVO', 'VjacPFUFY', 'jPV', 'gOPVPVPDhCAGARTbWAdXN', 'hBZQ', 'agYcYCMDh', 'VYPVPVPVPj', 'CDhBQEG', 'gJVQEGZQ', 'abWVbXiXNONONONONONONONSZSaPVPVYPYRYFUYUYJUNVjYR', 'agUFUFgUYgUgMCDhBQ', 'TFbWbTTZHZ', 'aeVeSZSZSZQDhCaCaCCDg', 'YIdbWXNO', 'aTDUChAGhgRbWiE', 'aYTbaZVZVZVZVRYcFbdbjdbdbPV', 'CGZQIQIEhBQEhgBQEFJEJEhEhEheKLKLKLKLKLKLKLKLKLED', 'aBeBAGhYRDUhCgeC', 'aDhBCQE', 'hHCHCgeBZQC', 'gCD', 'agdcdFJcVM', 'YNVgeKLKLKMLYMKLKLKLKLEGVQFbWX', 'VcPVYja', 'ggMCDahAGhR', 'aYMaM', 'aYaPVPVPRYcFJVjQE', 'ChAGhARbWbiD', 'gGhGhARIbFgaMCDhA', 'aTWbTaTdHa', 'UdUdFIcbWUXdUdNUdKLKLKLKPKLKLKLKLKLKLKLKLKLKLKLKEGI', 'hBQE', 'ZFTWbZdTTaHS', 'TbWiVVZVR', 'SWbTTHZTFb', 'YIdbWYXNKLKLKLKLKLKLKLKLEGVG', 'aIYaFIdcdcIHIHIHIHFIHIFdEJ', 'aTdZcbWXTiZaTEZVI', 'gDhAC', 'ACDN', 'TZQZETZSOVZS', 'XLKLKLKLKLKLKLKLKLKEN', 'aYdIFIFScdcb', 'BQE', 'MCgDhaAgGhAhAhR', 'aPghC', 'gCLCLKLKLKLKLKLKLKLKLKLKLE', 'aPaC', 'aTC', 'VdJVcFa', 'BQEG', 'aPSZC', 'aPaC', 'CfLKLKLKLKLKLKLKLKLKLE', 'ggcaM', 'DBZQh', 'hBQ', 'aaCdadPDZCaC', 'aOYaU', 'AhRbFbFG', 'Ci', 'YEGIdUbWbWXNfchYCcd', 'CDhB', 'abTWbTPTZaPVRcFWHjFWF', 'adTSZHZTZTZTTZ', 'aPTaC', 'aPiLKLKaPC', 'ggcCMaDh', 'aaIdFSTbTWXNONONfLKLKLKLKLKLKLKLKLKLKLEdhQ', 'VYaYacVdjacVFaEF', 'abd', 'gBQe', 'geBQ', 'abWbSTSTSTTZWH', 'aYaYIaYFIaYFcabWbdadT', 'aaUdUdUdUdUd', 'DQhBQEhB', 'XEAi', 'Ci', 'aPC', 'CHj', 'ZPaTPaaTVTV', 'aaCP', 'aVIFIdcdcdcbWbWbWbXdNLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLKLE', 'aPCcFJVPSPSPa', 'aIFIdcdcdcbdbWXdN', 'ChBZQD', 'AF', 'aaCVaVTVTV', 'aPjHjHjaC', 'CE', 'agM', 'aTPC', 'abWbdTcdcdcdcdcd', 'aPaC', 'agM', 'TTVIUddacbUWbd', 'aEcdcCDhBba', 'aPIFIcdcSdcScbWbXiUTEd', 'VYJcF', 'gCDhh', 'aPCHjHj', 'agM', 'CEG', 'aPSPPaKTKPJTaTa', 'agYMCDNX', 'aMgPa', 'aOdIFIbTObWbadT', 'aYij', 'BEAGQ', 'CE', 'TVbZR', 'aFIFIdcdcbWXNcOdI', 'aZHFTbWbSZaTTaS', 'aIdFdcdcbWX', 'CEhB', 'gDhAGhRbFC', 'aIdFTWXUdUdTdNLKLKLKLKLKLKLKLEA', 'AhRG', 'gEGCAC', 'ARGh', 'aPSZC', 'aVTPaC', 'aPDASAhSAC', 'ZZTZTZTTZTZaTZT', 'CE', 'eKLKLKLKELKTVLKLKLKLKLKLKL', 'adIFdcdcb', 'aWbWbTSZTZTZaTZSZSZQWEHJ', 'gDhBC', 'aTIbdZbd', 'TTSdZSZZQTEZThZATSTSZ', 'agCHjEGVAGAGYaYM', 'VcINYScbWX', 'aIdcbWXNUd', 'agMCACA', 'gCDhB', 'bbIFINUcUcbWbXNOd', 'daYbIVddcdcPIFIFEVhEhTd', 'dI', 'CDhB', 'aTZSZTZSZQIZTZTZ', 'aTZTZT', 'ARGh', 'aVTPC', 'adFdbcdcdcI', 'ghEC', 'aTZTZZTZTTSZHbZWadbYXTNVZTZTZ', 'aPDhCAGhR', 'aFbSTSTSTSZH', 'aPaC', 'CDhAGhAR', 'ZHTbWbZTTZTZSTSTSTZ', 'bYbFbWbZTSZZSZSTHHWbWbWbaTTZR', 'adZQXEdYIdhBQEhBZQVGaUdcbWUXNKLKLKLKLKLKEG', 'aZIUFIFIFcddcSdcbWUdUXdUTidE', 'dijJjJdYdYcYcYYdY', 'gDhC', 'aPHTjHjHjPC', 'agMCDh', 'aPDSTChg', 'geLKLKLKLKLKLKLKLKLK', 'agdcdMaM', 'AGhR', 'aFZa', 'VadcjFP', 'gBeBeBQe', 'gEC', 'aUaUbdbIdcbWX', 'gCDh', 'dIFIcdcdcdcbWXNXNP', 'TVPZbWbTTZTZVZIRYbFZTSjTSHjHjHjTZPH', 'ChBZQD', 'gEC', 'agMCDhAF', 'AGhR', 'AGhR', 'aijJWVYWaWY', 'agM', 'CX', 'adbdbdbdNdNdNbNbdXdadadXdUXUdUdUdUdTUdVT', 'aPC', 'aPaVaC', 'aTEZSTZSTSZQ', 'agcMCE', 'CDhAGhR', 'CDhAbJF', 'ddcdScbaI', 'aCPASHASAjHjPSPaP', 'aTSTZTSZT', 'aGbIdaddcbWXNfLKLKLKLKLKLKLKLE', 'gG', 'gDhBhghCQ', 'CihE', 'aFbWXdTNZdOI', 'CHjHjE', 'CE', 'EJCDhBhZQE', 'aPTC', 'ggMaCDA', 'gEChB', 'CiE', 'aGPVa', 'CDhBQ', 'aAVEPaVaVChC', 'VJYVcFa', 'AhAhRG', 'gDhC', 'adcdcdbHbWbYaYacdc', 'VUbIdUdUdFIFdcScbWXNTdTdOTaT', 'BEhAGhRIZQ', 'CDhB', 'CDhAGhAhR', 'ZTBYaZTZSTSZSZZQaEbCWbDZh', 'ARGh', 'CN', 'CEhAGhR', 'aZTZC', 'AhRG', 'AF', 'aIbdcbdT', 'AF', 'TaPYijijij', 'TZUZUTZRcJFUTJZKLKLKLKLTKLKLKLKLKLEQ', 'gCACE', 'aPCPTPa', 'agYJMLKLKLKLKLKLKLEG', 'ARGh', 'aMEQVIPdcbWXaiKLKLKLKLKLKbdLKbdLKLKbLKLKLKLEd', 'aaZTYj', 'abdbUTUTbTbTbTbd', 'abTHW', 'ARGh', 'CEG', 'ChAGhRD', 'gEhEhCB', 'Ci', 'aPTC', 'agMC', 'CiX', 'aTZTZTZTZTSZTZ', 'adgcdcdcdcdbQM', 'TSZQZESZSZ', 'aWbTHb', 'aPDThSTSaACACACACACACCA', 'TbCWbWbaTdIZHdcbWXigZhW', 'abIFIFdFdScScScbWXiEdad', 'CEhBQ', 'gJV', 'VadcF', 'aHjHjHjPEC', 'ThCZcdcbWTXWXZiTEZIGQE', 'BQ', 'IaC', 'acgMeKLKLKLKLKLKLKLKLKLKLEG', 'adcJUYMUgdUdI', 'FbIbIUdFUaUaUbWbWXTNKLKLKLKLKLKLKLKLKLKLE', 'aPaC', 'aPSC', 'AGhRb', 'C ...
# Filtered 2164 earlier pre-surgery songs' mapped syllable orders:
# ['aVaVKVPaVa', 'aDCDPhaCA', 'aZbTZTaHa', 'abWbTHFa', 'agcMCDh', 'aUYUOT', 'EAG', 'aWTa', 'aGAGdbdbIdcbWbXNiNiNgJLKLKLKLKLKLKLKLKE', 'bZRTEhAGhR', 'ChD', 'ajPTZRYYbFJV', 'IIdbWbad', 'CDhA', 'aDPhC', 'aiPVC', 'QZSGZQTSEZShBZSZQE', 'agCMDh', 'aPDShCCACACA', 'FajPPaC', 'GbAhAGaWahahbah', 'aOURFJ', 'aDhPSCZCDh', 'aQYgFgFgFMgFgFgFgFgCDhB', 'aaCPSZC', 'aHWHWHWIFbWbTdadacScW', 'ggcMCDhAaGhR', 'aNYOVX', 'aIYddPYPcbWXNLKLKLKLKLKLKLKLEF', 'aDPShCaCCA', 'aaTFIaZFITFIdcbWbWiUFTEd', 'NKLKLKLKLKLKLKLKLEG', 'ahBQEhBQIFIdSTZTZaYXNgdYadCD', 'aZSZQTEZSAZSGhR', 'CjV', 'agUCYUYM', 'TZFbWbSTTSTbRZHbWbiEGg', 'aMPgaPaC', 'aRgCDhMAGhQ', 'VjdcdcdFaVaVa', 'dIYcbWXN', 'aPabV', 'aPaPVTVPa', 'aGTGTVTa', 'aVeVeVeVYPVHIbWXNgejB', 'aJVYcF', 'aPVYaYCj', 'aC', 'aPYj', 'adcVUWX', 'ZbWbZTTVZTZTTZH', 'adIdbWXV', 'hCgeLKLKLKLKLKLKLKLKLKLE', 'dbIcVdVYVYXV', 'aPDhAaGhRC', 'adIdcbWXNKLKLKLKLKLKLEG', 'aPJa', 'aYNKLKLKLKLKLKLKLEJVbWYWYX', 'aYbIddcdcaFEOV', 'aabWXdaI', 'VdcPVF', 'abWXTdI', 'hGhRQRQRAbA', 'gFJV', 'aPYaIFIij', 'VPjY', 'aTZHWb', 'MFJLKLKLKLKLKLKLKLKLEhgAGghghR', 'geLKLKLKLKLKLKLKLKLKLKLEQ', 'FYbdaIaIaIUFdIdcYXa', 'aFIFIdcdbWdXNfLKLKLKLKLKLKLEIQ', 'aIVIdcbWXYdVbWaZT', 'VJVcPRcbWbiJiFEMEMEFJY', 'VaVFdcScScdcWFIHdWbWFJVI', 'ZaSZTSZSZSZZQTZTZTZ', 'ChAGhRD', 'aZaIdaWXVd', 'VTPVYRcUcbWiEFJbVWbY', 'aFYFj', 'VJbVWXYcYcYcYNdYdYfcILKLKLKLKLKLKLKLKLKLKLKLKLKLKLKEGAQE', 'aQPIYdYdYdcdYIWYHFbadYdYWXjNfKLKLKLKLKLKLE', 'aVIPad', 'VaJVTYPTaYij', 'aYijJEMCDhj', 'VYPIaIaFJVij', 'aTIZdcddJcJbJbJWagCD', 'aPIcbWXaNOdV', 'aDZTThZCCAGRVFVF', 'VYPj', 'aTZRIbWaUObWVbY', 'aVUYUNONO', 'aZTcdcdcdcdcdcbWb', 'aFIYcVbWXaNVYbaWbITPJQ', 'VIaIaIaIHIWFWFWFJYVcRcbWbIaaVIaIaa', 'aacXVTHbW', 'aFYiYj', 'aIdbWbXVd', 'aVYadcYdcadbWXI', 'aUYUO', 'aAGhRIPdcIFEThZCTDZhd', 'CGARDhCA', 'aIddaScbWbXV', 'VTaYPZQbYb', 'aIFbWXNKLKLKLKLKLKLKLKLdEV', 'aYPj', 'aFcVVdVcPbWXNadI', 'aPYj', 'ahPBDhCCD', 'hAGARFjP', 'GI', 'adcdcF', 'aXYNOVi', 'ZdbZTdYdPbdb', 'VKLKLKLKLKLEQOVaYZRFbWXjNfLfLKL', 'aCdXN', 'ahBQEODPhCCE', 'abaTTSTSTSVZKTZPQHbWZ', 'XdYdYdZTZTIaIaIaIdaScObYVUUYbWbTT', 'VQFFbWXNIOIVRFJVdG', 'AGgARFbWb', 'hCEFEJV', 'aUaUOYVbWa', 'gDhAGARARFC', 'aPC', 'aZSZSZQTaTSEZJSZS', 'YVO', 'aPYWaHaHWIWIFbWXdYNOjQE', 'BEMEMFQ', 'VaJcVdcF', 'ZQZEGSTZSZSZSZZSZSZQTEQEZThZSB', 'adadbWYX', 'ZYTVPVbWba', 'dbcbTPFbFIHdWH', 'gOhREAGQIdICDhBAQE', 'VPdcdIbWXNjOVY', 'VbWXNYUOIVYRYFjP', 'aaFEdadSJdcVdcRYJcJbFdcJVW', 'adcbWXWXdVTcRcFWIJ', 'VPYVPVZRFaJVj', 'addcdcdIaFI', 'ChAGhARFJD', 'VjPVRcFJVVFWbTOcaYJRcbWJVVcYcFX', 'aYFYjJV', 'aaZTZTZTTZTZHIbWbWIZTQadI', 'gDhCAGghR', 'aIFIFIbWXVUNOVYcbWd', 'VYPVPVRFbJVj', 'dOJaU', 'VYPVPVj', 'aIcbWdXNfKLKLKLKLKLE', 'aYOVZTZSZSZSj', 'adcSbVCdTZdZdZI', 'aVITVdcdcScObOdVbVb', 'acFJVaaVRYRYRYRcbWYijREMEMEJ', 'aPZdTZTZSZHbWbYZTZTjZPcdcdVdVdaQ', 'aBZQIdFcdcIWJMghCDh', 'aOJOVdU', 'ajTgZaedLKLKLaKLKLKLKLKLKLEYG', 'aVUO', 'hBQEG', 'TTIdZcbWXVTZSaTZZd', 'VdSScVdcdcO', 'aJXcNVaPVRcFYadJVcdPVQWE', 'adJVcdZTcF', 'aQECDhgBQMCDEhB', 'aVYj', 'aXNYObW', 'ChAGhRD', 'CDhAGhR', 'TITcbWZXTijdPVSZ', 'aYJiaUaUOUVY', 'BQ', 'ahCDYhBQEGiEbWAGQXE', 'YJVcRFcbWbYbYbYiEJ', 'hgACeLKLKLKLKLKLKLKLKLEQ', 'aQQSbWbaTTaPTPTZTPRIZcbWbiSJEZ', 'TZITFdcdcdcZWbJd', 'aFbWXdNadaOVIRbWbTVT', 'aNLKLYKLKLKLKLKLEbWX', 'hAGAhRFJVC', 'AGhARFJV', 'VdYdVadYcFdcJVbWIbWVWYXUNVWX', 'aUVadIFbWbXdNVdVdUVUVUV', 'VJVJVYBja', 'aTATATATATATAaTTATA', 'fKLKLKLKLKLKLKLKLELKL', 'NOV', 'adadaVdI', 'aVDTChB', 'TZIabWTaFaYUOZad', 'hhaha', 'aTPTZTZbTdTdTVT', 'abT', 'aTZTZTZaZ', 'VDAGARdWVWYOLKLKLKLKLKLKLKLKLEhaIC', 'bIddb', 'aEDPhAC', 'FdIPFIdYdYcdbaVaVaYVYVYdYbdb', 'aTijaFgYaY', 'PZSZSZSPTST', 'aVTVTVPVbTb', 'aaTSTSTSTSZHbWbTTZPTTabd', 'aYj', 'hbFA', 'aIdabd', 'cNVX', 'aUaVTZTPTPUTO', 'FaFAPDhWPWPBC', 'adYajTgZTZTTZa', 'aYghCAjGhAR', 'aLKLKLKLKLTSZSPDhCCDgeLKLKLK', 'bYdFbWbPYIa', 'ajdaY', 'abaIYad', 'adbdZTbZaTaZTdPTPZdZTZTZdaaZaZdTb', 'aYgij', 'VbdbVTPTPTdPTPQUaTbWUTXbTdNYbdbd', 'aUO', 'ghCDhAgGhR', 'gCDAGARbh', 'aCDhPAaPGhR', 'HJM', 'aOUVTaPTPTSTU', 'CDhCDhA', 'aDPhC', 'Aa', 'aTZTZTZTPTPTTPSZQZdEZdadadadad', 'aWYXNdadaId', 'aDPAPhCaC', 'aPTPTZQZaAGTZT', 'VOY',  ...

# %% [markdown]
# ## Divide data and save as a .mat file in the designated folder (NEED TO UPDATE FOLDER PATH IN LINE 65)

# %%
import pandas as pd
import scipy.io as sio
import os

# Function to save syllable orders as cell arrays
def save_group_to_mat(mapped_syllable_orders, group_name, animal_id, save_dir):
    # Ensure the save directory exists
    os.makedirs(save_dir, exist_ok=True)
    
    # Wrap each mapped syllable order in a list (for MATLAB cell array compatibility)
    mapped_syllable_orders_cell = [[order] for order in mapped_syllable_orders]
    
    # Prepare the data as a dictionary for saving to .mat format
    data_dict = {f'mapped_syllable_order_{group_name}': mapped_syllable_orders_cell}
    
    # Generate a file name based on the animal ID and group name
    file_name = f"{animal_id}_{group_name}.mat"
    file_path = os.path.join(save_dir, file_name)
    
    # Save the .mat file
    sio.savemat(file_path, data_dict)
    
    # Print confirmation
    print(f"Saved {file_name} to {file_path}")

# Function to process and save pre- and post-surgery syllable orders
def filter_surgery_songs(organized_data_frame, surgery_date, group_size, save_dir):
    # Filter the DataFrame for songs recorded after the lesion date (post-lesion)
    post_lesion_songs = organized_data_frame[organized_data_frame['Date'] > surgery_date]
    
    # Select the first 'group_size' number of rows from the post-lesion songs
    filtered_post_surgery_songs = post_lesion_songs.head(group_size)
    
    # Filter the DataFrame for songs recorded on or before the lesion date (pre-lesion)
    pre_lesion_songs = organized_data_frame[organized_data_frame['Date'] <= surgery_date]
    
    total_pre_lesion_songs = len(pre_lesion_songs)
    print(f"Total number of pre-lesion songs: {total_pre_lesion_songs}")
    
    if total_pre_lesion_songs < group_size * 2:
        raise ValueError(f"Not enough pre-lesion songs to split into two groups of size {group_size}. Total available: {total_pre_lesion_songs}")

    # Select the last 'group_size' number of rows for the latest pre-surgery songs
    latest_pre_surgery_songs = pre_lesion_songs.tail(group_size)
    
    # Select the 'group_size' rows just before the latest pre-surgery songs
    earlier_pre_surgery_songs = pre_lesion_songs.iloc[-(group_size * 2):-group_size]
    
    print(f"Number of latest pre-surgery songs: {len(latest_pre_surgery_songs)}")
    print(f"Number of earlier pre-surgery songs: {len(earlier_pre_surgery_songs)}")
    
    # Create lists to hold the mapped syllable orders for each group
    mapped_syllable_orders_post = list(filtered_post_surgery_songs['mapped_syllable_order'])
    mapped_syllable_orders_latest_pre = list(latest_pre_surgery_songs['mapped_syllable_order'])
    mapped_syllable_orders_earlier_pre = list(earlier_pre_surgery_songs['mapped_syllable_order'])

    # Get the animal ID (assuming it's consistent across the dataset)
    animal_id = organized_data_frame['Animal ID'].iloc[0]
    
    # Save each group of syllable orders into a separate .mat file
    save_group_to_mat(mapped_syllable_orders_post, 'post_lesion_songs', animal_id, save_dir)
    save_group_to_mat(mapped_syllable_orders_latest_pre, 'latest_pre_lesion_songs', animal_id, save_dir)
    save_group_to_mat(mapped_syllable_orders_earlier_pre, 'earlier_pre_lesion_songs', animal_id, save_dir)

save_directory = "/Users/mirandahulsey-vincent/Desktop/DECODER_cell_arrays"
# Assuming organized_data_frame_with_orders contains the data
filter_surgery_songs(organized_data_frame_with_orders, surgery_date, group_size, save_directory)
# Out:
# Total number of pre-lesion songs: 4608
# Number of latest pre-surgery songs: 2164
# Number of earlier pre-surgery songs: 2164
# Saved USA5326_post_lesion_songs.mat to /Users/mirandahulsey-vincent/Desktop/DECODER_cell_arrays/USA5326_post_lesion_songs.mat
# Saved USA5326_latest_pre_lesion_songs.mat to /Users/mirandahulsey-vincent/Desktop/DECODER_cell_arrays/USA5326_latest_pre_lesion_songs.mat
# Saved USA5326_earlier_pre_lesion_songs.mat to /Users/mirandahulsey-vincent/Desktop/DECODER_cell_arrays/USA5326_earlier_pre_lesion_songs.mat
